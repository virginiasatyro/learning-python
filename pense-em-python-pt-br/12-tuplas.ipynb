# %% [markdown]
# # Capítulo 12 - Tuplas
#
# Uma tupla é uma sequência de valores. Os valores podem ser de qualquer tipo, e podem ser indexados por números inteiros, portanto, nesse sentido, as tuplas são muito parecidas com as listas. A diferença importante é que as tuplas são imutáveis.
#
# Sintaticamente, uma tupla é uma lista de valores separados por vírgulas:

# %%
t = 'a', 'b', 'c', 'd', 'e'

# %% [markdown]
# Embora não seja sempre necessário, é comum colocar tuplas entre parênteses:

# %%
t = ('a', 'b', 'c', 'd', 'e')

# %% [markdown]
# Para criar uma tupla com um único elemento, é preciso incluir uma vírgula final:

# %%
t1 = 'a',
type(t1)
# Out:
# tuple

# %%
# Um único valor entre parênteses não é uma tupla:
t2 = ('a')
type(t2)
# Out:
# str

# %%
# Outra forma de criar uma tupla é com a função integrada tuple. 
# Sem argumentos, cria uma tupla vazia:
t3 = tuple()
type(t3)
# Out:
# tuple

# %%
# Se os argumentos forem uma sequência (string, lista ou tupla), 
# o resultado é uma tupla com os elementos da sequência:
t = tuple('lupins')
t
# Out:
# ('l', 'u', 'p', 'i', 'n', 's')

# %%
# A maior parte dos operadores de lista também funciona em tuplas. 
# O operador de colchetes indexa um elemento:
t = ('a', 'b', 'c', 'd', 'e')
t[0]
# Out:
# 'a'

# %%
# E o operador de fatia seleciona vários elementos:
t[1:3]
# Out:
# ('b', 'c')

# %%
# Entretanto, se tentar alterar um dos elementos da tupla, vai receber um erro:
t[0] = 'A'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Entretanto, se tentar alterar um dos elementos da tupla, vai receber um erro:
# ----> 2 t[0] = 'A'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Como tuplas são imutáveis, você não pode alterar os elementos, mas pode substituir uma tupla por outra:
t = ('A',) + t[1:]
t
# Essa instrução faz uma nova tupla e então a atribui a t.
# Out:
# ('A', 'b', 'c', 'd', 'e')

# %%
# Os operadores relacionais funcionam com tuplas e outras sequências:
(0, 1, 2) < (0, 3, 4)
# Out:
# True

# %%
(0, 1, 2000000) < (0, 3, 4)
# Out:
# True

# %%
# Muitas vezes, é útil trocar os valores de duas variáveis. 
# Com a atribuição convencional, é preciso usar uma variável temporária. 
# Por exemplo, trocar a e b.
a = tuple('abc')
b = tuple('xyz')

temp = a
a = b
b = temp

a
# Out:
# ('x', 'y', 'z')

# %%
# Essa solução é trabalhosa; a atribuição de tuplas é mais elegante:
a = tuple('abc')
b = tuple('xyz')

a, b = b, a

print(a, b)
# Out:
# ('x', 'y', 'z') ('a', 'b', 'c')

# %%
# De forma geral, o lado direito pode ter qualquer tipo de sequência (string, lista ou tupla). 
# Por exemplo, para dividir um endereço de email em um nome de usuário e um domínio, você poderia escrever:

addr = 'virginiasatyro@gmail.com'
uname, domain = addr.split('@')

print(uname, domain)
# Out:
# virginiasatyro gmail.com

# %%
# A função integrada divmod toma dois argumentos e devolve uma tupla de dois valores: o quociente e o resto. 
# Você pode guardar o resultado como uma tupla:
t = divmod(7, 3)
t
# Out:
# (2, 1)

# %%
# Ou usar a atribuição de tuplas para guardar os elementos separadamente:
quot, rem = divmod(7, 3)

print(quot, rem)
# Out:
# 2 1

# %%
# Aqui está um exemplo de função que retorna uma tupla:
def min_max(t):
  return min(t), max(t)

# %%
# As funções podem receber um número variável de argumentos. 
# Um nome de parâmetro que comece com * reúne vários argumentos em uma tupla. 
# Por exemplo, printall recebe qualquer número de argumentos e os exibe:
def printall(*args):
    print(args)

printall(1, 2.0, '3')
# Out:
# (1, 2.0, '3')

# %%
# O complemento de reunir é espalhar. 
# Por exemplo, o divmod recebe exatamente dois argumentos; ele não funciona com uma tupla:

t = (7, 3)
divmod(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       1 # O complemento de reunir é espalhar.
#       2 # Por exemplo, o divmod recebe exatamente dois argumentos; ele não funciona com uma tupla:
#       4 t = (7, 3)
# ----> 5 divmod(t)
#
# TypeError: divmod expected 2 arguments, got 1

# %%
# No entanto, se você espalhar a tupla, aí funciona:
divmod(*t)
# Out:
# (2, 1)

# %% [markdown]
# Muitas das funções integradas usam tuplas com argumentos de comprimento variável. Por exemplo, `max` e `min` podem receber qualquer número de argumentos:

# %%
max(1, 2, 3)
# Out:
# 3

# %%
# Mas sum, não:
sum(1, 2, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Mas sum, não:
# ----> 2 sum(1, 2, 3)
#
# TypeError: sum() takes at most 2 arguments (3 given)

# %%
# Como exercício, escreva uma função chamada sumall que receba qualquer número de argumentos e retorne a soma deles.
def sumall(*args):
    total = 0
    for num in args:
        total += num
    return total

sumall(1, 2, 3, 4, 5)
# Out:
# 15

# %% [markdown]
# `zip` é uma função integrada que recebe duas ou mais sequências e devolve uma lista de tuplas onde cada tupla contém um elemento de cada sequência. O nome da função tem a ver com o zíper, que se junta e encaixa duas carreiras de dentes.

# %%
s = 'abc' 
t = [0, 1, 2]
zip(s, t)

# %%
for pair in zip(s, t):
  print(pair)
# Out:
# ('a', 0)
# ('b', 1)
# ('c', 2)

# %%
# Se quiser usar operadores e métodos de lista, você pode usar um objeto zip para fazer uma lista:
list(zip(s, t))
# Out:
# [('a', 0), ('b', 1), ('c', 2)]

# %%
# Você pode usar a atribuição de tuplas em um loop for para atravessar uma lista de tuplas:
t = [('a', 0), ('b', 1), ('c', 2)]
for letter, number in t:
    print(number, letter)
# Out:
# 0 a
# 1 b
# 2 c

# %%
# Os dicionários têm um método chamado items que devolve uma sequência de tuplas, onde cada tupla é um par chave-valor:
d = {'a':0, 'b':1, 'c':2}
t = d.items()
t
# Out:
# dict_items([('a', 0), ('b', 1), ('c', 2)])

# %%
# O resultado é um objeto dict_items, que é um iterador que percorre os pares chave-valor. 
# Você pode usá-lo em um loop for, desta forma:
for key, value in d.items():
    print(key, value)
# Out:
# a 0
# b 1
# c 2

# %%
# Indo em outra direção, você pode usar uma lista de tuplas para inicializar um novo dicionário:
t = [('a', 0), ('c', 2), ('b', 1)]
d = dict(t)
d
# Out:
# {'a': 0, 'c': 2, 'b': 1}

# %% [markdown]
# Em muitos contextos, os tipos diferentes de sequências (strings, listas e tuplas) podem ser usados de forma intercambiável. **Então, como escolher uma em vez da outra?**
#
# Para começar com o óbvio, as strings são mais limitadas que outras sequências porque os elementos têm de ser caracteres. Também são imutáveis. Se precisar da capacidade de alterar caracteres em uma string (em vez de criar outra string) você pode querer usar uma lista de caracteres.
#
# *As listas são mais comuns que as tuplas, principalmente porque são mutáveis*. Mas há alguns casos em que você pode preferir tuplas:
#
# 1. Em alguns contextos, como em uma instrução `return`, é sintaticamente mais simples criar uma tupla que uma lista.
#
# 2. Se quiser usar uma sequência como uma chave de dicionário, é preciso usar um tipo imutável como uma tupla ou string.
#
# 3. Se estiver passando uma sequência como um argumento a uma função, usar tuplas reduz o potencial de comportamento inesperado devido a alias.
#
# Como tuplas são imutáveis, elas não fornecem métodos como `sort` e `reverse`, que alteram listas existentes. Porém, o Python fornece a função integrada `sorted`, que recebe qualquer sequência e retorna uma nova lista com os mesmos elementos ordenados, e `reversed`, que recebe uma sequência e retorna um iterador que percorre a lista em ordem reversa.
#
#
# --------------
#
# As listas, os dicionários e as tuplas são exemplos de estruturas de dados; neste capítulo estamos começando a ver estruturas de dados compostas, como as listas de tuplas ou dicionários que contêm tuplas como chaves e listas como valores. As estruturas de dados compostas são úteis, mas são propensas ao que chamo de erros de forma; isto é, erros causados quando uma estrutura de dados tem o tipo, tamanho ou estrutura incorretos. Por exemplo, se você estiver esperando uma lista com um número inteiro e eu der apenas o número inteiro (não em uma lista), não vai funcionar.
#
# Para ajudar a depurar esses tipos de erro, escrevi um módulo chamado structshape, que fornece uma função, também chamada structshape, que recebe qualquer tipo de estrutura de dados como argumento e retorna uma string, que resume sua forma.

# %%
"""
This module provides one function, structshape(), which takes
an object of any type and returns a string that summarizes the
"shape" of the data structure; that is, the type, size and
composition.

This module is part of Swampy, a suite of programs available from
allendowney.com/swampy.

Copyright 2012 Allen B. Downey
Distributed under the GNU General Public License at gnu.org/licenses/gpl.html.

"""

from __future__ import print_function

def structshape(ds, pending=None):
    """Returns a string that describes the shape of a data structure.

    ds: any Python object

    Returns: string
    """
    if pending is None:
        pending = set()

    if id(ds) in pending:
        return 'infinity'

    pending = pending | set([id(ds)])

    typename = type(ds).__name__

    # handle sequences
    sequence = (list, tuple, set, frozenset, type(iter('')))
    if isinstance(ds, sequence):
        t = []
        for i, x in enumerate(ds):
            t.append(structshape(x, pending))
        rep = '%s of %s' % (typename, listrep(t))
        return rep

    # handle dictionaries
    elif isinstance(ds, dict):
        keys = set()
        vals = set()
        for k, v in ds.items():
            keys.add(structshape(k, pending))
            vals.add(structshape(v, pending))
        rep = '%s of %d %s->%s' % (typename, len(ds), 
                                   setrep(keys), setrep(vals))
        return rep

    # handle other types
    else:
        if hasattr(ds, '__class__'):
            return ds.__class__.__name__
        else:
            return typename


def listrep(t):
    """Returns a string representation of a list of type strings.

    t: list of strings

    Returns: string
    """
    if len(t) == 0:
        return 'empty'

    current = t[0]
    count = 0
    res = []
    for x in t:
        if x == current:
            count += 1
        else:
            append(res, current, count)
            current = x
            count = 1
    append(res, current, count)
    return setrep(res)


def setrep(s):
    """Returns a string representation of a set of type strings.

    s: set of strings

    Returns: string
    """
    rep = ', '.join(s)
    if len(s) == 1:
        return rep
    else:
        return '(' + rep + ')'
    return 


def append(res, typestr, count):
    """Adds a new element to a list of type strings.

    Modifies res.

    res: list of type strings
    typestr: the new type string
    count: how many of the new type there are

    Returns: None
    """
    if count == 1:
        rep = typestr
    else:
        rep = '%d %s' % (count, typestr)
    res.append(rep)


if __name__ == '__main__':
    t = []
    print(structshape(t))

    t = [1,2,3]
    print(structshape(t))

    t2 = [[1,2], [3,4], [5,6]]
    print(structshape(t2))

    t3 = [1, 2, 3, 4.0, '5', '6', [7], [8], 9]
    print(structshape(t3))

    class Point:
        """trivial object type"""

    t4 = [Point(), Point()]
    print(structshape(t4))

    s = set('abc')
    print(structshape(s))

    lt = zip(t, s)
    print(structshape(lt))

    d = dict(lt)        
    print(structshape(d))

    it = iter('abc')
    print(structshape(it))

    t = []
    t.append(t)
    print(structshape(t))
# Out:
# list of empty
# list of 3 int
# list of 3 list of 2 int
# list of (3 int, float, 2 str, 2 list of int, int)
# list of 2 Point
# set of 3 str
# zip
# dict of 3 int->str
# str_ascii_iterator of 3 str
# list of infinity

# %%
t = [1, 2, 3]
structshape(t)
# Out:
# 'list of 3 int'

# %%
t2 = [[1,2], [3,4], [5,6]]
structshape(t2)
# Out:
# 'list of 3 list of 2 int'

# %%
t3 = [1, 2, 3, 4.0, '5', '6', [7], [8], 9]
structshape(t3)
# Out:
# 'list of (3 int, float, 2 str, 2 list of int, int)'

# %%
s = 'abc'
lt = list(zip(t, s))
structshape(lt)
# Out:
# 'list of 3 tuple of (int, str)'

# %%
d = dict(lt)
structshape(d)
# Out:
# 'dict of 3 int->str'

# %% [markdown]
# ## Glossário
#
# - **tupla**:
#     - Sequência imutável de elementos.
#
# - **atribuição de tupla**:
#     - Atribuição com uma sequência no lado direito e uma tupla de variáveis à esquerda. O lado direito é avaliado e então seus elementos são atribuídos às variáveis à esquerda.
#
# - **gather**:
#     - Operação para montar uma tupla com argumento de comprimento variável.
#
# - **scatter**:
#     - Operação para tratar uma sequência como uma lista de argumentos.
#
# - **objeto zip**:
#     - O resultado de chamar uma função integrada zip; um objeto que se repete por uma sequência de tuplas.
#
# - **iterador**:
#     - Objeto que pode se repetir por uma sequência, mas que não oferece operadores de lista e métodos.
#
# - **estrutura de dados**:
#     - Coleção de valores relacionados, muitas vezes organizados em listas, dicionários, tuplas etc.
#
# - **erro de forma**:
#     - Erro causado pelo fato de o valor ter a forma incorreta; isto é, tipo ou tamanho incorreto.
#
#
# ## Exercícios
#
# ### Exercício 12.1
#
# Escreva uma função chamada `most_frequent` que receba uma string e exiba as letras em ordem decrescente de frequência. Encontre amostras de texto de vários idiomas diferentes e veja como a frequência das letras varia entre os idiomas. Compare seus resultados com as tabelas em http://en.wikipedia.org/wiki/Letter_frequencies.
#
# Solução: http://thinkpython2.com/code/most_frequent.py.

# %%
def most_frequent(str):
  letter_dic = {}
  for letter in str:
    print(letter)
    if letter in letter_dic:
      letter_dic[letter] += 1
    else:
      letter_dic[letter] = 1

  #for i in letter_dic:
  #  print(i, letter_dic)
  ordered = dict(sorted(letter_dic.items(), key=lambda item: item[1], reverse=True))
  print(ordered)

  return 0

most_frequent('paralelepipedo')
# Out:
# p
# a
# r
# a
# l
# e
# l
# e
# p
# i
# p
# e
# d
# o
# {'p': 3, 'e': 3, 'a': 2, 'l': 2, 'r': 1, 'i': 1, 'd': 1, 'o': 1}
# 0

# %%
# versão do autor https://greenteapress.com/thinkpython/code/most_frequent.py
def make_histogram(s):
    """Make a map from letters to number of times they appear in s.

    s: string

    Returns: map from letter to frequency
    """
    hist = {}
    for x in s:
        hist[x] = hist.get(x, 0) + 1
    return hist

def most_frequent(s):
    """Sorts the letters in s in reverse order of frequency.

    s: string

    Returns: list of letters
    """
    hist = make_histogram(s)

    t = []
    for x, freq in hist.items():
        t.append((freq, x))

    t.sort(reverse=True)

    res = []
    for freq, x in t:
        res.append(x)

    return res

most_frequent('paralelepipedo')
# Out:
# ['p', 'e', 'l', 'a', 'r', 'o', 'i', 'd']

# %% [markdown]
# ### Exercício 12.2
#
# Mais anagramas!
#
# 1. Escreva um programa que leia uma lista de palavras de um arquivo (veja “Leitura de listas de palavras”, na página 133) e imprima todos os conjuntos de palavras que são anagramas.
#
# Aqui está um exemplo de como a saída pode parecer:
#
# ```
#         ['deltas', 'desalt', 'lasted', 'salted', 'slated', 'staled']
#         ['retainers', 'ternaries']
#         ['generating', 'greatening']
#         ['resmelts', 'smelters', 'termless']
# ```
#
# Dica: você pode querer construir um dicionário que mapeie uma coleção de letras a uma lista de palavras que podem ser soletradas com essas letras. A pergunta é: como representar a coleção de letras de forma que possa ser usada como uma chave?
#
# 2. Altere o programa anterior para que exiba a lista mais longa de anagramas primeiro, seguido pela segunda mais longa, e assim por diante.
#
# 3. No Scrabble, um “bingo” é quando você joga todas as sete peças na sua estante, junto com uma peça no tabuleiro, para formar uma palavra de oito letras. Que coleção de oito letras forma o maior número possível de bingos? Dica: há sete.
#
# Solução: http://thinkpython2.com/code/anagram_sets.py.

# %%
# ordena as letras de uma palavra
def sort_letters(str):
  str_list = []
  for s in str:
    str_list.append(s)
  
  str_sorted = ''.join(sorted(str_list))
  print(str_sorted)

  return str_sorted

# sort_letters('deltas')

# %%
with open('words.txt') as fin:
    anagram_dict = {}

    for line in fin:
        word = line.strip()
        key = sort_letters(word)
        anagram_dict.setdefault(key, []).append(word)
# Out:
# aa
# aah
# aadeh
# aaghin
# aahs
# aal
# aaiil
# aaiils
# aals
# aaadkrrv
# aaadkrrsv
# aadflorw
# aadelorsvw
# aas
# aaeglosv
# aaeglossv
# aab
# aaabc
# aaabcs
# aabci
# aabck
# aabcsu
# aabcessu
# aabft
# aaabk
# aaabks
# aabelno
# aabelnos
# aabmp
# aabeempr
# aabeemprs
# aabmps
# aabdnno
# aabddenno
# aabdginnno
# aabdemnnnot
# aabdemnnnost
# aabdnnos
# aabs
# aabes
# aabdes
# aabdelsy
# aabeemnst
# aabeemnsst
# aabers
# aaberss
# aabess
# aabhs
# acgiinqru
# aciiinoqstu
# aciiinoqsstu
# aceiiiqstuv
# aciqtu
# aciqstu
# acdeiqttu
# acgiinqttu
# aacinrs
# aacinrss
# acer
# aaceegr
# aaceegrs
# acder
# acers
# acdir
# acdeirr
# acdeirst
# acdeiinr
# acdeiinrs
# acdeiiirst
# acdiirty
# acdilry
# acdeinrss
# acdeeinrsss
# aceiimnors
# aciimnoorsu
# acimnory
# aabcort
# aabcciort
# aabcorst
# acdnoort
# acdnoorst
# acegnor
# acegnors
# aceilnor
# aceilnors
# achilort
# achilorst
# aacimor
# aacilmor
# acimnoor
# accinor
# acmnory
# acmnorsy
# acorss
# acciorst
# acciorsst
# acciort
# acimorst
# acimorsst
# aacelrty
# aacelrsty
# accilry
# accilrsy
# act
# aact
# aabcelt
# acdet
# acint
# aacilnt
# acgint
# acginst
# aaciint
# aaceiint
# aaciinnt
# aaciinnst
# aaciinst
# acciint
# acdeiint
# acdeiinst
# aciimnst
# aciimnsst
# aciimntu
# aciimnstu
# acdiinot
# acdiinost
# acinnot
# acinnost
# acinst
# acinot
# acinost
# aaceittv
# aacdeittv
# aaceisttv
# aacgiinttv
# aaciinottv
# aaciinosttv
# aceitv
# aceiltvy
# aceistv
# aciimstv
# aciimsstv
# aciisttv
# aciissttv
# aceiiisttv
# aciittvy
# acort
# achiorst
# acorst
# acersst
# aceerssst
# acst
# aacltu
# aaceiilsttu
# aacilttuy
# aaaciilnottuz
# aaaciilnosttuz
# aaceiltuz
# aacdeiltuz
# aaceilstuz
# aacgiilntuz
# aaclltuy
# aaacilrtu
# aaceirstu
# aacrtuy
# aacettu
# aacdettu
# aacesttu
# aacginttu
# aacorttu
# aacorsttu
# aacetu
# aceiistu
# acituy
# aaceeltu
# acemnu
# acemnsu
# accenprtuuu
# accenprstuuu
# accinprsttuuu
# accinprssttuuu
# aaccentu
# aaccenstu
# acetu
# aceltuy
# aceensstu
# aceeenssstu
# acertu
# acestu
# acesttu
# acccily
# acly
# aacelty
# aacdelty
# aacelsty
# aacgilnty
# aclsy
# ad
# aadeg
# aadegs
# aaadgil
# aadgio
# aadgios
# aaacdemn
# aaacdemns
# aaacdeimns
# aaacdmny
# aaadmnt
# aaadeilmnst
# aaadlmnty
# aaadmnst
# aadeimst
# aadeimsst
# aadpt
# aaabdeiiilpstt
# aaabdiilptty
# aaabdelpt
# aaadinoptt
# aaadinopstt
# aaddept
# aadeprt
# aadeprst
# aadginpt
# aadinopt
# aadinopst
# aadeiptv
# aadoprt
# aadoprst
# aadpst
# aaadilx
# add
# aabddel
# aaddx
# aaddesx
# addde
# adddely
# addden
# aaddden
# adddens
# adddemnu
# adder
# adders
# abddeil
# acddit
# acdddeit
# acddgiint
# acddiinot
# acddiinost
# acddeiitv
# acddist
# addgin
# addiinot
# aaddiilnot
# aaddiillnoty
# addiinost
# addeiitv
# addeiistv
# addel
# adddel
# addels
# addgiln
# adderss
# aabddeelrss
# adddeerss
# addeersss
# addeginrss
# adderst
# adds
# acddeu
# acdddeu
# acddentu
# aehilorst
# aeegiloors
# aegloory
# aaenortu
# aaceinortu
# aaaceilnortu
# aaaceillnortuy
# aaceinorstu
# aaenorstu
# aeeimnoors
# aemnoory
# aeloors
# aeloorss
# aaceeoprs
# aaeorstt
# aaeorsstt
# aegoru
# aegorsu
# aery
# aeeehstt
# aeeehsstt
# aceehistt
# aaceehillstty
# aceehisstt
# aaeilstv
# aeehrt
# aceehirt
# aeehrst
# aafr
# aafrs
# aadefr
# aadeefr
# aff
# aabeffiiilst
# aabffiilty
# aabeffl
# aabffly
# aaffir
# aaeffir
# aaeffirs
# aaffirs
# acefft
# aaceffinott
# aaceffinostt
# acdeefft
# acdeefflty
# aceeffrt
# aceeffrst
# aceffgint
# aceffgilnty
# aceffinot
# aaceeffinott
# aaceeffilnotty
# aceffinost
# aceffst
# aeeffnrt
# aaceffin
# aacdeffin
# aaceffins
# aacffgiinn
# aaffint
# aaffinst
# aceffhi
# aceffhis
# aadffiitv
# aadffiistv
# aaeffiilt
# aadeffiilt
# aaeffiilst
# aaffgiiilnt
# aaffiiilnot
# aaffiiilnost
# aeffin
# adeffin
# aeffilny
# aeffins
# aeffiiinst
# affiinty
# affimr
# aaffiimnort
# aaffiimnorst
# aaeffiimrtv
# aaeffiilmrtvy
# aaeffiimrstv
# adeffimr
# aeffimrr
# aeffimrrs
# affgiimnr
# affimrs
# affix
# aaffilx
# adeffix
# aeffirx
# aeffirsx
# aeffisx
# aaffiilx
# affgiinx
# aafflstu
# aaefflsstu
# acffilt
# acdeffilt
# acffgiilnt
# acffiilnot
# acffiilnost
# acffilst
# aceefflnu
# aceefflnsu
# aefflntu
# aefflnstu
# afflux
# aefflsux
# adffor
# addeffor
# adffginor
# adffors
# aefforst
# adeefforst
# aeffginorst
# aefforsst
# aaffry
# aadeffry
# aaeffrry
# aaeffrrsy
# aaffginry
# aaffrsy
# affghirt
# adeffghirt
# affgghiinrt
# affghirst
# affnort
# adeffnort
# affginnort
# affnorst
# affinosu
# affinossu
# aafghn
# aafghin
# aafghins
# aafghns
# adefil
# aefir
# aaeflm
# aaflot
# aeflrttu
# afoot
# aefor
# aflou
# aadfir
# aeefrt
# aeefrst
# aefhrs
# afirt
# afirst
# aft
# aefrt
# aeeffilrt
# aeeffilrst
# aaefhmrtt
# aaefhmrstt
# aefnnoort
# aefnnoorst
# aefrst
# aaefrttx
# aefghhortttu
# aefghhorstttu
# aadefrrtw
# aadefrrstw
# afmostt
# aafost
# aafosst
# aag
# aagin
# aaginst
# aacghllo
# aacghllos
# aadgloow
# aadgloosw
# aaagm
# aaagms
# aaeegmt
# aaeegmst
# aacgim
# aagmosu
# aaaegp
# aaagip
# aaegp
# aacegip
# aagr
# aacgir
# aacgirs
# aagrs
# aags
# aaegt
# aaegst
# aaegitz
# aadegitz
# aaegistz
# aaggiintz
# aadgiot
# aaegv
# aaegsv
# aaegz
# aeg
# adeg
# adegly
# adeegnss
# adeeegnsss
# aeeg
# aeggin
# aeggins
# aeeglss
# aegglno
# aceegins
# acegny
# aagilmnru
# aalmrsu
# aalry
# aals
# aaakls
# aaaklss
# aalorst
# aalorsst
# aaelt
# aadelt
# aailnot
# aailnost
# abl
# aabl
# aabcelor
# aabcelors
# aabls
# aaablt
# aaablst
# aablorsst
# aabelorssst
# abdelo
# abdelos
# abeilt
# abceilor
# abceilors
# aabilln
# abciiln
# abiilmns
# abiilmnss
# abilno
# abilnos
# abeilt
# abeilst
# abciilt
# abls
# ablmu
# abelmnu
# abelmnsu
# abilmnu
# abilmnsu
# abelmosu
# abelmossu
# ablmsu
# ablmnruu
# ablmnrsuu
# aacdel
# aacdels
# aacehlst
# aacehlsst
# aaccil
# aaccils
# aacdeil
# aacdeils
# aacdell
# aacdells
# aacdely
# aacdelsy
# aaaclrz
# aaaclrsz
# accehilm
# aaccehillm
# aceehilms
# acehilmst
# acehilmsst
# acehlmy
# acehilmsy
# achlmyy
# acdeiiln
# achlloo
# acchilloo
# acchilloos
# achillmoos
# achillmooss
# achlloos
# acelov
# acdelov
# acelosv
# addeehly
# addeehlsy
# adelr
# aadelmnr
# adeelmnr
# adelrs
# adllo
# aadellos
# aadelloss
# adllos
# adelos
# adeloss
# aaddilnov
# adilnr
# adilnrs
# ael
# aaelorty
# acel
# acels
# aeel
# aefl
# aefls
# aaeglr
# aaeglrs
# aeehlosu
# aeehlossu
# abceilm
# abceilms
# aehlp
# aehlps
# aelrt
# adeelrt
# aeelrrt
# aeelrstt
# aegilnrt
# aellrty
# aeelnrsst
# aeeelnrssst
# aelrst
# aels
# aelnoru
# aeelnoru
# aeelnorsu
# aelnorsu
# aeilnv
# aeilnsv
# aeefilw
# aeeilsvw
# aaeilx
# aaeilsx
# aeilnx
# aeeilnx
# aeeilnsx
# aeilnsx
# aafl
# aafikl
# aafikls
# aaaffll
# aaafflls
# aafilqu
# aafilnqu
# aafilnqsu
# aafilqsu
# aafls
# aafjlor
# aafjlors
# aceflors
# aagl
# aaegl
# aagll
# aaabglor
# aaabglors
# aagls
# aabeglr
# aabcegilr
# aaabcegilllry
# aabeglrs
# aeegilnr
# aeegilnrs
# acdegiil
# acdegiils
# adgil
# adegiiilst
# adgiilty
# agiln
# aaegilnt
# aaegilnst
# agilns
# adgilo
# aeggilloos
# aggllooy
# aglor
# agilmors
# agilmorss
# aghilmort
# aghilmorst
# aglors
# aglmu
# aglmsu
# aails
# aaeilss
# abiil
# abdeiil
# abeiils
# abgiiiln
# abiils
# abeill
# aaddil
# aaddeil
# aaddeils
# aaddils
# aeiln
# aaeegiln
# aaeegilns
# aaeeilnt
# aadeeilnt
# aaeeilnst
# aaegiilnnt
# aaeiilnnot
# aaeiilnnost
# adeeiln
# aeeeiln
# aeeeilns
# aeeilnr
# aeeilnrs
# aegiilnn
# aeiilmns
# aeiilmnss
# aeiilnst
# aeiilnsst
# aeillny
# aeilnor
# aeilnors
# aeilns
# afil
# afilmor
# afils
# aghilt
# adeghilt
# agghiilnt
# aghilst
# agiln
# adegiln
# aegilnr
# aegilnrs
# aggiilnn
# aegilmnnt
# agilnnnoyy
# annosy
# aalnnu
# aallnnuy
# aalnnsu
# aeiinnstu
# ainntuy
# alnnu
# aalnnru
# aaelnntu
# aelnntu
# aelnnstu
# ailnnu
# adellnnu
# agillnnnu
# aelmnnntu
# aelmnnnstu
# aelnnosu
# alnnsu
# alnnsuu
# aelnnssuu
# aano
# aanos
# aadlno
# aadllnoy
# adeno
# adenos
# acdino
# aacdillnoy
# adeinoz
# addeinoz
# adeinosz
# adgiinnoz
# adennoy
# adennosy
# acdinnoy
# ainnot
# adeinnot
# aeinnort
# aeinnorst
# agiinnnot
# aeimnnnott
# aeimnnnostt
# ainnost
# aelno
# aelnos
# aelnoty
# aelnosty
# aaeilmnos
# aalmnoosu
# aalmnoy
# acimno
# aeimno
# aeimnos
# amnoy
# anno
# amnnoy
# aeiimnnosty
# aimnnotyy
# amnnoosuy
# almnnoosuyy
# amnnosy
# aainoops
# aainoopss
# aainop
# aainops
# aainops
# aainopss
# aaknor
# aaknors
# aceinort
# aaeinorx
# aaeinorsx
# aeeinorsx
# aenorxy
# achinort
# aaimnos
# aaimnoss
# acimnos
# aehnort
# aaeimnox
# aaeimnosx
# aceimnox
# aainox
# aainosx
# acinox
# aans
# aaens
# aaenst
# aadenst
# aeeinnrs
# aeeinnrss
# aenorssu
# aenrsw
# aabeelnrsw
# adeenrsw
# aeenrrsw
# aeenrrssw
# aeginnrsw
# aenrssw
# ant
# aant
# aacdint
# aacdinst
# aaent
# aagimnnost
# aagimnnosst
# aaginnostt
# aacgiinnostt
# aaginnosstt
# aaeginnotz
# aadeginnotz
# aaeginnostz
# aaggiinnnotz
# aacgilnt
# aacgilnst
# aaccinrtt
# aanst
# aent
# aaeenrtt
# aaeenrstt
# abeellmntu
# acdeeent
# acddeeent
# acdeeenntt
# acdeeennstt
# acdeeenst
# acdeeginnt
# adent
# aadeentt
# aaddeentt
# aadeenstt
# aadeginntt
# adeent
# aefintx
# aaefintx
# aeefinstx
# aeginnt
# aeelnopt
# aeelnopst
# aaennnt
# aaeennnt
# aaelnnnt
# aaennnst
# aaenpstt
# aaenpsstt
# aeinorrt
# aemnoort
# aemnoorst
# aenst
# aeenptty
# aeenpstty
# aeenrttv
# adeeenrttv
# aeeginnrttv
# aeenrsttv
# aaehilnt
# aceehilnst
# aehilntx
# aehmnt
# adeehmnt
# aaehimnt
# aeghimnnt
# aehmnst
# aehnrt
# aaehlnrt
# adehinrt
# adehinrst
# aehnrst
# aeehnsst
# aehinsst
# ahillnt
# ahillnst
# aadhinot
# adhinot
# aeghilnoost
# aghlnooty
# aacehnrst
# aacehinrtt
# aacehinrstt
# aahnrtx
# adhinooprt
# aacghillnoooprt
# aghilnoooprstt
# aghilnoooprsstt
# aghlnoooprty
# aint
# aabiinnoortt
# aaaccdeiimnt
# aaadiiiimnnnorsttt
# aaeggiinnorsst
# aaeeggiinrsstv
# aaacfiinrrtt
# aaeiilnnt
# aaacchiinnrt
# aaachiinnrstt
# aaaeiinnnnottx
# aaadehiinprtt
# aainrt
# aaprt
# aadehiprt
# aadehiprst
# aaceiptt
# aacehiptt
# aaacehillptty
# aaehipst
# aahpty
# aaeiptt
# aaeipstt
# aep
# aaekp
# adep
# aeekp
# aeeiklp
# aepr
# acepru
# aceprsu
# aeeinprt
# aeeinprst
# aeeiprs
# aefiiprt
# aefiiprst
# aeprs
# aeeprrtu
# aeeprrstu
# aepry
# aeps
# aaeeilpst
# aaelpty
# aepx
# aeepsx
# aaaghip
# aaaghips
# aaehinpt
# aaehinpst
# aaahips
# aaachips
# aaachipss
# aaahipss
# aachips
# aachipss
# aaehilp
# aaehilnp
# aehilnop
# aeehpss
# aehipss
# acehipt
# adhip
# adehips
# aadhiinp
# aadhiinps
# adhips
# ahips
# aaehlopt
# aaehlopst
# aahinop
# aahinops
# achinop
# achinops
# aehioprs
# adehioprs
# aehioprss
# aghiinoprs
# ahimoprs
# ahimoprss
# ahioprst
# achiioprst
# ahioprsst
# aehioprz
# adehioprz
# aehioprsz
# aghiinoprz
# achiopt
# aacdhiioprs
# aahhpt
# aaehhpt
# ahhopstu
# aehillpsy
# ahllpyy
# aainp
# aaaiinpr
# aaaiinprs
# aaeiiprs
# aaiiprst
# aaiiprsst
# aaipry
# aacilp
# aacillpy
# aceips
# aciilpu
# acilpsuu
# aceeip
# aaaiimnp
# aaaiimnps
# aginp
# aegiiloops
# agiloopy
# ahips
# ahilpsy
# aaailps
# aaailpss
# aacilpst
# aelnpty
# aeilpt
# aeilpst
# aciilpt
# ablmop
# ablmops
# aaenp
# aaelnp
# aaenps
# aceinp
# aaenop
# aaelnop
# aaenops
# aceinop
# aaceloppsy
# aaceloppssy
# aacciloppty
# aaaccilloppty
# aacoppr
# aaceiopprs
# aacopprs
# aacoppry
# aceoopp
# aceoopps
# accioopp
# aceinopr
# aachoppry
# aachloppry
# aadlop
# adeoopss
# adioopss
# adoopsu
# aacgimop
# aaegimops
# aagmopy
# aaeglop
# aaegnop
# aeegop
# aeegops
# acegiop
# alloop
# alloops
# agloop
# aaglloop
# acegiloopt
# aacegillloopty
# aagiloop
# aaegiloop
# aagiloops
# aegiloops
# agiloopst
# aegiloopz
# adegiloopz
# aegiloopsz
# aggiilnoopz
# agloops
# aegloopu
# aegloopsu
# agloopy
# aelnopu
# aelnopsu
# acimopt
# acimopst
# aeimopsx
# aiimopsx
# aeghoppy
# aeghoppsy
# acceiloppt
# aeeiloppsx
# aeloppxy
# aoprt
# aaceiopsst
# aacopsty
# aaeiopssst
# aaopssty
# aaeopstt
# aaeopsstt
# ailopst
# ailopsst
# aelopst
# aelopsst
# aehiloppsst
# aciloopst
# aehoopprst
# aehoopprsst
# aaceehioprst
# aacehoprty
# aceehopt
# aceehopst
# aeghmopt
# aeghmopst
# aehmopt
# aehmopst
# aalpp
# aallpp
# aadellpp
# aagillnpp
# aallpps
# aalpps
# aaaegnpp
# aaaegnpps
# aaapprt
# aaapprst
# aaapprstu
# aaaepprsstu
# aaelppr
# aadeelppr
# aaegilnppr
# aadeellppr
# aaegillnppr
# aaelpprs
# aaimnooz
# aaimnoosz
# demooz
# eeimoorstz
# emoortyz
# gimnooz
# hmoooprz
# hmoooprsz
# moosz
# nooz
# alnooz
# enooossz
# inooossz
# cinoootz
# noosz
# ehiloopz
# ehiloopsz
# ehooptyz
# ehoopstyz
# oosz
# emooprsz
# emooprssz
# eoooprsz
# eoooprssz
# cimoootz
# eimooostz
# moootyz
# iorz
# ilorz
# aillorz
# aillorsz
# eillorz
# eillorsz
# illoorz
# illoorsz
# ilorsz
# eorstz
# eorsstz
# aeouvz
# aeosuvz
# dnosuz
# eiowz
# aiosyz
# aiossyz
# cchiinuz
# cchiinsuz
# abceikwz
# abceikswz
# agmoyz
# agmosyz
# aagmotyz
# egosyz
# egossyz
# giossyz
# egiiosstyz
# giostyyz
# egotyz
# eegnotyz
# eegnostyz
# egostyz
# cgiotyz
# aemsyz
# aemssyz
# emyz
# emsyz
# egmnoyz
# eegmnoyz
# eegmnosyz
# egmnosyz
# egilmoosyz
# glmooyyz
# emossyz
# imossyz
# cimotyz
# egimrsuyz
# gmruyyz

# %%
print(sort_letters('deltas'))
print('adelst', anagram_dict['adelst'])
# Out:
# adelst
# adelst
# adelst ['deltas', 'desalt', 'lasted', 'salted', 'slated', 'staled']

# %%
# remover do dicionario se não houver anagramas
def as_list(v):
    return v if isinstance(v, (list, tuple, set)) else [v]

multi_anagram_dict = {}
multi_anagram_dict = [key for key, value in anagram_dict.items() if len(as_list(value)) > 1]

# %%
multi_anagram_dict
# Out:
# ['aah',
#  'aadeh',
#  'aal',
#  'aals',
#  'aab',
#  'aaabcs',
#  'aabs',
#  'aabeemnst',
#  'aabgins',
#  'aaberst',
#  'aabort',
#  'aaborst',
#  'abbe',
#  'abbes',
#  'aabem',
#  'abde',
#  'abeklmos',
#  'abet',
#  'abest',
#  'aabelstt',
#  'abeertt',
#  'abeerstt',
#  'abeortt',
#  'abeorstt',
#  'abdehorr',
#  'abehorrr',
#  'abehorrrs',
#  'abghinorr',
#  'abdei',
#  'abddei',
#  'abdeirs',
#  'abdeis',
#  'aabdelt',
#  'aabgilnt',
#  'abel',
#  'abelr',
#  'abels',
#  'abelst',
#  'abilns',
#  'abelntu',
#  'abelnstu',
#  'abilnotu',
#  'abilnostu',
#  'abhmo',
#  'abhmos',
#  'abo',
#  'aabdor',
#  'abdeo',
#  'abdeos',
#  'abort',
#  'abdeort',
#  'abeorrt',
#  'abeorrst',
#  'abginort',
#  'aborst',
#  'abos',
#  'abdnosu',
#  'aabcert',
#  'aabcdeert',
#  'aabceginrt',
#  'aabcerst',
#  'abdegir',
#  'abddegir',
#  'abdegirs',
#  'abdggiinr',
#  'abirs',
#  'abceiss',
#  'abbeorrs',
#  'abbeorrss',
#  'abinooprst',
#  'aabcerrstt',
#  'abesu',
#  'abdesu',
#  'abersu',
#  'aberssu',
#  'abtu',
#  'abstu',
#  'aby',
#  'abdey',
#  'abginy',
#  'absy',
#  'abssy',
#  'aacdir',
#  'aaacdinr',
#  'aaacdinrs',
#  'aacdirs',
#  'aaceinr',
#  'aaceinrs',
#  'acceeprt',
#  'acceeprst',
#  'accost',
#  'acceortu',
#  'acceorstu',
#  'aacclru',
#  'aacclrsu',
#  'accersu',
#  'acde',
#  'abcer',
#  'abceerr',
#  'abcceir',
#  'aceorsu',
#  'acers',
#  'aces',
#  'aacelst',
#  'aceenost',
#  'aceeost',
#  'aceh',
#  'aceehns',
#  'acehs',
#  'acehir',
#  'acehist',
#  'aceehirv',
#  'aceehirsv',
#  'aachmort',
#  'aachmorst',
#  'acdi',
#  'acdis',
#  'aacdeeirt',
#  'aacinr',
#  'acem',
#  'acems',
#  'acen',
#  'acden',
#  'acens',
#  'acdeno',
#  'acdenos',
#  'aceinost',
#  'acciinot',
#  'acnor',
#  'acnors',
#  'aacinrs',
#  'acer',
#  'aaceegrs',
#  'acder',
#  'acdir',
#  'acdeirr',
#  'aceilnor',
#  'aceilnors',
#  'acimorsst',
#  'act',
#  'acdet',
#  'acint',
#  'acginst',
#  'acdeiint',
#  'acdeiinst',
#  'acdiinot',
#  'acinnot',
#  'acinnost',
#  'acinst',
#  'acinot',
#  'acinost',
#  'aaceittv',
#  'aacdeittv',
#  'aaceisttv',
#  'aacgiinttv',
#  'acort',
#  'achiorst',
#  'acorst',
#  'acersst',
#  'acst',
#  'aacorttu',
#  'aacorsttu',
#  'acertu',
#  'acestu',
#  'acesttu',
#  'acly',
#  'aclsy',
#  'ad',
#  'aadeimst',
#  'aadeprt',
#  'aadeprst',
#  'add',
#  'adder',
#  'adders',
#  'acddit',
#  'acddist',
#  'addel',
#  'adddel',
#  'addels',
#  'adds',
#  'acddersu',
#  'adeem',
#  'adeems',
#  'adeiinst',
#  'adept',
#  'adeeprt',
#  'adepst',
#  'adeehr',
#  'addeehr',
#  'addeehnr',
#  'adeehnrt',
#  'adeehnrst',
#  'adeehrr',
#  'adeehrs',
#  'adit',
#  'adist',
#  'adejrstu',
#  'adejrsstu',
#  'aadmn',
#  'ademn',
#  'adeimrr',
#  'adeimrrs',
#  'adeimrs',
#  'adimst',
#  'adeoprt',
#  'adeoprst',
#  'adeor',
#  'addeor',
#  'adeorr',
#  'adeorrs',
#  'adeors',
#  'adnor',
#  'adenorr',
#  'adenorrs',
#  'adnors',
#  'ados',
#  'adilorty',
#  'adeinorsst',
#  'ads',
#  'abdors',
#  'abddeors',
#  'abdginors',
#  'aadlortu',
#  'aadlorstu',
#  'adstu',
#  'aacdensv',
#  'abderv',
#  'adeersv',
#  'adeeirstv',
#  'aderstv',
#  'adeisv',
#  'adeissv',
#  'aacdimny',
#  'adez',
#  'adesz',
#  'adees',
#  'aeensu',
#  'aaeilr',
#  'aeeirs',
#  'aeeirst',
#  'acdeortu',
#  'acdeorstu',
#  'aeegiloors',
#  'aegloory',
#  'aeloors',
#  'aeloorss',
#  'aery',
#  'aaeilstv',
#  'aeehrt',
#  'aceehirt',
#  'aeehrst',
#  'aaffir',
#  'aaffirs',
#  'aeffimrr',
#  'aeffimrrs',
#  'aeffirx',
#  'adefil',
#  'aefir',
#  'aeefrt',
#  'aeefrst',
#  'aft',
#  'aefrst',
#  'aagr',
#  'aagrs',
#  'aags',
#  'aaegsv',
#  'aeg',
#  'adeg',
#  'aeegns',
#  'aeeginss',
#  'aaegilnt',
#  'aeeginrst',
#  'aegr',
#  'aegrs',
#  'aegs',
#  'aeggr',
#  'aeggrs',
#  'aadeggr',
#  'aadeggrs',
#  'aeggrss',
#  'agin',
#  'aeginnr',
#  'aeginnrs',
#  'agist',
#  'agisst',
#  'aaeglr',
#  'aeegl',
#  'aaegimnt',
#  'aegmnno',
#  'acginost',
#  'acginosst',
#  'ago',
#  'aaglno',
#  'aegno',
#  'aegnos',
#  'aeginos',
#  'adeginos',
#  'aginost',
#  'aeegr',
#  'adeegr',
#  'aeegrs',
#  'acegirst',
#  'aegsu',
#  'ah',
#  'aehm',
#  'aehors',
#  'adei',
#  'adeir',
#  'adeirs',
#  'adeis',
#  'adeimn',
#  'adis',
#  'aegilt',
#  'aegilst',
#  'aegirt',
#  'aegirst',
#  'adeil',
#  'aeilnor',
#  'aeilnors',
#  'agiiln',
#  'aeilmnt',
#  'aeilmnst',
#  'ails',
#  'aim',
#  'adeim',
#  'aeimr',
#  'aeimrs',
#  'afilmu',
#  'aeilmss',
#  'aims',
#  'ain',
#  'ains',
#  'aeillnss',
#  'aceirrsw',
#  'aeirst',
#  'agiinrs',
#  'aeilrss',
#  'aaimnr',
#  'aeimnr',
#  'ainr',
#  'ainrs',
#  'aioprsst',
#  'airs',
#  'adeirt',
#  'airst',
#  'adeils',
#  'aeilss',
#  'aist',
#  'aeirsv',
#  'aajr',
#  'aeekns',
#  'aikn',
#  'aaadelms',
#  'aaln',
#  'aadlns',
#  'aagln',
#  'aalns',
#  'aalnt',
#  'aalnst',
#  'aallny',
#  'aallnsy',
#  'aalmr',
#  'aagilmnr',
#  'aalmrs',
#  'abl',
#  'aabl',
#  'aabls',
#  'aaablt',
#  'aaablst',
#  'abdelo',
#  'abeilt',
#  'abceilor',
#  'abceilors',
#  'abeilst',
#  'abls',
#  'abelmnsu',
#  'ablmnruu',
#  'ablmnrsuu',
#  'aacdels',
#  'aaccil',
#  'aaccils',
#  'accehilm',
#  'acehilmsy',
#  'acelov',
#  'acelosv',
#  'adelr',
#  'adelrs',
#  'adllo',
#  'adllos',
#  'adeloss',
#  'ael',
#  'acel',
#  'acels',
#  'aefl',
#  'aefls',
#  'aaeglrs',
#  'abceilm',
#  'aelrt',
#  'adeelrt',
#  'aeelrrt',
#  'aegilnrt',
#  'aelrst',
#  'aels',
#  'aelnorsu',
#  'aeilnv',
#  'aeilnsv',
#  'aeilnx',
#  'aagl',
#  'aaegl',
#  'aagls',
#  'aeegilnrs',
#  'agiln',
#  'agilns',
#  'adgilo',
#  'aglor',
#  'aghilmort',
#  'aghilmorst',
#  'aglors',
#  'aglmu',
#  'aglmsu',
#  'abeiils',
#  'abeill',
#  'aeiln',
#  'adeeiln',
#  'aeiilnst',
#  'aeilns',
#  'afil',
#  'afils',
#  'adeghilt',
#  'adegiln',
#  'aegilnr',
#  'aegilnrs',
#  'aegilmnnt',
#  'adeiln',
#  'aeilnr',
#  'aeilnrs',
#  'agiilnn',
#  'adeilp',
#  'adeilps',
#  'ailst',
#  'ailt',
#  'adeilnu',
#  'aaeiklls',
#  'aaellry',
#  'aeegillrs',
#  'aegllry',
#  'aaceilln',
#  'aaceillns',
#  'aadillo',
#  'aegllno',
#  'aegllnos',
#  'allot',
#  'allost',
#  'adellott',
#  'agillnott',
#  'aellorv',
#  'aellorsv',
#  'allosw',
#  'alloy',
#  'alls',
#  'adeellss',
#  'adellu',
#  'adellsu',
#  'aellru',
#  'aellrsu',
#  'aalm',
#  'aahlm',
#  'aahlms',
#  'aalms',
#  'aelm',
#  'aehlm',
#  'aelms',
#  'adlmno',
#  'adlmnos',
#  'almost',
#  'alms',
#  'acelmu',
#  'acelmsu',
#  'adelmu',
#  'acilno',
#  'aelo',
#  'aflot',
#  'aelno',
#  'aglno',
#  'afloo',
#  'alow',
#  'alp',
#  'ahilopss',
#  'aeilnp',
#  'aeilnps',
#  'aiilnpst',
#  'aiilnpsst',
#  'alps',
#  'aeiklss',
#  'alos',
#  'alt',
#  'aalrt',
#  'aalrst',
#  'aaelnrtt',
#  'aaelnrstt',
#  'aaceilnorstt',
#  'aeelrrst',
#  'ahlot',
#  'adeilttu',
#  'adeilsttu',
#  'alot',
#  'alost',
#  'ailmrstu',
#  'ailmrsstu',
#  'ailrsttu',
#  'ailrssttu',
#  'alst',
#  'almu',
#  'ailmnu',
#  'aalmnu',
#  'almsu',
#  'aeilnstu',
#  'almssuy',
#  'am',
#  'aaimn',
#  'aamss',
#  'aagimnss',
#  'abeemrs',
#  'abemr',
#  'abemrs',
#  'abeimrtv',
#  'abelm',
#  'abdelm',
#  'abelmr',
#  'abelmrs',
#  'abelms',
#  'abgilmn',
#  'abemnos',
#  'abmos',
#  'abmry',
#  'aeemr',
#  'aeemrs',
#  'acelmnor',
#  'acelmnors',
#  'aemn',
#  'aabeelmn',
#  'adeemnr',
#  'adeemnrs',
#  'ademns',
#  'aeimnty',
#  'aemns',
#  'aemnt',
#  'aaeimnt',
#  'aaeimnst',
#  'aemnst',
#  'aceemr',
#  'acdeemr',
#  'aceemrr',
#  'aceemrrs',
#  'aceemrs',
#  'acegimnr',
#  'aceims',
#  'adim',
#  'adeims',
#  'adiimn',
#  'adiimns',
#  'adims',
#  'agimo',
#  'aimn',
#  'aeimn',
#  'aeimns',
#  'aimns',
#  'aimr',
#  'aimrs',
#  'aimss',
#  'aeimosst',
#  'aeilmort',
#  'aeilmorst',
#  'aeemmrt',
#  'aeemmrst',
#  'aeimmn',
#  'aeimmns',
#  'aaeimns',
#  'aceimns',
#  'aceimnst',
#  'adeeimnst',
#  'acimn',
#  'aimnno',
#  'aimnnos',
#  'aeimnost',
#  'akmo',
#  'akmos',
#  'agmno',
#  'aemoorstt',
#  'adeimorst',
#  'aeimortz',
#  'aeimorstz',
#  'amnotu',
#  'amnostu',
#  'amorsu',
#  'amp',
#  'aelmp',
#  'aelmpr',
#  'almpy',
#  'amps',
#  'aacmrt',
#  'aacmrst',
#  'aelmtu',
#  'aelmstu',
#  'ademsu',
#  'aemrssu',
#  'aemssu',
#  'an',
#  'aademn',
#  'aademns',
#  'aaceilmn',
#  'aaceilmns',
#  'aaceilnt',
#  'aaceilnst',
#  'aacegilns',
#  'aaenpst',
#  'aaenpsst',
#  'aacchinr',
#  'aachimnrs',
#  'aans',
#  'acenorst',
#  'aceeinrsst',
#  'achnor',
#  'achnors',
#  'achinnsu',
#  'aceeinnrt',
#  'aceinnst',
#  'acnno',
#  'acennos',
#  'acenrss',
#  'adns',
#  'aen',
#  'aaenr',
#  'aaenrs',
#  'adeeln',
#  'aegilnn',
#  'aceimn',
#  'aaeginrs',
#  'aens',
#  'aeinrst',
#  'aenrsstu',
#  'aehlnot',
#  'aehlnost',
#  'aenw',
#  'aagns',
#  'aegln',
#  'acegiln',
#  'aeglns',
#  'aeglnsu',
#  'aegnr',
#  'adeegnr',
#  'aegginnr',
#  'aegnrs',
#  'adegln',
#  'aeglnr',
#  'aggilnns',
#  'aagnor',
#  'aeginrr',
#  'aeginrst',
#  'agnry',
#  'agnst',
#  'agnsst',
#  'aeginnu',
#  'ailn',
#  'ailns',
#  'aailmn',
#  'aailmns',
#  'aaimns',
#  'aaeimnrt',
#  'aaeimnrst',
#  'aiimns',
#  'aiimnst',
#  'ainnos',
#  'aeinss',
#  'aeeinstt',
#  'aeeinsstt',
#  'ahkn',
#  'ahkns',
#  'aeklnst',
#  'aaegln',
#  'aaeglns',
#  'aann',
#  'aanns',
#  'adeilnn',
#  'adeilnns',
#  'adennoy',
#  'aeiinnstu',
#  'ailnnu',
#  'ainnot',
#  'adeinnot',
#  'aeinnort',
#  'aeinnorst',
#  'ainnost',
#  'aelnos',
#  'acimno',
#  'anno',
#  'aainops',
#  'aainopss',
#  'aceinort',
#  'acimnos',
#  'acinox',
#  'aenorssu',
#  'aenrsw',
#  'aenrssw',
#  'ant',
#  'aaginnostt',
#  'aaginnosstt',
#  'aent',
#  'aeginnt',
#  'aenst',
#  'aehmnt',
#  'aaehimnt',
#  'aehmnst',
#  'aehnrt',
#  'adehinrst',
#  'aehnrst',
#  'aehinsst',
#  'aeghilnoost',
#  'aint',
#  'aainrst',
#  'aciknt',
#  'aciknst',
#  'adeinott',
#  'adeinostt',
#  'aacfiimnsst',
#  'aeginnst',
#  'agilnost',
#  'aeiimnnost',
#  'aimnnoty',
#  'aiimnooqsttu',
#  'aginnst',
#  'adeinopst',
#  'aceiinprtty',
#  'aadeinqttu',
#  'aeinqtu',
#  'aeinqrtu',
#  'ainst',
#  'aaeinrst',
#  'aelnrt',
#  'aelnrst',
#  'aanrt',
#  'aalnrt',
#  'aenrst',
#  'anst',
#  'aeinrssu',
#  'aainrsu',
#  'acinru',
#  'anorsuu',
#  'aenssu',
#  'ailnv',
#  'ailnsv',
#  'any',
#  'aiorst',
#  'aiorsst',
#  'aaceiptt',
#  'aep',
#  'aeeiklp',
#  'aepr',
#  'aceprsu',
#  'aeprs',
#  'aepry',
#  'aeps',
#  'aehilnop',
#  'aeehpss',
#  'acehipt',
#  'adehips',
#  'ahips',
#  'ahimoprs',
#  'aaipry',
#  'aceips',
#  'aacilpst',
#  'aelnpty',
#  'aeilpst',
#  'aaenp',
#  'aaenps',
#  'aceinopr',
#  'acimopt',
#  'ailopst',
#  'ailopsst',
#  'aelopst',
#  'aalpp',
#  'aallpp',
#  'aaenpprt',
#  'aaegilnpp',
#  'aelpp',
#  'aelpps',
#  'adenpp',
#  'adenpps',
#  'aadeipprs',
#  'aeipprs',
#  'aelppsu',
#  'acioprt',
#  'acioprst',
#  'adenopr',
#  'anoprs',
#  'aepss',
#  'aipss',
#  'apt',
#  'aeprt',
#  'alpty',
#  'aenpsst',
#  'aeenpssst',
#  'aeiilnqu',
#  'abeirrt',
#  'abeirrst',
#  'abdeorr',
#  'aberstu',
#  'acr',
#  'aacdginr',
#  'aacdginrs',
#  'achr',
#  'aachimrs',
#  'aachirst',
#  'aachirsst',
#  'acdehr',
#  'acehrrs',
#  'acehrs',
#  'achilrs',
#  'acehinrs',
#  'acghinr',
#  'acghinrs',
#  'acginr',
#  'acdekr',
#  'acgiknr',
#  'acor',
#  'acrs',
#  'acrsu',
#  'acerssu',
#  'abder',
#  'abders',
#  'acdeeinrs',
#  'adenrt',
#  'aer',
#  'aceir',
#  'aers',
#  'aeert',
#  'aeerst',
#  'afr',
#  'aaglr',
#  'aaglrs',
#  'aegnrt',
#  'aceginrt',
#  'aegnrst',
#  'aegmnrtu',
#  'aegmnrstu',
#  'agilr',
#  'agilrs',
#  'aeglr',
#  'adeglr',
#  'aeglrs',
#  'aggilnr',
#  'agnor',
#  'agnors',
#  'agort',
#  'agorst',
#  'aegru',
#  'aegrsu',
#  'agrsu',
#  'aegrssu',
#  'aair',
#  'aairs',
#  'adir',
#  'adeirr',
#  'adeirst',
#  'adeinrss',
#  'aeilrs',
#  'aaeirstt',
#  'aeeirtt',
#  'aeeirstt',
#  'ailr',
#  'adeilr',
#  'ailrs',
#  'aeirs',
#  'aeinrs',
#  'aeirss',
#  'aairst',
#  'aaeirst',
#  'aairsst',
#  'akrs',
#  'aelrs',
#  'amr',
#  'ademr',
#  'aemrr',
#  'aemrrs',
#  'aemrt',
#  'aemrst',
#  'aflmru',
#  'aflmrsu',
#  'agimnr',
#  'agimnrs',
#  'aelmrt',
#  'aelmrst',
#  'aeimorrs',
#  'aacimnor',
#  'aacimnors',
#  'aimprt',
#  'aimprst',
#  'aemrrst',
#  'amrs',
#  'anoortt',
#  'anoorstt',
#  'adior',
#  'adiors',
#  'ainort',
#  'adeinort',
#  'agiinnort',
#  'ainorst',
#  'anorty',
#  'aenprt',
#  'aenprst',
#  'aerrst',
#  'adeerrst',
#  'aeerrrst',
#  'aeerrrsst',
#  'aeginrrst',
#  'aerrsst',
#  'airrs',
#  'aeirrss',
#  'aeirrv',
#  'aeirrsv',
#  'aaborrs',
#  'aagnorrt',
#  'aorrwy',
#  'ars',
#  'aaeenrst',
#  'aaeenrsst',
#  'aceinrs',
#  'aceinrss',
#  'adeeinrss',
#  'aeeinrst',
#  'aeeinrsst',
#  'aenors',
#  'aerss',
#  'ahinrs',
#  'ahinrss',
#  'ainors',
#  'airss',
#  'anors',
#  'anorss',
#  'art',
#  'aceilrt',
#  'acdeilrt',
#  'aceilrst',
#  'aeirrt',
#  'aeirstt',
#  'aeinrsst',
#  'aainrsst',
#  'airstt',
#  'aeirsstt',
#  'airsstt',
#  'aelrsst',
#  'arst',
#  'arty',
#  'amru',
#  'amrsu',
#  'aalrv',
#  'aorsv',
#  'acdens',
#  'acdeenrs',
#  'acdeenrss',
#  'aceinnoss',
#  'acenst',
#  'acensst',
#  'aaceinrst',
#  'aaceinrsst',
#  'aceisst',
#  'acciist',
#  'acost',
#  'acosst',
#  'abceirs',
#  'abcdeirs',
#  'acssu',
#  'aeipsss',
#  'aceipst',
#  'ahs',
#  'adehs',
#  'aehns',
#  'aehss',
#  'aehlrs',
#  'aeghilnrs',
#  'aehlrss',
#  'aehlsss',
#  'aahmns',
#  'ahsy',
#  'adeiss',
#  'aks',
#  'aaknst',
#  'aekrs',
#  'aekrss',
#  'aeksw',
#  'agikns',
#  'agiknss',
#  'aeelps',
#  'aps',
#  'acepst',
#  'aenps',
#  'aenpss',
#  'aaeeprst',
#  'aadeeprst',
#  'aaeeprsst',
#  ...]

# %%
print(sort_letters('deltas'))
print('aal', anagram_dict['aal'])
# Out:
# adelst
# adelst
# aal ['aal', 'ala']

# %%
i = 0
for key in anagram_dict:
    if i < 20:
      print(key, anagram_dict[key])
      i = i + 1
# Out:
# aa ['aa']
# aah ['aah', 'aha']
# aadeh ['aahed', 'ahead']
# aaghin ['aahing']
# aahs ['aahs']
# aal ['aal', 'ala']
# aaiil ['aalii']
# aaiils ['aaliis']
# aals ['aals', 'alas']
# aaadkrrv ['aardvark']
# aaadkrrsv ['aardvarks']
# aadflorw ['aardwolf']
# aadelorsvw ['aardwolves']
# aas ['aas']
# aaeglosv ['aasvogel']
# aaeglossv ['aasvogels']
# aab ['aba', 'baa']
# aaabc ['abaca']
# aaabcs ['abacas', 'casaba']
# aabci ['abaci']

# %%
def print_anagram_sets_in_order(dict):
    # make a list of (length, word pairs)
    list_anagrams = []
    for v in dict.values():
        if len(v) > 1:
            list_anagrams.append((len(v), v))

    # sort in ascending order of length
    list_anagrams.sort()

    # print the sorted list
    for x in list_anagrams:
        print(x)

print_anagram_sets_in_order(anagram_dict)
# Out:
# (2, ['aah', 'aha'])
# (2, ['aahed', 'ahead'])
# (2, ['aal', 'ala'])
# (2, ['aals', 'alas'])
# (2, ['aba', 'baa'])
# (2, ['abacas', 'casaba'])
# (2, ['abas', 'baas'])
# (2, ['abasement', 'entamebas'])
# (2, ['abasing', 'bisnaga'])
# (2, ['abaters', 'abreast'])
# (2, ['abator', 'rabato'])
# (2, ['abators', 'rabatos'])
# (2, ['abbe', 'babe'])
# (2, ['abbes', 'babes'])
# (2, ['abeam', 'ameba'])
# (2, ['abelmosk', 'smokable'])
# (2, ['abetter', 'beretta'])
# (2, ['abetters', 'berettas'])
# (2, ['abettor', 'taboret'])
# (2, ['abettors', 'taborets'])
# (2, ['abhorred', 'harbored'])
# (2, ['abhorrer', 'harborer'])
# (2, ['abhorrers', 'harborers'])
# (2, ['abhorring', 'harboring'])
# (2, ['abide', 'abied'])
# (2, ['abided', 'baddie'])
# (2, ['abides', 'biased'])
# (2, ['ablated', 'datable'])
# (2, ['ablating', 'bangtail'])
# (2, ['ablins', 'blains'])
# (2, ['abluent', 'tunable'])
# (2, ['abluents', 'unstable'])
# (2, ['ablution', 'abutilon'])
# (2, ['ablutions', 'abutilons'])
# (2, ['abmho', 'abohm'])
# (2, ['abmhos', 'abohms'])
# (2, ['abo', 'boa'])
# (2, ['aboard', 'abroad'])
# (2, ['abode', 'adobe'])
# (2, ['abodes', 'adobes'])
# (2, ['aborter', 'taborer'])
# (2, ['aborters', 'taborers'])
# (2, ['aborting', 'taboring'])
# (2, ['abos', 'boas'])
# (2, ['abounds', 'bausond'])
# (2, ['abreacted', 'acerbated'])
# (2, ['abreacting', 'acerbating'])
# (2, ['abridge', 'brigade'])
# (2, ['abridged', 'brigaded'])
# (2, ['abridges', 'brigades'])
# (2, ['abridging', 'brigading'])
# (2, ['abris', 'sabir'])
# (2, ['absorber', 'reabsorb'])
# (2, ['absorbers', 'reabsorbs'])
# (2, ['absorption', 'probations'])
# (2, ['abstracter', 'reabstract'])
# (2, ['abuse', 'beaus'])
# (2, ['abused', 'daubes'])
# (2, ['abuser', 'bursae'])
# (2, ['aby', 'bay'])
# (2, ['abying', 'baying'])
# (2, ['abys', 'bays'])
# (2, ['abyss', 'bassy'])
# (2, ['acarid', 'cardia'])
# (2, ['acaridan', 'arcadian'])
# (2, ['acaridans', 'arcadians'])
# (2, ['acarine', 'carinae'])
# (2, ['accepter', 'reaccept'])
# (2, ['accepters', 'reaccepts'])
# (2, ['accost', 'coacts'])
# (2, ['accouter', 'accoutre'])
# (2, ['accouters', 'accoutres'])
# (2, ['accrual', 'caracul'])
# (2, ['accrues', 'accuser'])
# (2, ['acerber', 'cerebra'])
# (2, ['acerbic', 'breccia'])
# (2, ['acerous', 'carouse'])
# (2, ['aces', 'case'])
# (2, ['acetals', 'lactase'])
# (2, ['acetones', 'notecase'])
# (2, ['acetose', 'coatees'])
# (2, ['ache', 'each'])
# (2, ['achenes', 'enchase'])
# (2, ['aches', 'chase'])
# (2, ['achier', 'cahier'])
# (2, ['achiest', 'aitches'])
# (2, ['achiever', 'chivaree'])
# (2, ['achievers', 'chivarees'])
# (2, ['achromat', 'trachoma'])
# (2, ['achromats', 'trachomas'])
# (2, ['acierated', 'eradicate'])
# (2, ['acne', 'cane'])
# (2, ['acnodes', 'deacons'])
# (2, ['aconitic', 'cationic'])
# (2, ['acreages', 'gearcase'])
# (2, ['acrider', 'carried'])
# (2, ['acrolein', 'colinear'])
# (2, ['acroleins', 'censorial'])
# (2, ['acrotisms', 'ostracism'])
# (2, ['act', 'cat'])
# (2, ['acted', 'cadet'])
# (2, ['actin', 'antic'])
# (2, ['actings', 'casting'])
# (2, ['actinides', 'indicates'])
# (2, ['actinoid', 'diatonic'])
# (2, ['actinon', 'contain'])
# (2, ['activate', 'cavitate'])
# (2, ['activated', 'cavitated'])
# (2, ['activates', 'cavitates'])
# (2, ['activating', 'cavitating'])
# (2, ['actor', 'taroc'])
# (2, ['actuator', 'autocrat'])
# (2, ['actuators', 'autocrats'])
# (2, ['acuter', 'curate'])
# (2, ['acutes', 'cuesta'])
# (2, ['acutest', 'scutate'])
# (2, ['ad', 'da'])
# (2, ['adamsite', 'diastema'])
# (2, ['adapter', 'readapt'])
# (2, ['adapters', 'readapts'])
# (2, ['add', 'dad'])
# (2, ['addict', 'didact'])
# (2, ['addicts', 'didacts'])
# (2, ['addled', 'daddle'])
# (2, ['addles', 'saddle'])
# (2, ['adds', 'dads'])
# (2, ['adducers', 'crusaded'])
# (2, ['adeem', 'edema'])
# (2, ['adenitis', 'dainties'])
# (2, ['adepts', 'pasted'])
# (2, ['adhere', 'header'])
# (2, ['adhered', 'redhead'])
# (2, ['adherend', 'hardened'])
# (2, ['adherent', 'neatherd'])
# (2, ['adherents', 'neatherds'])
# (2, ['adherer', 'reheard'])
# (2, ['adit', 'dita'])
# (2, ['adjuster', 'readjust'])
# (2, ['adjusters', 'readjusts'])
# (2, ['adman', 'daman'])
# (2, ['admirer', 'married'])
# (2, ['admits', 'amidst'])
# (2, ['adopter', 'readopt'])
# (2, ['adored', 'deodar'])
# (2, ['adorer', 'roared'])
# (2, ['adorers', 'drosera'])
# (2, ['adorn', 'radon'])
# (2, ['adorner', 'readorn'])
# (2, ['adorners', 'readorns'])
# (2, ['adorns', 'radons'])
# (2, ['ados', 'soda'])
# (2, ['adroitness', 'intradoses'])
# (2, ['ads', 'sad'])
# (2, ['adsorbed', 'roadbeds'])
# (2, ['adsorbing', 'boardings'])
# (2, ['adulator', 'laudator'])
# (2, ['adulators', 'laudators'])
# (2, ['adust', 'dauts'])
# (2, ['advances', 'canvased'])
# (2, ['adverb', 'braved'])
# (2, ['adverse', 'evaders'])
# (2, ['advertise', 'derivates'])
# (2, ['adverts', 'starved'])
# (2, ['advises', 'dissave'])
# (2, ['adynamic', 'cyanamid'])
# (2, ['adze', 'daze'])
# (2, ['adzes', 'dazes'])
# (2, ['aedes', 'eased'])
# (2, ['aeneus', 'unease'])
# (2, ['aerial', 'realia'])
# (2, ['aeries', 'easier'])
# (2, ['aeriest', 'seriate'])
# (2, ['aeroducts', 'educators'])
# (2, ['aerologies', 'areologies'])
# (2, ['aerology', 'areology'])
# (2, ['aerosol', 'roseola'])
# (2, ['aerosols', 'roseolas'])
# (2, ['aestival', 'salivate'])
# (2, ['aetheric', 'hetaeric'])
# (2, ['affair', 'raffia'])
# (2, ['affairs', 'raffias'])
# (2, ['affirmer', 'reaffirm'])
# (2, ['affirmers', 'reaffirms'])
# (2, ['affixer', 'reaffix'])
# (2, ['afield', 'failed'])
# (2, ['afire', 'feria'])
# (2, ['afreet', 'feater'])
# (2, ['afreets', 'feaster'])
# (2, ['aft', 'fat'])
# (2, ['agar', 'raga'])
# (2, ['agars', 'ragas'])
# (2, ['agas', 'saga'])
# (2, ['agaves', 'savage'])
# (2, ['age', 'gae'])
# (2, ['agenes', 'senega'])
# (2, ['agenesis', 'assignee'])
# (2, ['agential', 'alginate'])
# (2, ['agentries', 'reseating'])
# (2, ['aggrade', 'garaged'])
# (2, ['aggrades', 'saggared'])
# (2, ['agin', 'gain'])
# (2, ['agists', 'staigs'])
# (2, ['aglee', 'eagle'])
# (2, ['agminate', 'enigmata'])
# (2, ['agnomen', 'nongame'])
# (2, ['agnostics', 'coastings'])
# (2, ['ago', 'goa'])
# (2, ['agonal', 'analog'])
# (2, ['agone', 'genoa'])
# (2, ['agones', 'genoas'])
# (2, ['agonies', 'agonise'])
# (2, ['agonised', 'diagnose'])
# (2, ['agonist', 'gitanos'])
# (2, ['agues', 'usage'])
# (2, ['ah', 'ha'])
# (2, ['aide', 'idea'])
# (2, ['aiglet', 'ligate'])
# (2, ['aiglets', 'ligates'])
# (2, ['ailed', 'ideal'])
# (2, ['aileron', 'alienor'])
# (2, ['ailerons', 'alienors'])
# (2, ['ailing', 'nilgai'])
# (2, ['ailment', 'aliment'])
# (2, ['aim', 'ami'])
# (2, ['aimer', 'ramie'])
# (2, ['aimful', 'famuli'])
# (2, ['ain', 'ani'])
# (2, ['ainsells', 'sensilla'])
# (2, ['aircrews', 'airscrew'])
# (2, ['airman', 'marina'])
# (2, ['airs', 'sari'])
# (2, ['airted', 'tirade'])
# (2, ['aisles', 'lassie'])
# (2, ['aits', 'sati'])
# (2, ['aivers', 'varies'])
# (2, ['ajar', 'raja'])
# (2, ['akenes', 'skeane'])
# (2, ['akin', 'kain'])
# (2, ['alamedas', 'salaamed'])
# (2, ['alan', 'anal'])
# (2, ['alands', 'sandal'])
# (2, ['alang', 'lagan'])
# (2, ['alant', 'natal'])
# (2, ['alants', 'aslant'])
# (2, ['alanyl', 'anally'])
# (2, ['alanyls', 'nasally'])
# (2, ['alarm', 'malar'])
# (2, ['alarming', 'marginal'])
# (2, ['alarms', 'malars'])
# (2, ['alba', 'baal'])
# (2, ['albedo', 'doable'])
# (2, ['albeit', 'albite'])
# (2, ['albicore', 'cabriole'])
# (2, ['albicores', 'cabrioles'])
# (2, ['albumens', 'bluesman'])
# (2, ['alburnum', 'laburnum'])
# (2, ['alburnums', 'laburnums'])
# (2, ['alcades', 'scalade'])
# (2, ['alcaic', 'cicala'])
# (2, ['alcaics', 'cicalas'])
# (2, ['alchemic', 'chemical'])
# (2, ['alchymies', 'lechayims'])
# (2, ['alcove', 'coeval'])
# (2, ['alcoves', 'coevals'])
# (2, ['alder', 'lader'])
# (2, ['alders', 'laders'])
# (2, ['aldol', 'allod'])
# (2, ['aldols', 'allods'])
# (2, ['aldoses', 'lassoed'])
# (2, ['ale', 'lea'])
# (2, ['alec', 'lace'])
# (2, ['alegars', 'laagers'])
# (2, ['alembic', 'cembali'])
# (2, ['aleurons', 'neurosal'])
# (2, ['alevins', 'valines'])
# (2, ['alexin', 'xenial'])
# (2, ['alga', 'gala'])
# (2, ['algae', 'galea'])
# (2, ['algas', 'galas'])
# (2, ['algoid', 'dialog'])
# (2, ['algorithm', 'logarithm'])
# (2, ['algorithms', 'logarithms'])
# (2, ['algum', 'almug'])
# (2, ['algums', 'almugs'])
# (2, ['alibies', 'bailies'])
# (2, ['aliened', 'delaine'])
# (2, ['alienist', 'litanies'])
# (2, ['alifs', 'fails'])
# (2, ['alighted', 'gilthead'])
# (2, ['alignment', 'lamenting'])
# (2, ['aliners', 'nailers'])
# (2, ['alining', 'nailing'])
# (2, ['aliunde', 'unideal'])
# (2, ['alkalies', 'alkalise'])
# (2, ['allayer', 'areally'])
# (2, ['allergies', 'galleries'])
# (2, ['alliances', 'canailles'])
# (2, ['allodia', 'alodial'])
# (2, ['allonge', 'galleon'])
# (2, ['allonges', 'galleons'])
# (2, ['allot', 'atoll'])
# (2, ['allots', 'atolls'])
# (2, ['allotted', 'totalled'])
# (2, ['allotting', 'totalling'])
# (2, ['allover', 'overall'])
# (2, ['allovers', 'overalls'])
# (2, ['allows', 'sallow'])
# (2, ['alloy', 'loyal'])
# (2, ['alls', 'sall'])
# (2, ['allseeds', 'leadless'])
# (2, ['allude', 'aludel'])
# (2, ['alludes', 'aludels'])
# (2, ['allure', 'laurel'])
# (2, ['allures', 'laurels'])
# (2, ['alma', 'lama'])
# (2, ['almah', 'hamal'])
# (2, ['almahs', 'hamals'])
# (2, ['almas', 'lamas'])
# (2, ['almeh', 'hemal'])
# (2, ['almond', 'dolman'])
# (2, ['almonds', 'dolmans'])
# (2, ['almuce', 'macule'])
# (2, ['almuces', 'macules'])
# (2, ['almude', 'mauled'])
# (2, ['alnico', 'oilcan'])
# (2, ['aloe', 'olea'])
# (2, ['alone', 'anole'])
# (2, ['along', 'logan'])
# (2, ['aloof', 'loofa'])
# (2, ['alow', 'awol'])
# (2, ['alphosis', 'haplosis'])
# (2, ['alpinists', 'tailspins'])
# (2, ['alsikes', 'asslike'])
# (2, ['also', 'sola'])
# (2, ['alt', 'lat'])
# (2, ['alterant', 'tarletan'])
# (2, ['altercations', 'intercoastal'])
# (2, ['altitude', 'latitude'])
# (2, ['altitudes', 'latitudes'])
# (2, ['altruists', 'ultraists'])
# (2, ['alum', 'maul'])
# (2, ['alumna', 'manual'])
# (2, ['alums', 'mauls'])
# (2, ['alunites', 'insulate'])
# (2, ['alyssum', 'asylums'])
# (2, ['am', 'ma'])
# (2, ['amass', 'massa'])
# (2, ['amassing', 'siamangs'])
# (2, ['ambeers', 'besmear'])
# (2, ['ambivert', 'verbatim'])
# (2, ['ambles', 'blames'])
# (2, ['ambones', 'bemoans'])
# (2, ['ambos', 'sambo'])
# (2, ['ambry', 'barmy'])
# (2, ['ameer', 'ramee'])
# (2, ['amelcorn', 'cornmeal'])
# (2, ['amelcorns', 'cornmeals'])
# (2, ['amenable', 'nameable'])
# (2, ['amenders', 'meanders'])
# (2, ['amenity', 'anytime'])
# (2, ['amentia', 'animate'])
# (2, ['amentias', 'animates'])
# (2, ['amerce', 'raceme'])
# (2, ['amercer', 'creamer'])
# (2, ['amerces', 'racemes'])
# (2, ['amices', 'camise'])
# (2, ['amid', 'maid'])
# (2, ['amides', 'medias'])
# (2, ['amidin', 'diamin'])
# (2, ['amidins', 'diamins'])
# (2, ['amids', 'maids'])
# (2, ['amigo', 'imago'])
# (2, ['amiss', 'simas'])
# (2, ['amitoses', 'atomises'])
# (2, ['amitrole', 'rolamite'])
# (2, ['amitroles', 'rolamites'])
# (2, ['ammeter', 'metamer'])
# (2, ['ammeters', 'metamers'])
# (2, ['ammine', 'immane'])
# (2, ['ammines', 'misname'])
# (2, ['amnesia', 'anemias'])
# (2, ['amnesic', 'cinemas'])
# (2, ['amnestic', 'semantic'])
# (2, ['amnestied', 'dementias'])
# (2, ['amnic', 'manic'])
# (2, ['amnion', 'nomina'])
# (2, ['amniotes', 'misatone'])
# (2, ['amok', 'mako'])
# (2, ['amoks', 'makos'])
# (2, ['among', 'mango'])
# (2, ['amorettos', 'stateroom'])
# (2, ['amortised', 'mediators'])
# (2, ['amortize', 'atomizer'])
# (2, ['amortizes', 'atomizers'])
# (2, ['amount', 'outman'])
# (2, ['amounts', 'outmans'])
# (2, ['amours', 'ramous'])
# (2, ['ample', 'maple'])
# (2, ['ampler', 'palmer'])
# (2, ['amply', 'palmy'])
# (2, ['amtrac', 'tarmac'])
# (2, ['amtracs', 'tarmacs'])
# (2, ['amulet', 'muleta'])
# (2, ['amulets', 'muletas'])
# (2, ['amused', 'medusa'])
# (2, ['amuses', 'assume'])
# (2, ['an', 'na'])
# (2, ['anadem', 'maenad'])
# (2, ['anadems', 'maenads'])
# (2, ['analcime', 'calamine'])
# (2, ['analcimes', 'calamines'])
# (2, ['analcite', 'laitance'])
# (2, ['analcites', 'laitances'])
# (2, ['analgesic', 'angelicas'])
# (2, ['anapest', 'peasant'])
# (2, ['anapests', 'peasants'])
# (2, ['anarchic', 'characin'])
# (2, ['anarchism', 'chairmans'])
# (2, ['anas', 'ansa'])
# (2, ['ancestor', 'enactors'])
# (2, ['ancestries', 'resistance'])
# (2, ['anchusin', 'unchains'])
# (2, ['ancienter', 'nectarine'])
# (2, ['ancon', 'canon'])
# (2, ['ancones', 'sonance'])
# (2, ['ancress', 'caserns'])
# (2, ['ands', 'sand'])
# (2, ['ane', 'nae'])
# (2, ['anear', 'arena'])
# (2, ['anears', 'arenas'])
# (2, ['anes', 'sane'])
# (2, ['anestrus', 'saunters'])
# (2, ['anethol', 'ethanol'])
# (2, ['anethols', 'ethanols'])
# (2, ['angas', 'sanga'])
# (2, ['angering', 'enraging'])
# (2, ['angler', 'regnal'])
# (2, ['anglings', 'slanging'])
# (2, ['angora', 'organa'])
# (2, ['angry', 'rangy'])
# (2, ['angsts', 'stangs'])
# (2, ['anguine', 'guanine'])
# (2, ['animas', 'manias'])
# (2, ['animater', 'marinate'])
# (2, ['animaters', 'marinates'])
# (2, ['animis', 'simian'])
# (2, ['anions', 'nasion'])
# (2, ['anisettes', 'tetanises'])
# (2, ['anklets', 'lankest'])
# (2, ['anlage', 'galena'])
# (2, ['anna', 'nana'])
# (2, ['annas', 'nanas'])
# (2, ['annelid', 'lindane'])
# (2, ['annelids', 'lindanes'])
# (2, ['annoyed', 'anodyne'])
# (2, ['annuities', 'insinuate'])
# (2, ['annuli', 'unnail'])
# (2, ['anoint', 'nation'])
# (2, ['anointed', 'antinode'])
# (2, ['anointer', 'reanoint'])
# (2, ['anointers', 'reanoints'])
# (2, ['anoles', 'lanose'])
# (2, ['anon', 'nona'])
# (2, ['anopsias', 'paisanos'])
# (2, ['anoxic', 'axonic'])
# (2, ['anserous', 'arsenous'])
# (2, ['answer', 'resawn'])
# (2, ['answers', 'rawness'])
# (2, ['ant', 'tan'])
# (2, ['antagonist', 'stagnation'])
# (2, ['antagonists', 'stagnations'])
# (2, ['anthem', 'hetman'])
# (2, ['anthemia', 'haematin'])
# (2, ['anthems', 'hetmans'])
# (2, ['anther', 'thenar'])
# (2, ['antherids', 'tarnished'])
# (2, ['anthers', 'thenars'])
# (2, ['anthologies', 'theologians'])
# (2, ['anti', 'tain'])
# (2, ['antick', 'catkin'])
# (2, ['anticks', 'catkins'])
# (2, ['antidote', 'tetanoid'])
# (2, ['antidotes', 'stationed'])
# (2, ['antifascism', 'fanaticisms'])
# (2, ['antigens', 'gentians'])
# (2, ['antilogs', 'solating'])
# (2, ['antimonies', 'antinomies'])
# (2, ['antimony', 'antinomy'])
# (2, ['antimosquito', 'misquotation'])
# (2, ['antings', 'staning'])
# (2, ['antipodes', 'pintadoes'])
# (2, ['antipyretic', 'pertinacity'])
# (2, ['antiquated', 'aquatinted'])
# (2, ['antique', 'quinate'])
# (2, ['antiquer', 'quainter'])
# (2, ['antra', 'ratan'])
# (2, ['antral', 'tarnal'])
# (2, ['ants', 'tans'])
# (2, ['anuresis', 'senarius'])
# (2, ['anurias', 'saurian'])
# (2, ['anuric', 'uranic'])
# (2, ['anurous', 'uranous'])
# (2, ['anuses', 'usneas'])
# (2, ['any', 'nay'])
# (2, ['aorists', 'satoris'])
# (2, ['apatetic', 'capitate'])
# (2, ['ape', 'pea'])
# (2, ['apelike', 'pealike'])
# (2, ['apercus', 'scauper'])
# (2, ['aphelion', 'phelonia'])
# (2, ['apheses', 'spahees'])
# (2, ['aphetic', 'hepatic'])
# (2, ['aphides', 'diphase'])
# (2, ['aphorism', 'morphias'])
# (2, ['apiary', 'piraya'])
# (2, ['apices', 'spicae'])
# (2, ['aplastic', 'capitals'])
# (2, ['aplenty', 'penalty'])
# (2, ['apnea', 'paean'])
# (2, ['apneas', 'paeans'])
# (2, ['apomict', 'potamic'])
# (2, ['apostil', 'topsail'])
# (2, ['apostils', 'topsails'])
# (2, ['apostle', 'pelotas'])
# (2, ['appal', 'papal'])
# (2, ['appall', 'palpal'])
# (2, ['apparent', 'trappean'])
# (2, ['appealing', 'lagniappe'])
# (2, ['appels', 'apples'])
# (2, ['append', 'napped'])
# (2, ['appends', 'snapped'])
# (2, ['appraised', 'disappear'])
# (2, ['apprise', 'sappier'])
# (2, ['apricot', 'parotic'])
# (2, ['apricots', 'piscator'])
# (2, ['aprons', 'parson'])
# (2, ['apsis', 'aspis'])
# (2, ['aptness', 'patness'])
# (2, ['aptnesses', 'patnesses'])
# (2, ['aquiline', 'quiniela'])
# (2, ['arbiter', 'rarebit'])
# (2, ['arbiters', 'rarebits'])
# (2, ['arbutes', 'bursate'])
# (2, ['arc', 'car'])
# (2, ['arch', 'char'])
# (2, ['archaism', 'charisma'])
# (2, ['archaist', 'citharas'])
# (2, ['archaists', 'catharsis'])
# (2, ['archers', 'crasher'])
# (2, ['archils', 'carlish'])
# (2, ['archines', 'inarches'])
# (2, ['arco', 'orca'])
# (2, ['arcus', 'scaur'])
# (2, ['ardencies', 'increased'])
# (2, ['ardent', 'ranted'])
# (2, ['arete', 'eater'])
# (2, ['arf', 'far'])
# (2, ['argal', 'graal'])
# (2, ['argals', 'graals'])
# (2, ['argent', 'garnet'])
# (2, ['argentum', 'argument'])
# (2, ['argentums', 'arguments'])
# (2, ['argled', 'glared'])
# (2, ['argling', 'glaring'])
# (2, ['argot', 'groat'])
# (2, ['argots', 'groats'])
# (2, ['arguses', 'saugers'])
# (2, ['aria', 'raia'])
# (2, ['arias', 'raias'])
# (2, ['arid', 'raid'])
# (2, ['arider', 'raider'])
# (2, ['aridness', 'sardines'])
# (2, ['ariettas', 'aristate'])
# (2, ['ariette', 'iterate'])
# (2, ['arisen', 'arsine'])
# (2, ['aristas', 'tarsias'])
# (2, ['arks', 'sark'])
# (2, ['armer', 'rearm'])
# (2, ['armers', 'rearms'])
# (2, ['armful', 'fulmar'])
# (2, ['arming', 'margin'])
# (2, ['armings', 'margins'])
# (2, ['armlet', 'tramel'])
# (2, ['armoires', 'armories'])
# (2, ['armonica', 'macaroni'])
# (2, ['armonicas', 'macaronis'])
# (2, ['armpit', 'impart'])
# (2, ['armrest', 'smarter'])
# (2, ['arnotto', 'rattoon'])
# (2, ['arnottos', 'rattoons'])
# (2, ['aroid', 'radio'])
# (2, ['aroids', 'radios'])
# (2, ['aroint', 'ration'])
# (2, ['arointing', 'rationing'])
# (2, ['aroints', 'rations'])
# (2, ['aroynt', 'notary'])
# (2, ['arrester', 'rearrest'])
# (2, ['arresters', 'rearrests'])
# (2, ['arresting', 'serrating'])
# (2, ['arris', 'sirra'])
# (2, ['arrive', 'varier'])
# (2, ['arrives', 'variers'])
# (2, ['arrobas', 'rasbora'])
# (2, ['arrogant', 'tarragon'])
# (2, ['arrowy', 'yarrow'])
# (2, ['ars', 'ras'])
# (2, ['arsenate', 'serenata'])
# (2, ['arsenates', 'serenatas'])
# (2, ['arsenic', 'carnies'])
# (2, ['arsenics', 'raciness'])
# (2, ['arsenides', 'readiness'])
# (2, ['arshin', 'shairn'])
# (2, ['arshins', 'shairns'])
# (2, ['arsino', 'norias'])
# (2, ['arsis', 'saris'])
# (2, ['arsons', 'sonars'])
# (2, ['article', 'recital'])
# (2, ['articled', 'lacertid'])
# (2, ['artier', 'irater'])
# (2, ['artisans', 'tsarinas'])
# (2, ['artistes', 'striates'])
# (2, ['arty', 'tray'])
# (2, ['arum', 'mura'])
# (2, ['arval', 'larva'])
# (2, ['arvos', 'savor'])
# (2, ['ascend', 'dances'])
# (2, ['ascender', 'reascend'])
# (2, ['ascenders', 'reascends'])
# (2, ['ascension', 'canonises'])
# (2, ['ascertains', 'sectarians'])
# (2, ['ascites', 'ectasis'])
# (2, ['ascitic', 'sciatic'])
# (2, ['ascots', 'coasts'])
# (2, ['ascribe', 'caribes'])
# (2, ['ascribed', 'carbides'])
# (2, ['ascus', 'casus'])
# (2, ['asepsis', 'aspises'])
# (2, ['aseptic', 'spicate'])
# (2, ['ash', 'has'])
# (2, ['ashen', 'hanse'])
# (2, ['ashes', 'sheas'])
# (2, ['ashman', 'shaman'])
# (2, ['ask', 'kas'])
# (2, ['askant', 'tankas'])
# (2, ['askings', 'gaskins'])
# (2, ['aspect', 'epacts'])
# (2, ['asperate', 'separate'])
# (2, ['asperated', 'separated'])
# (2, ['asperates', 'separates'])
# (2, ['asperating', 'separating'])
# (2, ['asperges', 'presages'])
# (2, ['aspersed', 'repassed'])
# (2, ['asperser', 'spearers'])
# (2, ['asperses', 'repasses'])
# (2, ['asphalt', 'spathal'])
# (2, ['aspheric', 'seraphic'])
# (2, ['aspics', 'spicas'])
# (2, ['aspirant', 'partisan'])
# (2, ['aspirants', 'partisans'])
# (2, ['aspirated', 'disparate'])
# (2, ['aspirers', 'praisers'])
# (2, ['aspiring', 'praising'])
# (2, ['asrama', 'samara'])
# (2, ['assailers', 'reassails'])
# (2, ['assaying', 'gainsays'])
# (2, ['assemble', 'beamless'])
# (2, ['assenters', 'sarsenets'])
# (2, ['assenting', 'sensating'])
# (2, ['assentors', 'starnoses'])
# (2, ['asserters', 'reasserts'])
# (2, ['assertion', 'senoritas'])
# (2, ['asserts', 'trasses'])
# (2, ['assess', 'sasses'])
# (2, ['assigners', 'reassigns'])
# (2, ['assigns', 'sassing'])
# (2, ['assist', 'stasis'])
# (2, ['assistant', 'satanists'])
# (2, ['assisted', 'disseats'])
# (2, ['assoiled', 'isoleads'])
# (2, ['assort', 'roasts'])
# (2, ['assorted', 'torsades'])
# (2, ['assorting', 'organists'])
# (2, ['assuage', 'sausage'])
# (2, ['assuages', 'sausages'])
# (2, ['assumed', 'medusas'])
# (2, ['assumers', 'masseurs'])
# (2, ['assure', 'urases'])
# (2, ['assurer', 'rasures'])
# (2, ['astatine', 'sanitate'])
# (2, ['astatines', 'sanitates'])
# (2, ['asterias', 'atresias'])
# (2, ['asthenic', 'chanties'])
# (2, ['astheny', 'shantey'])
# (2, ['astonied', 'sedation'])
# (2, ['astrals', 'tarsals'])
# (2, ['astricted', 'tetracids'])
# (2, ['astringed', 'gradients'])
# (2, ['astute', 'statue'])
# (2, ['astuteness', 'tautnesses'])
# (2, ['asunder', 'danseur'])
# (2, ['at', 'ta'])
# (2, ['atechnic', 'catechin'])
# (2, ['atheists', 'hastiest'])
# (2, ['athletic', 'thetical'])
# (2, ['atlas', 'talas'])
# (2, ['atman', 'manta'])
# (2, ['atmans', 'mantas'])
# (2, ['atom', 'moat'])
# (2, ['atomies', 'atomise'])
# (2, ['atone', 'oaten'])
# (2, ['atoned', 'donate'])
# (2, ['atoner', 'ornate'])
# (2, ['atopies', 'opiates'])
# (2, ['atrip', 'tapir'])
# (2, ['atrocity', 'citatory'])
# (2, ['atropism', 'pastromi'])
# (2, ['atropisms', 'pastromis'])
# (2, ['attacher', 'reattach'])
# (2, ['attacker', 'reattack'])
# (2, ['attackers', 'reattacks'])
# (2, ['attainer', 'reattain'])
# (2, ['attainers', 'reattains'])
# (2, ['attars', 'strata'])
# (2, ['attended', 'dentated'])
# (2, ['attendee', 'edentate'])
# (2, ['attendees', 'edentates'])
# (2, ['attentive', 'tentative'])
# (2, ['attentively', 'tentatively'])
# (2, ['attesting', 'gnattiest'])
# (2, ['attestor', 'testator'])
# (2, ['attestors', 'testators'])
# (2, ['attic', 'tacit'])
# (2, ['atticism', 'mastitic'])
# (2, ['atticists', 'statistic'])
# (2, ['attics', 'static'])
# (2, ['attire', 'ratite'])
# (2, ['attorn', 'ratton'])
# (2, ['attorns', 'rattons'])
# (2, ['attrited', 'titrated'])
# (2, ['auction', 'caution'])
# (2, ['auctioning', 'cautioning'])
# (2, ['auctions', 'cautions'])
# (2, ['audients', 'sinuated'])
# (2, ['augend', 'unaged'])
# (2, ['aught', 'ghaut'])
# (2, ['aughts', 'ghauts'])
# (2, ['augment', 'mutagen'])
# (2, ['augments', 'mutagens'])
# (2, ['auks', 'skua'])
# (2, ['aulder', 'lauder'])
# (2, ['auldest', 'saluted'])
# (2, ['aunt', 'tuna'])
# (2, ['aunties', 'sinuate'])
# (2, ['aunts', 'tunas'])
# (2, ['aural', 'laura'])
# (2, ['aurei', 'uraei'])
# (2, ['aureus', 'uraeus'])
# (2, ['auric', 'curia'])
# (2, ['austerer', 'treasure'])
# (2, ['authored', 'outheard'])
# (2, ['autoing', 'outgain'])
# (2, ['autopsic', 'captious'])
# (2, ['availed', 'vedalia'])
# (2, ['avarice', 'caviare'])
# (2, ['avarices', 'caviares'])
# (2, ['avenge', 'geneva'])
# (2, ['avenger', 'engrave'])
# (2, ['avengers', 'engraves'])
# (2, ['avenges', 'genevas'])
# (2, ['averse', 'reaves'])
# (2, ['avert', 'trave'])
# (2, ['avgases', 'savages'])
# (2, ['aviatrices', 'vicariates'])
# (2, ['avid', 'diva'])
# (2, ['avo', 'ova'])
# (2, ['avocet', 'octave'])
# (2, ['avocets', 'octaves'])
# (2, ['avodire', 'avoider'])
# (2, ['avodires', 'avoiders'])
# (2, ['avower', 'reavow'])
# (2, ['avulse', 'values'])
# (2, ['awakener', 'reawaken'])
# (2, ['awakeners', 'reawakens'])
# (2, ['awe', 'wae'])
# (2, ['aweather', 'wheatear'])
# (2, ['awed', 'wade'])
# (2, ['aweless', 'weasels'])
# (2, ['awes', 'waes'])
# (2, ['awing', 'wigan'])
# (2, ['awl', 'law'])
# (2, ['awless', 'swales'])
# (2, ['awn', 'wan'])
# (2, ['awning', 'waning'])
# (2, ['awnings', 'snawing'])
# (2, ['awry', 'wary'])
# (2, ['axel', 'axle'])
# (2, ['axels', 'axles'])
# (2, ['axemen', 'examen'])
# (2, ['axites', 'taxies'])
# (2, ['ay', 'ya'])
# (2, ['aye', 'yea'])
# (2, ['ays', 'say'])
# (2, ['azido', 'diazo'])
# (2, ['azines', 'zanies'])
# (2, ['azo', 'zoa'])
# (2, ['azole', 'zoeal'])
# (2, ['azotemic', 'metazoic'])
# (2, ['babbled', 'blabbed'])
# (2, ['babbling', 'blabbing'])
# (2, ['babka', 'kabab'])
# (2, ['babkas', 'kababs'])
# (2, ['babul', 'bubal'])
# (2, ['babuls', 'bubals'])
# (2, ['bacillar', 'cabrilla'])
# (2, ['backlashed', 'blackheads'])
# (2, ['backmost', 'tombacks'])
# (2, ['backout', 'outback'])
# (2, ['backouts', 'outbacks'])
# (2, ['backrest', 'brackets'])
# (2, ['backset', 'setback'])
# (2, ['backsets', 'setbacks'])
# (2, ['backside', 'diebacks'])
# (2, ['backward', 'drawback'])
# (2, ['backwards', 'drawbacks'])
# (2, ['bacon', 'banco'])
# (2, ['bacons', 'bancos'])
# (2, ['bacterial', 'calibrate'])
# (2, ['bad', 'dab'])
# (2, ['badmen', 'bedamn'])
# (2, ['bads', 'dabs'])
# (2, ['bag', 'gab'])
# (2, ['bagasse', 'seabags'])
# (2, ['bagfuls', 'bagsful'])
# (2, ['bagnio', 'gabion'])
# (2, ['bagnios', 'gabions'])
# (2, ['bags', 'gabs'])
# (2, ['bahadurs', 'subahdar'])
# (2, ['baht', 'bath'])
# (2, ['bahts', 'baths'])
# (2, ['bailer', 'librae'])
# (2, ['bails', 'basil'])
# (2, ['bailsmen', 'bimensal'])
# (2, ['bairn', 'brain'])
# (2, ['bairnish', 'brainish'])
# (2, ['bairns', 'brains'])
# (2, ['baith', 'habit'])
# (2, ['bake', 'beak'])
# (2, ['bakemeat', 'makebate'])
# (2, ['bakemeats', 'makebates'])
# (2, ['bakes', 'beaks'])
# (2, ['bakings', 'basking'])
# (2, ['balancer', 'barnacle'])
# (2, ['balancers', 'barnacles'])
# (2, ['balded', 'bladed'])
# (2, ['balder', 'blared'])
# (2, ['baled', 'blade'])
# (2, ['baleen', 'enable'])
# (2, ['baleens', 'enables'])
# (2, ['balkline', 'linkable'])
# (2, ['balm', 'lamb'])
# (2, ['balmlike', 'lamblike'])
# (2, ['balms', 'lambs'])
# (2, ['balsamic', 'cabalism'])
# (2, ['baluster', 'rustable'])
# (2, ['bambinos', 'nabobism'])
# (2, ['ban', 'nab'])
# (2, ['banalities', 'insatiable'])
# (2, ['bandies', 'basined'])
# (2, ['bandore', 'broaden'])
# (2, ['bandores', 'broadens'])
# (2, ['bane', 'bean'])
# (2, ['banes', 'beans'])
# (2, ['banger', 'graben'])
# (2, ['bangers', 'grabens'])
# (2, ['banishes', 'banshies'])
# (2, ['banister', 'barniest'])
# (2, ['bans', 'nabs'])
# (2, ['banshee', 'shebean'])
# (2, ['banshees', 'shebeans'])
# (2, ['bantam', 'batman'])
# (2, ['bantams', 'batsman'])
# (2, ['banterers', 'barrenest'])
# (2, ['bar', 'bra'])
# (2, ['barbed', 'dabber'])
# (2, ['barbel', 'rabble'])
# (2, ['barbet', 'rabbet'])
# (2, ['barbless', 'slabbers'])
# (2, ['barding', 'brigand'])
# (2, ['barege', 'bargee'])
# (2, ['bareges', 'bargees'])
# (2, ['barer', 'barre'])
# (2, ['bargained', 'gabardine'])
# (2, ['barging', 'garbing'])
# (2, ['baric', 'rabic'])
# (2, ['barkier', 'brakier'])
# (2, ['barkiest', 'brakiest'])
# (2, ['barking', 'braking'])
# (2, ['barky', 'braky'])
# (2, ['barn', 'bran'])
# (2, ['barns', 'brans'])
# (2, ['baronet', 'reboant'])
# (2, ['barong', 'brogan'])
# (2, ['barongs', 'brogans'])
# (2, ['barony', 'baryon'])
# (2, ['barret', 'barter'])
# (2, ['barrets', 'barters'])
# (2, ['barrette', 'berretta'])
# (2, ['barrettes', 'berrettas'])
# (2, ['bars', 'bras'])
# (2, ['barye', 'yerba'])
# (2, ['baryes', 'yerbas'])
# (2, ['baryte', 'betray'])
# (2, ['barytes', 'betrays'])
# (2, ['bas', 'sab'])
# (2, ['basally', 'salably'])
# (2, ['basalt', 'tablas'])
# (2, ['basaltic', 'cabalist'])
# (2, ['base', 'sabe'])
# (2, ['basely', 'belays'])
# (2, ['bases', 'sabes'])
# (2, ['bashers', 'brashes'])
# (2, ['basinets', 'bassinet'])
# (2, ['basins', 'sabins'])
# (2, ['basion', 'bonsai'])
# (2, ['bask', 'kabs'])
# (2, ['bass', 'sabs'])
# (2, ['basseted', 'besteads'])
# (2, ['bastard', 'tabards'])
# (2, ['basters', 'breasts'])
# (2, ['bastille', 'listable'])
# (2, ['bastioned', 'botanised'])
# (2, ['basts', 'stabs'])
# (2, ['bat', 'tab'])
# (2, ['batboys', 'bobstay'])
# (2, ['batcher', 'brachet'])
# (2, ['batchers', 'brachets'])
# (2, ['batiste', 'bistate'])
# (2, ['battier', 'biretta'])
# (2, ['battle', 'tablet'])
# (2, ['battled', 'blatted'])
# (2, ['battles', 'tablets'])
# (2, ['battling', 'blatting'])
# (2, ['battue', 'tubate'])
# (2, ['bauble', 'bubale'])
# (2, ['baubles', 'bubales'])
# (2, ['baud', 'daub'])
# (2, ['bauds', 'daubs'])
# (2, ['bawl', 'blaw'])
# (2, ['bawled', 'blawed'])
# (2, ['bawler', 'warble'])
# (2, ['bawlers', 'warbles'])
# (2, ['bawling', 'blawing'])
# (2, ['bawls', 'blaws'])
# (2, ['bayadeer', 'bayadere'])
# (2, ['bayadeers', 'bayaderes'])
# (2, ['bazar', 'braza'])
# (2, ['bazars', 'brazas'])
# (2, ['beadiest', 'diabetes'])
# (2, ['beadings', 'debasing'])
# (2, ['beadsmen', 'bedesman'])
# (2, ['beagle', 'glebae'])
# (2, ['beaker', 'berake'])
# (2, ['beakers', 'berakes'])
# (2, ['beam', 'bema'])
# (2, ['beams', 'bemas'])
# (2, ['beanpole', 'openable'])
# (2, ['bearded', 'breaded'])
# (2, ['bearding', 'breading'])
# (2, ['bearings', 'sabering'])
# (2, ['beaut', 'tubae'])
# (2, ['beavered', 'bereaved'])
# (2, ['beavering', 'bereaving'])
# (2, ['becharmed', 'chambered'])
# (2, ['becharming', 'chambering'])
# (2, ['becked', 'bedeck'])
# (2, ['becrust', 'becurst'])
# (2, ['bed', 'deb'])
# (2, ['bedamned', 'bemadden'])
# (2, ['bedel', 'bleed'])
# (2, ['bedell', 'belled'])
# (2, ['bedels', 'bleeds'])
# (2, ['bedewing', 'bewinged'])
# (2, ['bedight', 'bighted'])
# (2, ['bedim', 'imbed'])
# (2, ['bedims', 'imbeds'])
# (2, ['bedlams', 'beldams'])
# (2, ['bedless', 'blessed'])
# (2, ['bedmaker', 'embarked'])
# (2, ['bedrapes', 'bespread'])
# (2, ['bedrooms', 'boredoms'])
# (2, ['bedrugged', 'begrudged'])
# (2, ['bedrugging', 'begrudging'])
# (2, ['beds', 'debs'])
# (2, ['bedsore', 'sobered'])
# (2, ['bedtimes', 'bemisted'])
# (2, ['beeches', 'beseech'])
# (2, ['beefier', 'freebie'])
# (2, ['been', 'bene'])
# (2, ['beer', 'bree'])
# (2, ['beers', 'brees'])
# (2, ['beets', 'beset'])
# (2, ['befinger', 'befringe'])
# (2, ['befingers', 'befringes'])
# (2, ['befleaed', 'feedable'])
# (2, ['befret', 'bereft'])
# (2, ['begalled', 'gabelled'])
# (2, ['begird', 'bridge'])
# (2, ['begirds', 'bridges'])
# (2, ['beglad', 'gabled'])
# (2, ['begrudge', 'buggered'])
# (2, ['belabors', 'sorbable'])
# (2, ['belaced', 'debacle'])
# (2, ['belady', 'dyable'])
# (2, ['belated', 'bleated'])
# (2, ['belayed', 'dyeable'])
# (2, ['belied', 'edible'])
# (2, ['bellied', 'libeled'])
# (2, ['bellowed', 'bowelled'])
# (2, ['bellowing', 'bowelling'])
# (2, ['belt', 'blet'])
# (2, ['bemean', 'bename'])
# (2, ['bemired', 'berimed'])
# (2, ['bemiring', 'beriming'])
# (2, ['bemusing', 'misbegun'])
# (2, ['ben', 'neb'])
# (2, ['benisons', 'boniness'])
# (2, ['bens', 'nebs'])
# (2, ['beraking', 'breaking'])
# (2, ['beringed', 'breeding'])
# (2, ['berme', 'ember'])
# (2, ['bermes', 'embers'])
# (2, ['berthing', 'brighten'])
# (2, ['bescour', 'obscure'])
# (2, ['bescours', 'obscures'])
# (2, ['beshadow', 'bowheads'])
# (2, ['beslime', 'besmile'])
# (2, ['beslimed', 'besmiled'])
# (2, ['beslimes', 'besmiles'])
# (2, ['besliming', 'besmiling'])
# (2, ['besmoked', 'embosked'])
# (2, ['besmoking', 'embosking'])
# (2, ['besoms', 'emboss'])
# (2, ['besotted', 'obtested'])
# (2, ['besotting', 'obtesting'])
# (2, ['bespake', 'bespeak'])
# (2, ['best', 'bets'])
# (2, ['bestead', 'debates'])
# (2, ['bestiary', 'sybarite'])
# (2, ['bestrew', 'webster'])
# (2, ['bestrews', 'websters'])
# (2, ['bestrid', 'bistred'])
# (2, ['bestride', 'bistered'])
# (2, ['bestrown', 'brownest'])
# (2, ['betided', 'debited'])
# (2, ['betiding', 'debiting'])
# (2, ['betokens', 'steenbok'])
# (2, ['betonies', 'ebonites'])
# (2, ['betrayal', 'rateably'])
# (2, ['betrayer', 'teaberry'])
# (2, ['bevatrons', 'observant'])
# (2, ['bey', 'bye'])
# (2, ['beys', 'byes'])
# (2, ['bhoot', 'booth'])
# (2, ['bhoots', 'booths'])
# (2, ['bias', 'isba'])
# (2, ['bibs', 'sibb'])
# (2, ['bicolor', 'brocoli'])
# (2, ['bicolors', 'brocolis'])
# (2, ['bicorn', 'bicron'])
# (2, ['bid', 'dib'])
# (2, ['bidet', 'debit'])
# (2, ['bidets', 'debits'])
# (2, ['bids', 'dibs'])
# (2, ['bier', 'brie'])
# (2, ['biforate', 'fireboat'])
# (2, ['big', 'gib'])
# (2, ['biggin', 'gibing'])
# (2, ['bigly', 'bilgy'])
# (2, ['bike', 'kibe'])
# (2, ['bikes', 'kibes'])
# (2, ['bilboes', 'lobbies'])
# (2, ['biller', 'rebill'])
# (2, ['billers', 'rebills'])
# (2, ['bilobed', 'lobbied'])
# (2, ['biltong', 'bolting'])
# (2, ['bima', 'iamb'])
# (2, ['bimas', 'iambs'])
# (2, ['bin', 'nib'])
# (2, ['binal', 'blain'])
# (2, ['binary', 'brainy'])
# (2, ['binders', 'rebinds'])
# (2, ['bio', 'obi'])
# (2, ['biocidal', 'diabolic'])
# (2, ['bioclean', 'coinable'])
# (2, ['biogeny', 'obeying'])
# (2, ['bionic', 'niobic'])
# (2, ['bios', 'obis'])
# (2, ['bipedal', 'piebald'])
# (2, ['bipolar', 'parboil'])
# (2, ['bird', 'drib'])
# (2, ['birder', 'birred'])
# (2, ['birds', 'dribs'])
# (2, ['birks', 'brisk'])
# (2, ['birle', 'liber'])
# (2, ['birled', 'bridle'])
# (2, ['birles', 'libers'])
# (2, ['birlings', 'brisling'])
# (2, ['birretta', 'brattier'])
# (2, ['bis', 'sib'])
# (2, ['bistro', 'orbits'])
# (2, ['biter', 'tribe'])
# (2, ['bitstock', 'bittocks'])
# (2, ['bizarre', 'brazier'])
# (2, ['bizarres', 'braziers'])
# (2, ['blankest', 'blankets'])
# (2, ['blast', 'blats'])
# (2, ['blastema', 'lambaste'])
# (2, ['blastemas', 'lambastes'])
# (2, ['blasters', 'stablers'])
# (2, ['blastier', 'librates'])
# (2, ['blasting', 'stabling'])
# (2, ['blastings', 'stablings'])
# (2, ['blasty', 'stably'])
# (2, ['blather', 'halbert'])
# (2, ['blathers', 'halberts'])
# (2, ['blearily', 'reliably'])
# (2, ['bleater', 'retable'])
# (2, ['bleaters', 'retables'])
# (2, ['bleating', 'tangible'])
# (2, ['blessing', 'glibness'])
# (2, ['blimy', 'limby'])
# (2, ['blinder', 'brindle'])
# (2, ['blinders', 'brindles'])
# (2, ['blisters', 'bristles'])
# (2, ['bloated', 'lobated'])
# (2, ['bloats', 'oblast'])
# (2, ['blobbed', 'bobbled'])
# (2, ['blobbing', 'bobbling'])
# (2, ['blooded', 'boodled'])
# (2, ['blooding', 'boodling'])
# (2, ['bloomer', 'rebloom'])
# (2, ['bloomers', 'reblooms'])
# (2, ['blot', 'bolt'])
# (2, ['blots', 'bolts'])
# (2, ['blotted', 'bottled'])
# (2, ['blotter', 'bottler'])
# (2, ['blotters', 'bottlers'])
# (2, ['blottier', 'libretto'])
# (2, ['blotting', 'bottling'])
# (2, ['bloused', 'doubles'])
# (2, ['blouses', 'boluses'])
# (2, ['blow', 'bowl'])
# (2, ['blowby', 'wobbly'])
# (2, ['blower', 'bowler'])
# (2, ['blowers', 'bowlers'])
# (2, ['blowfish', 'fishbowl'])
# (2, ['blowfly', 'flyblow'])
# (2, ['blowing', 'bowling'])
# (2, ['blows', 'bowls'])
# (2, ['blubber', 'bubbler'])
# (2, ['blubbers', 'bubblers'])
# (2, ['blue', 'lube'])
# (2, ['bluegill', 'gullible'])
# (2, ['bluenose', 'nebulose'])
# (2, ['bluer', 'ruble'])
# (2, ['blues', 'lubes'])
# (2, ['bluesy', 'blueys'])
# (2, ['blume', 'umbel'])
# (2, ['blunder', 'bundler'])
# (2, ['blunders', 'bundlers'])
# (2, ['blunge', 'bungle'])
# (2, ['blunged', 'bungled'])
# (2, ['blunger', 'bungler'])
# (2, ['blungers', 'bunglers'])
# (2, ['blunges', 'bungles'])
# (2, ['blunging', 'bungling'])
# (2, ['blur', 'burl'])
# (2, ['blush', 'buhls'])
# (2, ['blushes', 'bushels'])
# (2, ['boar', 'bora'])
# (2, ['boarded', 'roadbed'])
# (2, ['boarders', 'reboards'])
# (2, ['boars', 'boras'])
# (2, ['boasters', 'sorbates'])
# (2, ['boasting', 'boatings'])
# (2, ['boasts', 'sabots'])
# (2, ['boatels', 'oblates'])
# (2, ['bodement', 'entombed'])
# (2, ['bodice', 'ceboid'])
# (2, ['bodices', 'ceboids'])
# (2, ['bodies', 'dobies'])
# (2, ['body', 'doby'])
# (2, ['bog', 'gob'])
# (2, ['bogan', 'goban'])
# (2, ['bogans', 'gobans'])
# (2, ['bogeyman', 'moneybag'])
# (2, ['bogies', 'gobies'])
# (2, ['bogle', 'globe'])
# (2, ['bogles', 'globes'])
# (2, ['bogs', 'gobs'])
# (2, ['bogy', 'goby'])
# (2, ['bohea', 'obeah'])
# (2, ['boheas', 'obeahs'])
# (2, ['bohemias', 'obeahism'])
# (2, ['boiled', 'bolide'])
# (2, ['boiler', 'reboil'])
# (2, ['boilers', 'reboils'])
# (2, ['bolder', 'bordel'])
# (2, ['bole', 'lobe'])
# (2, ['boles', 'lobes'])
# (2, ['bolsters', 'lobsters'])
# (2, ['bombed', 'mobbed'])
# (2, ['bomber', 'mobber'])
# (2, ['bombers', 'mobbers'])
# (2, ['bombing', 'mobbing'])
# (2, ['bondage', 'dogbane'])
# (2, ['bondages', 'dogbanes'])
# (2, ['bone', 'ebon'])
# (2, ['bonefish', 'fishbone'])
# (2, ['boneless', 'noblesse'])
# (2, ['boner', 'borne'])
# (2, ['bones', 'ebons'])
# (2, ['boney', 'ebony'])
# (2, ['bongoist', 'boosting'])
# (2, ['bonita', 'obtain'])
# (2, ['bonitoes', 'eobionts'])
# (2, ['bonus', 'bosun'])
# (2, ['bonzer', 'bronze'])
# (2, ['booger', 'goober'])
# (2, ['boogers', 'goobers'])
# (2, ['bookcase', 'casebook'])
# (2, ['bookcases', 'casebooks'])
# (2, ['booms', 'bosom'])
# (2, ['boons', 'boson'])
# (2, ['boor', 'broo'])
# (2, ['boors', 'broos'])
# (2, ['boost', 'boots'])
# (2, ['bootjack', 'jackboot'])
# (2, ['bootjacks', 'jackboots'])
# (2, ['boozer', 'rebozo'])
# (2, ['boozers', 'rebozos'])
# (2, ['bordello', 'doorbell'])
# (2, ['bordellos', 'doorbells'])
# (2, ['bordures', 'suborder'])
# (2, ['bore', 'robe'])
# (2, ['borers', 'resorb'])
# (2, ['borides', 'disrobe'])
# (2, ['borings', 'sorbing'])
# (2, ['bos', 'sob'])
# (2, ['bosh', 'hobs'])
# (2, ['boss', 'sobs'])
# (2, ['bosses', 'obsess'])
# (2, ['bossier', 'riboses'])
# (2, ['bots', 'stob'])
# (2, ['boulder', 'doubler'])
# (2, ['boulders', 'doublers'])
# (2, ['boulle', 'lobule'])
# (2, ['bounced', 'buncoed'])
# (2, ['bouncing', 'buncoing'])
# (2, ['bounden', 'unboned'])
# (2, ['bourne', 'unrobe'])
# (2, ['bourns', 'suborn'])
# (2, ['bousy', 'buoys'])
# (2, ['boweled', 'elbowed'])
# (2, ['boweling', 'elbowing'])
# (2, ['bowers', 'browse'])
# (2, ['bowery', 'bowyer'])
# (2, ['bowings', 'bowsing'])
# (2, ['bowlder', 'lowbred'])
# (2, ['bowmen', 'enwomb'])
# (2, ['bows', 'swob'])
# (2, ['boxwood', 'woodbox'])
# (2, ['boyard', 'byroad'])
# (2, ['boyards', 'byroads'])
# (2, ['boys', 'sybo'])
# (2, ['braces', 'cabers'])
# (2, ['bracteal', 'cartable'])
# (2, ['brahmas', 'sambhar'])
# (2, ['braid', 'rabid'])
# (2, ['braids', 'disbar'])
# (2, ['brail', 'libra'])
# (2, ['braille', 'liberal'])
# (2, ['brailles', 'liberals'])
# (2, ['braise', 'rabies'])
# (2, ['braises', 'brassie'])
# (2, ['brakeage', 'breakage'])
# (2, ['brakeages', 'breakages'])
# (2, ['branches', 'brechans'])
# (2, ['brasiers', 'brassier'])
# (2, ['braunite', 'urbanite'])
# (2, ['braunites', 'urbanites'])
# (2, ['brawled', 'warbled'])
# (2, ['brawler', 'warbler'])
# (2, ['brawlers', 'warblers'])
# (2, ['brawlie', 'wirable'])
# (2, ['brawling', 'warbling'])
# (2, ['brayed', 'redbay'])
# (2, ['braze', 'zebra'])
# (2, ['brazes', 'zebras'])
# (2, ['breadnut', 'turbaned'])
# (2, ['breakout', 'outbreak'])
# (2, ['breakouts', 'outbreaks'])
# (2, ['breasted', 'debaters'])
# (2, ['brede', 'breed'])
# (2, ['bredes', 'breeds'])
# (2, ['briber', 'ribber'])
# (2, ['bribers', 'ribbers'])
# (2, ['bribing', 'ribbing'])
# (2, ['bricole', 'corbeil'])
# (2, ['bricoles', 'corbeils'])
# (2, ['bridal', 'ribald'])
# (2, ['bridally', 'ribaldly'])
# (2, ['bridals', 'ribalds'])
# (2, ['brisance', 'carbines'])
# (2, ['briskest', 'briskets'])
# (2, ['bristled', 'driblets'])
# (2, ['bristol', 'strobil'])
# (2, ['bristols', 'strobils'])
# (2, ['britzkas', 'britzska'])
# (2, ['broadcaster', 'rebroadcast'])
# (2, ['broadcasters', 'rebroadcasts'])
# (2, ['broadside', 'sideboard'])
# (2, ['broadsides', 'sideboards'])
# (2, ['broiders', 'disrober'])
# (2, ['brokages', 'grosbeak'])
# (2, ['bromid', 'morbid'])
# (2, ['bromo', 'broom'])
# (2, ['bromos', 'brooms'])
# (2, ['broses', 'sobers'])
# (2, ['broth', 'throb'])
# (2, ['broths', 'throbs'])
# (2, ['brugh', 'burgh'])
# (2, ['brughs', 'burghs'])
# (2, ['bruin', 'burin'])
# (2, ['bruins', 'burins'])
# (2, ['bruised', 'burdies'])
# (2, ['bruiser', 'buriers'])
# (2, ['bruiters', 'burriest'])
# (2, ['brume', 'umber'])
# (2, ['brumes', 'umbers'])
# (2, ['brunt', 'burnt'])
# (2, ['brushes', 'bushers'])
# (2, ['brusker', 'burkers'])
# (2, ['brutely', 'butlery'])
# (2, ['bucklers', 'subclerk'])
# (2, ['bucksaw', 'sawbuck'])
# (2, ['bucksaws', 'sawbucks'])
# (2, ['bud', 'dub'])
# (2, ['budder', 'redbud'])
# (2, ['budders', 'redbuds'])
# (2, ['budge', 'debug'])
# (2, ['budges', 'debugs'])
# (2, ['buds', 'dubs'])
# (2, ['buffer', 'rebuff'])
# (2, ['buffered', 'rebuffed'])
# (2, ['buffering', 'rebuffing'])
# (2, ['buffers', 'rebuffs'])
# (2, ['bugle', 'bulge'])
# (2, ['bugled', 'bulged'])
# (2, ['bugles', 'bulges'])
# (2, ['bugling', 'bulging'])
# (2, ['builder', 'rebuild'])
# (2, ['builders', 'rebuilds'])
# (2, ['buildup', 'upbuild'])
# (2, ['buildups', 'upbuilds'])
# (2, ['bun', 'nub'])
# (2, ['bundist', 'dustbin'])
# (2, ['bundists', 'dustbins'])
# (2, ['bunked', 'debunk'])
# (2, ['bunkered', 'debunker'])
# (2, ['bur', 'rub'])
# (2, ['burans', 'unbars'])
# (2, ['buras', 'bursa'])
# (2, ['burbled', 'rubbled'])
# (2, ['burblier', 'rubblier'])
# (2, ['burbling', 'rubbling'])
# (2, ['burbly', 'rubbly'])
# (2, ['burd', 'drub'])
# (2, ['burds', 'drubs'])
# (2, ['burg', 'grub'])
# (2, ['burgs', 'grubs'])
# (2, ['burier', 'rubier'])
# (2, ['burkes', 'busker'])
# (2, ['burliest', 'subtiler'])
# (2, ['burnies', 'suberin'])
# (2, ['burnout', 'outburn'])
# (2, ['burnouts', 'outburns'])
# (2, ['burs', 'rubs'])
# (2, ['burses', 'subers'])
# (2, ['bury', 'ruby'])
# (2, ['burying', 'rubying'])
# (2, ['bus', 'sub'])
# (2, ['bush', 'hubs'])
# (2, ['bushfires', 'furbishes'])
# (2, ['busings', 'bussing'])
# (2, ['buss', 'subs'])
# (2, ['bustics', 'cubists'])
# (2, ['bustier', 'rubiest'])
# (2, ['bustiest', 'stubiest'])
# (2, ['busting', 'tubings'])
# (2, ['bustles', 'sublets'])
# (2, ['busts', 'stubs'])
# (2, ['busy', 'buys'])
# (2, ['but', 'tub'])
# (2, ['butenes', 'subteen'])
# (2, ['buteos', 'obtuse'])
# (2, ['buttered', 'rebutted'])
# (2, ['buttering', 'rebutting'])
# (2, ['buttoner', 'rebutton'])
# (2, ['buttoners', 'rebuttons'])
# (2, ['butyls', 'subtly'])
# (2, ['bwana', 'nawab'])
# (2, ['bwanas', 'nawabs'])
# (2, ['cabestro', 'cabresto'])
# (2, ['cabestros', 'cabrestos'])
# (2, ['cabs', 'scab'])
# (2, ['cachets', 'catches'])
# (2, ['cackled', 'clacked'])
# (2, ['cackling', 'clacking'])
# (2, ['cactoid', 'octadic'])
# (2, ['cadaster', 'cadastre'])
# (2, ['cadasters', 'cadastres'])
# (2, ['caddises', 'discased'])
# (2, ['cadge', 'caged'])
# (2, ['cadger', 'graced'])
# (2, ['cads', 'scad'])
# (2, ['caduceus', 'caucused'])
# (2, ['caecally', 'calyceal'])
# (2, ['caestus', 'cuestas'])
# (2, ['caesuric', 'curacies'])
# (2, ['cafe', 'face'])
# (2, ['cafes', 'faces'])
# (2, ['cageling', 'glaceing'])
# (2, ['cager', 'grace'])
# (2, ['cahiers', 'cashier'])
# (2, ['caiman', 'maniac'])
# (2, ['caimans', 'maniacs'])
# (2, ['cairds', 'darics'])
# (2, ['cairn', 'naric'])
# (2, ['caissons', 'cassinos'])
# (2, ['calami', 'camail'])
# (2, ['calamint', 'claimant'])
# (2, ['calamints', 'claimants'])
# (2, ['calamus', 'maculas'])
# (2, ['calcines', 'scenical'])
# (2, ['caldera', 'craaled'])
# (2, ['calendal', 'canalled'])
# (2, ['calends', 'candles'])
# (2, ['caliber', 'calibre'])
# (2, ['calibers', 'calibres'])
# (2, ['caliche', 'chalice'])
# (2, ['caliches', 'chalices'])
# (2, ['califs', 'fiscal'])
# (2, ['calipash', 'pashalic'])
# (2, ['calipees', 'especial'])
# (2, ['caliper', 'replica'])
# (2, ['calk', 'lack'])
# (2, ['calked', 'lacked'])
# (2, ['calking', 'lacking'])
# (2, ['calli', 'lilac'])
# (2, ['callose', 'locales'])
# (2, ['calloses', 'coalless'])
# (2, ['callosity', 'stoically'])
# (2, ['calls', 'scall'])
# (2, ['calm', 'clam'])
# (2, ['calmed', 'macled'])
# (2, ['calmer', 'marcel'])
# (2, ['calmest', 'camlets'])
# (2, ['calms', 'clams'])
# (2, ['calories', 'carioles'])
# (2, ['caloyers', 'coarsely'])
# (2, ['calque', 'claque'])
# (2, ['calques', 'claques'])
# (2, ['calumets', 'muscatel'])
# (2, ['calumnies', 'masculine'])
# (2, ['calvary', 'cavalry'])
# (2, ['calve', 'clave'])
# (2, ['calyces', 'cyclase'])
# (2, ['calycle', 'cecally'])
# (2, ['cam', 'mac'])
# (2, ['camber', 'crambe'])
# (2, ['cambered', 'embraced'])
# (2, ['cambering', 'embracing'])
# (2, ['cambers', 'crambes'])
# (2, ['camel', 'macle'])
# (2, ['cameo', 'comae'])
# (2, ['camped', 'decamp'])
# (2, ['campers', 'scamper'])
# (2, ['campiest', 'campsite'])
# (2, ['campings', 'scamping'])
# (2, ['camps', 'scamp'])
# (2, ['canceler', 'clarence'])
# (2, ['cancelers', 'clarences'])
# (2, ['cancroid', 'draconic'])
# (2, ['candider', 'riddance'])
# (2, ['candies', 'incased'])
# (2, ['candle', 'lanced'])
# (2, ['canfuls', 'cansful'])
# (2, ['cangue', 'uncage'])
# (2, ['cangues', 'uncages'])
# (2, ['canines', 'encinas'])
# (2, ['canneries', 'narceines'])
# (2, ['canners', 'scanner'])
# (2, ['cannier', 'narcein'])
# (2, ['cannings', 'scanning'])
# (2, ['cannot', 'canton'])
# (2, ['canoe', 'ocean'])
# (2, ['canoes', 'oceans'])
# (2, ['canoness', 'sonances'])
# (2, ['canonists', 'sanctions'])
# (2, ['canopying', 'poignancy'])
# (2, ['cans', 'scan'])
# (2, ['cantering', 'recanting'])
# (2, ['canto', 'cotan'])
# (2, ['cantos', 'cotans'])
# (2, ['canula', 'lacuna'])
# (2, ['canulae', 'lacunae'])
# (2, ['canulas', 'lacunas'])
# (2, ['canvasers', 'canvasser'])
# (2, ['cap', 'pac'])
# (2, ['cape', 'pace'])
# (2, ['caped', 'paced'])
# (2, ['capelans', 'scalepan'])
# (2, ['caph', 'chap'])
# (2, ['caphs', 'chaps'])
# (2, ['capitols', 'coalpits'])
# (2, ['caplins', 'inclasp'])
# (2, ['caponiers', 'procaines'])
# (2, ['capote', 'toecap'])
# (2, ['capotes', 'toecaps'])
# (2, ['capouch', 'pachuco'])
# (2, ['caps', 'pacs'])
# (2, ['capsular', 'scapular'])
# (2, ['capsule', 'specula'])
# (2, ['captan', 'catnap'])
# (2, ['caption', 'paction'])
# (2, ['captions', 'pactions'])
# (2, ['captor', 'cartop'])
# (2, ['caramels', 'ceramals'])
# (2, ['carbon', 'corban'])
# (2, ['carbons', 'corbans'])
# (2, ['carders', 'scarred'])
# (2, ['careen', 'recane'])
# (2, ['careers', 'creaser'])
# (2, ['careless', 'rescales'])
# (2, ['carer', 'racer'])
# (2, ['caresser', 'creasers'])
# (2, ['carful', 'fulcra'])
# (2, ['carhop', 'coprah'])
# (2, ['carhops', 'coprahs'])
# (2, ['carinal', 'cranial'])
# (2, ['carinate', 'craniate'])
# (2, ['carious', 'curiosa'])
# (2, ['cark', 'rack'])
# (2, ['carks', 'racks'])
# (2, ['carlines', 'lanciers'])
# (2, ['carmines', 'cremains'])
# (2, ['carn', 'narc'])
# (2, ['carns', 'narcs'])
# (2, ['carob', 'cobra'])
# (2, ['carobs', 'cobras'])
# (2, ['caroche', 'coacher'])
# (2, ['caroches', 'coachers'])
# (2, ['caroli', 'lorica'])
# (2, ['carolled', 'collared'])
# (2, ['carolling', 'collaring'])
# (2, ['caroluses', 'carousels'])
# (2, ['carom', 'macro'])
# (2, ['caromed', 'comrade'])
# (2, ['caroms', 'macros'])
# (2, ['carp', 'crap'])
# (2, ['carpet', 'preact'])
# (2, ['carpeted', 'preacted'])
# (2, ['carpeting', 'preacting'])
# (2, ['carping', 'craping'])
# (2, ['carriers', 'scarrier'])
# (2, ['carries', 'scarier'])
# (2, ['carritches', 'scratchier'])
# (2, ['carrot', 'trocar'])
# (2, ['carrots', 'trocars'])
# (2, ['cartoon', 'coranto'])
# (2, ['cartoons', 'corantos'])
# (2, ['carts', 'scart'])
# (2, ['carved', 'craved'])
# (2, ['carvel', 'claver'])
# (2, ['carvels', 'clavers'])
# (2, ['carver', 'craver'])
# (2, ['carvers', 'cravers'])
# (2, ['carving', 'craving'])
# (2, ['carvings', 'cravings'])
# (2, ['casabas', 'cassaba'])
# (2, ['casavas', 'cassava'])
# (2, ['cascabel', 'cascable'])
# (2, ['cascabels', 'cascables'])
# (2, ['cascade', 'saccade'])
# (2, ['cascades', 'saccades'])
# (2, ['casein', 'incase'])
# (2, ['caseins', 'incases'])
# (2, ['casettes', 'cassette'])
# (2, ['cashed', 'chased'])
# (2, ['cashiers', 'rachises'])
# (2, ['cashing', 'chasing'])
# (2, ['cask', 'sack'])
# (2, ['casked', 'sacked'])
# (2, ['casking', 'sacking'])
# (2, ['casks', 'sacks'])
# (2, ['casky', 'yacks'])
# (2, ['casque', 'sacque'])
# (2, ['casques', 'sacques'])
# (2, ['casserole', 'escaroles'])
# (2, ['cassock', 'cossack'])
# (2, ['cassocks', 'cossacks'])
# (2, ['castes', 'cestas'])
# (2, ['castling', 'catlings'])
# (2, ['castoff', 'offcast'])
# (2, ['castoffs', 'offcasts'])
# (2, ['castors', 'costars'])
# (2, ['castrate', 'teacarts'])
# (2, ['casts', 'scats'])
# (2, ['casual', 'causal'])
# (2, ['casually', 'causally'])
# (2, ['casuals', 'causals'])
# (2, ['catalos', 'coastal'])
# (2, ['catamites', 'masticate'])
# (2, ['catchers', 'cratches'])
# (2, ['catchiest', 'catechist'])
# (2, ['cate', 'tace'])
# (2, ['catechins', 'chanciest'])
# (2, ['catechism', 'schematic'])
# (2, ['catenoids', 'sonicated'])
# (2, ['cateress', 'cerastes'])
# (2, ['cathouse', 'soutache'])
# (2, ['cathouses', 'soutaches'])
# (2, ['catlin', 'tincal'])
# (2, ['catling', 'talcing'])
# (2, ['catlins', 'tincals'])
# (2, ['catsup', 'upcast'])
# (2, ['catsups', 'upcasts'])
# (2, ['cattails', 'statical'])
# (2, ['cattier', 'citrate'])
# (2, ['catties', 'statice'])
# (2, ['cattily', 'tacitly'])
# (2, ['cattinesses', 'tacitnesses'])
# (2, ['cattish', 'tachist'])
# (2, ['cattle', 'tectal'])
# (2, ['caudle', 'cedula'])
# (2, ['caudles', 'cedulas'])
# (2, ['cauld', 'ducal'])
# (2, ['cauldron', 'crunodal'])
# (2, ['caules', 'clause'])
# (2, ['cause', 'sauce'])
# (2, ['caused', 'sauced'])
# (2, ['causes', 'sauces'])
# (2, ['causey', 'cayuse'])
# (2, ['causeys', 'cayuses'])
# (2, ['causing', 'saucing'])
# (2, ['caveat', 'vacate'])
# (2, ['caveats', 'vacates'])
# (2, ['caverned', 'cravened'])
# (2, ['caverning', 'cravening'])
# (2, ['caverns', 'cravens'])
# (2, ['cavies', 'vesica'])
# (2, ['cavitied', 'vaticide'])
# (2, ['ceasing', 'incages'])
# (2, ['cedis', 'dices'])
# (2, ['ceil', 'lice'])
# (2, ['ceiled', 'decile'])
# (2, ['ceils', 'slice'])
# (2, ['ceinture', 'enuretic'])
# (2, ['ceintures', 'centuries'])
# (2, ['celiac', 'cicale'])
# (2, ['celibate', 'citeable'])
# (2, ['cellared', 'recalled'])
# (2, ['cellarer', 'recaller'])
# (2, ['cellarers', 'recallers'])
# (2, ['cellaring', 'recalling'])
# (2, ['cementer', 'cerement'])
# (2, ['cementers', 'cerements'])
# (2, ['cense', 'scene'])
# (2, ['censes', 'scenes'])
# (2, ['censoring', 'necrosing'])
# (2, ['centaur', 'uncrate'])
# (2, ['centimo', 'tonemic'])
# (2, ['cento', 'conte'])
# (2, ['centos', 'contes'])
# (2, ['centred', 'credent'])
# (2, ['centrist', 'citterns'])
# (2, ['centroid', 'doctrine'])
# (2, ['centroids', 'doctrines'])
# (2, ['cents', 'scent'])
# (2, ['ceramic', 'racemic'])
# (2, ['cerci', 'ceric'])
# (2, ['cercus', 'cruces'])
# (2, ['cereal', 'relace'])
# (2, ['cerebrum', 'cumberer'])
# (2, ['cerebrums', 'cumberers'])
# (2, ['ceres', 'scree'])
# (2, ['cering', 'cringe'])
# (2, ['ceriph', 'cipher'])
# (2, ['cerium', 'uremic'])
# (2, ['ceriums', 'murices'])
# (2, ['cernuous', 'coenurus'])
# (2, ['cero', 'core'])
# (2, ['cerotic', 'orectic'])
# (2, ['certification', 'rectification'])
# (2, ['certifications', 'rectifications'])
# (2, ['certified', 'rectified'])
# (2, ['certifier', 'rectifier'])
# (2, ['certifiers', 'rectifiers'])
# (2, ['certifies', 'rectifies'])
# (2, ['certify', 'rectify'])
# (2, ['certifying', 'rectifying'])
# (2, ['certitude', 'rectitude'])
# (2, ['certitudes', 'rectitudes'])
# (2, ['cervices', 'crevices'])
# (2, ['cesium', 'miscue'])
# (2, ['cesiums', 'miscues'])
# (2, ['cess', 'secs'])
# (2, ['cessions', 'cosiness'])
# (2, ['cesspit', 'septics'])
# (2, ['cesti', 'cites'])
# (2, ['cestode', 'escoted'])
# (2, ['cestodes', 'cosseted'])
# (2, ['cestus', 'scutes'])
# (2, ['cetane', 'tenace'])
# (2, ['cetanes', 'tenaces'])
# (2, ['chadarim', 'drachmai'])
# (2, ['chain', 'china'])
# (2, ['chained', 'echidna'])
# (2, ['chains', 'chinas'])
# (2, ['chairs', 'rachis'])
# (2, ['chaldron', 'chlordan'])
# (2, ['chaldrons', 'chlordans'])
# (2, ['chalet', 'thecal'])
# (2, ['chalked', 'hackled'])
# (2, ['chalkier', 'hacklier'])
# (2, ['chalkiest', 'hackliest'])
# (2, ['chalking', 'hackling'])
# (2, ['chalky', 'hackly'])
# (2, ['challie', 'helical'])
# (2, ['cham', 'mach'])
# (2, ['chamiso', 'chamois'])
# (2, ['chancier', 'chicaner'])
# (2, ['chancres', 'cranches'])
# (2, ['chanson', 'noncash'])
# (2, ['chantries', 'snatchier'])
# (2, ['chapel', 'pleach'])
# (2, ['chapes', 'cheaps'])
# (2, ['chapt', 'patch'])
# (2, ['chapter', 'patcher'])
# ...
# (5, ['altars', 'astral', 'ratals', 'talars', 'tarsal'])
# (5, ['alts', 'last', 'lats', 'salt', 'slat'])
# (5, ['ambled', 'bedlam', 'beldam', 'blamed', 'lambed'])
# (5, ['ambler', 'blamer', 'lamber', 'marble', 'ramble'])
# (5, ['amblers', 'blamers', 'lambers', 'marbles', 'rambles'])
# (5, ['amen', 'mane', 'mean', 'name', 'nema'])
# (5, ['amines', 'animes', 'inseam', 'mesian', 'semina'])
# (5, ['angered', 'derange', 'enraged', 'grandee', 'grenade'])
# (5, ['angrier', 'earring', 'grainer', 'rangier', 'rearing'])
# (5, ['antes', 'etnas', 'nates', 'neats', 'stane'])
# (5, ['antis', 'saint', 'satin', 'stain', 'tains'])
# (5, ['aper', 'pare', 'pear', 'rape', 'reap'])
# (5, ['apes', 'apse', 'pase', 'peas', 'spae'])
# (5, ['apter', 'pater', 'peart', 'prate', 'taper'])
# (5, ['arches', 'chares', 'chaser', 'eschar', 'search'])
# (5, ['arcuses', 'causers', 'cesuras', 'saucers', 'sucrase'])
# (5, ['argle', 'glare', 'lager', 'large', 'regal'])
# (5, ['argons', 'groans', 'orangs', 'organs', 'sarong'])
# (5, ['ariels', 'resail', 'sailer', 'serail', 'serial'])
# (5, ['ariettes', 'iterates', 'teariest', 'treaties', 'treatise'])
# (5, ['arpent', 'enrapt', 'entrap', 'parent', 'trepan'])
# (5, ['arpents', 'entraps', 'parents', 'pastern', 'trepans'])
# (5, ['arts', 'rats', 'star', 'tars', 'tsar'])
# (5, ['ascot', 'coast', 'coats', 'costa', 'tacos'])
# (5, ['aspires', 'paresis', 'parises', 'praises', 'spireas'])
# (5, ['assertor', 'assorter', 'oratress', 'reassort', 'roasters'])
# (5, ['asset', 'easts', 'sates', 'seats', 'tasse'])
# (5, ['aster', 'rates', 'stare', 'tares', 'tears'])
# (5, ['ate', 'eat', 'eta', 'tae', 'tea'])
# (5, ['attunes', 'nutates', 'tautens', 'tetanus', 'unstate'])
# (5, ['awns', 'sawn', 'snaw', 'swan', 'wans'])
# (5, ['bestir', 'bister', 'bistre', 'biters', 'tribes'])
# (5, ['bluest', 'bluets', 'bustle', 'sublet', 'subtle'])
# (5, ['boaster', 'boaters', 'borates', 'rebatos', 'sorbate'])
# (5, ['bromes', 'ombers', 'ombres', 'somber', 'sombre'])
# (5, ['brutes', 'burets', 'buster', 'rebuts', 'tubers'])
# (5, ['caners', 'casern', 'cranes', 'nacres', 'rances'])
# (5, ['canister', 'ceratins', 'cisterna', 'creatins', 'scantier'])
# (5, ['carles', 'clears', 'lacers', 'scaler', 'sclera'])
# (5, ['centiares', 'cisternae', 'creatines', 'iterances', 'nectaries'])
# (5, ['cereus', 'ceruse', 'recuse', 'rescue', 'secure'])
# (5, ['certes', 'erects', 'resect', 'secret', 'terces'])
# (5, ['chaste', 'cheats', 'sachet', 'scathe', 'taches'])
# (5, ['cheater', 'hectare', 'recheat', 'reteach', 'teacher'])
# (5, ['cions', 'coins', 'icons', 'scion', 'sonic'])
# (5, ['corsets', 'costers', 'escorts', 'scoters', 'sectors'])
# (5, ['craals', 'lascar', 'rascal', 'sacral', 'scalar'])
# (5, ['cruse', 'cures', 'curse', 'ecrus', 'sucre'])
# (5, ['dales', 'deals', 'lades', 'lased', 'leads'])
# (5, ['daters', 'derats', 'stared', 'trades', 'treads'])
# (5, ['dates', 'sated', 'stade', 'stead', 'tsade'])
# (5, ['dearer', 'reader', 'reared', 'redear', 'reread'])
# (5, ['deer', 'dere', 'dree', 'rede', 'reed'])
# (5, ['deil', 'deli', 'diel', 'idle', 'lied'])
# (5, ['delist', 'idlest', 'listed', 'silted', 'tildes'])
# (5, ['demerit', 'dimeter', 'merited', 'mitered', 'retimed'])
# (5, ['demireps', 'epiderms', 'impeders', 'premised', 'simpered'])
# (5, ['derries', 'desirer', 'redries', 'resider', 'serried'])
# (5, ['designer', 'energids', 'redesign', 'reedings', 'resigned'])
# (5, ['destain', 'detains', 'instead', 'sainted', 'stained'])
# (5, ['diesel', 'ediles', 'elides', 'sedile', 'seidel'])
# (5, ['diet', 'dite', 'edit', 'tide', 'tied'])
# (5, ['dineros', 'indorse', 'ordines', 'rosined', 'sordine'])
# (5, ['diopters', 'dioptres', 'peridots', 'proteids', 'riposted'])
# (5, ['drawer', 'redraw', 'reward', 'warder', 'warred'])
# (5, ['drupes', 'dupers', 'perdus', 'prudes', 'pursed'])
# (5, ['eaglets', 'gelates', 'legates', 'segetal', 'telegas'])
# (5, ['earing', 'gainer', 'reagin', 'regain', 'regina'])
# (5, ['earless', 'leasers', 'resales', 'reseals', 'sealers'])
# (5, ['earns', 'nares', 'nears', 'saner', 'snare'])
# (5, ['eath', 'haet', 'hate', 'heat', 'thae'])
# (5, ['editors', 'sortied', 'steroid', 'storied', 'triodes'])
# (5, ['enlist', 'inlets', 'listen', 'silent', 'tinsel'])
# (5, ['entrails', 'latrines', 'ratlines', 'retinals', 'trenails'])
# (5, ['enviers', 'inverse', 'veiners', 'venires', 'versine'])
# (5, ['eons', 'noes', 'nose', 'ones', 'sone'])
# (5, ['eroding', 'groined', 'ignored', 'negroid', 'redoing'])
# (5, ['eros', 'ores', 'roes', 'rose', 'sore'])
# (5, ['erugos', 'grouse', 'rogues', 'rouges', 'rugose'])
# (5, ['ervils', 'livers', 'livres', 'silver', 'sliver'])
# (5, ['escarps', 'parsecs', 'scrapes', 'secpars', 'spacers'])
# (5, ['everts', 'revest', 'revets', 'verset', 'verste'])
# (5, ['fetors', 'forest', 'fortes', 'foster', 'softer'])
# (5, ['filets', 'fliest', 'flites', 'itself', 'stifle'])
# (5, ['fires', 'fries', 'frise', 'reifs', 'serif'])
# (5, ['gapers', 'gasper', 'grapes', 'parges', 'sparge'])
# (5, ['gilder', 'girdle', 'glider', 'regild', 'ridgel'])
# (5, ['gilders', 'girdles', 'gliders', 'regilds', 'ridgels'])
# (5, ['girons', 'grison', 'groins', 'rosing', 'signor'])
# (5, ['halters', 'harslet', 'lathers', 'slather', 'thalers'])
# (5, ['hares', 'hears', 'rheas', 'share', 'shear'])
# (5, ['hector', 'rochet', 'rotche', 'tocher', 'troche'])
# (5, ['heros', 'hoers', 'horse', 'shoer', 'shore'])
# (5, ['hist', 'hits', 'shit', 'sith', 'this'])
# (5, ['hooters', 'reshoot', 'sheroot', 'shooter', 'soother'])
# (5, ['host', 'hots', 'shot', 'soth', 'tosh'])
# (5, ['inert', 'inter', 'niter', 'nitre', 'trine'])
# (5, ['inserter', 'reinsert', 'reinters', 'rentiers', 'terrines'])
# (5, ['inset', 'neist', 'senti', 'stein', 'tines'])
# (5, ['insure', 'inures', 'rusine', 'urines', 'ursine'])
# (5, ['intreat', 'iterant', 'nattier', 'nitrate', 'tertian'])
# (5, ['karns', 'knars', 'narks', 'ranks', 'snark'])
# (5, ['lameness', 'maleness', 'maneless', 'nameless', 'salesmen'])
# (5, ['lapses', 'passel', 'saleps', 'sepals', 'spales'])
# (5, ['late', 'tael', 'tale', 'teal', 'tela'])
# (5, ['latrine', 'ratline', 'reliant', 'retinal', 'trenail'])
# (5, ['lave', 'leva', 'vale', 'veal', 'vela'])
# (5, ['laveers', 'leavers', 'reveals', 'several', 'vealers'])
# (5, ['leaser', 'reales', 'resale', 'reseal', 'sealer'])
# (5, ['leets', 'sleet', 'steel', 'stele', 'teles'])
# (5, ['leviers', 'relives', 'reviles', 'servile', 'veilers'])
# (5, ['list', 'lits', 'silt', 'slit', 'tils'])
# (5, ['lister', 'liters', 'litres', 'relist', 'tilers'])
# (5, ['loops', 'polos', 'pools', 'sloop', 'spool'])
# (5, ['loots', 'lotos', 'sotol', 'stool', 'tools'])
# (5, ['lopers', 'polers', 'proles', 'sloper', 'splore'])
# (5, ['lores', 'loser', 'orles', 'roles', 'sorel'])
# (5, ['manos', 'mason', 'moans', 'monas', 'nomas'])
# (5, ['mares', 'marse', 'maser', 'reams', 'smear'])
# (5, ['mate', 'meat', 'meta', 'tame', 'team'])
# (5, ['merit', 'miter', 'mitre', 'remit', 'timer'])
# (5, ['nows', 'owns', 'snow', 'sown', 'wons'])
# (5, ['ouster', 'outers', 'routes', 'souter', 'stoure'])
# (5, ['parers', 'parser', 'rapers', 'rasper', 'sparer'])
# (5, ['parleys', 'parsley', 'players', 'replays', 'sparely'])
# (5, ['part', 'prat', 'rapt', 'tarp', 'trap'])
# (5, ['partlets', 'platters', 'prattles', 'splatter', 'sprattle'])
# (5, ['pastries', 'piasters', 'piastres', 'raspiest', 'traipses'])
# (5, ['peins', 'penis', 'pines', 'snipe', 'spine'])
# (5, ['pintos', 'piston', 'pitons', 'points', 'postin'])
# (5, ['plisse', 'slipes', 'speils', 'spiels', 'spiles'])
# (5, ['pores', 'poser', 'prose', 'ropes', 'spore'])
# (5, ['poster', 'presto', 'stoper', 'topers', 'tropes'])
# (5, ['prides', 'prised', 'redips', 'spider', 'spired'])
# (5, ['ratos', 'roast', 'rotas', 'taros', 'toras'])
# (5, ['recused', 'reduces', 'rescued', 'secured', 'seducer'])
# (5, ['refits', 'resift', 'rifest', 'sifter', 'strife'])
# (5, ['resaws', 'sawers', 'sewars', 'swears', 'wrasse'])
# (5, ['resow', 'serow', 'sower', 'swore', 'worse'])
# (5, ['respects', 'scepters', 'sceptres', 'specters', 'spectres'])
# (5, ['restrain', 'retrains', 'strainer', 'terrains', 'trainers'])
# (5, ['retests', 'setters', 'streets', 'tersest', 'testers'])
# (5, ['riots', 'tiros', 'torsi', 'trios', 'trois'])
# (5, ['roost', 'roots', 'rotos', 'toros', 'torso'])
# (5, ['roset', 'rotes', 'store', 'tores', 'torse'])
# (5, ['rosets', 'sorest', 'stores', 'torses', 'tosser'])
# (5, ['rosiest', 'sorites', 'sorties', 'stories', 'trioses'])
# (5, ['roust', 'routs', 'stour', 'torus', 'tours'])
# (5, ['rowth', 'throw', 'whort', 'worth', 'wroth'])
# (5, ['rues', 'ruse', 'suer', 'sure', 'user'])
# (5, ['ryots', 'story', 'stroy', 'troys', 'tyros'])
# (5, ['skate', 'stake', 'steak', 'takes', 'teaks'])
# (5, ['spirt', 'sprit', 'stirp', 'strip', 'trips'])
# (5, ['state', 'taste', 'tates', 'teats', 'testa'])
# (5, ['stater', 'taster', 'taters', 'tetras', 'treats'])
# (6, ['acred', 'arced', 'cadre', 'cared', 'cedar', 'raced'])
# (6, ['aiders', 'deairs', 'irades', 'raised', 'redias', 'resaid'])
# (6, ['airts', 'astir', 'sitar', 'stair', 'stria', 'tarsi'])
# (6, ['alert', 'alter', 'artel', 'later', 'ratel', 'taler'])
# (6, ['alerting', 'altering', 'integral', 'relating', 'tanglier', 'triangle'])
# (6, ['alevin', 'alvine', 'valine', 'veinal', 'venial', 'vineal'])
# (6, ['aliens', 'alines', 'elains', 'lianes', 'saline', 'silane'])
# (6, ['aligners', 'engrails', 'nargiles', 'realigns', 'signaler', 'slangier'])
# (6, ['ardeb', 'barde', 'bared', 'beard', 'bread', 'debar'])
# (6, ['aretes', 'easter', 'eaters', 'reseat', 'seater', 'teaser'])
# (6, ['aril', 'lair', 'liar', 'lira', 'rail', 'rial'])
# (6, ['arils', 'lairs', 'liars', 'liras', 'rails', 'rials'])
# (6, ['ashed', 'deash', 'hades', 'heads', 'sadhe', 'shade'])
# (6, ['aspirer', 'parries', 'praiser', 'rapiers', 'raspier', 'repairs'])
# (6, ['bares', 'baser', 'bears', 'braes', 'saber', 'sabre'])
# (6, ['canter', 'centra', 'nectar', 'recant', 'tanrec', 'trance'])
# (6, ['canters', 'nectars', 'recants', 'scanter', 'tanrecs', 'trances'])
# (6, ['caress', 'carses', 'crases', 'escars', 'scares', 'seracs'])
# (6, ['carpels', 'clasper', 'parcels', 'placers', 'reclasp', 'scalper'])
# (6, ['claroes', 'coalers', 'escolar', 'oracles', 'recoals', 'solacer'])
# (6, ['corset', 'coster', 'escort', 'rectos', 'scoter', 'sector'])
# (6, ['cruet', 'curet', 'cuter', 'eruct', 'recut', 'truce'])
# (6, ['dater', 'derat', 'rated', 'tared', 'trade', 'tread'])
# (6, ['dearths', 'hardest', 'hardset', 'hatreds', 'threads', 'trashed'])
# (6, ['deers', 'drees', 'redes', 'reeds', 'seder', 'sered'])
# (6, ['deils', 'delis', 'idles', 'isled', 'sidle', 'slide'])
# (6, ['deltas', 'desalt', 'lasted', 'salted', 'slated', 'staled'])
# (6, ['deposit', 'dopiest', 'podites', 'posited', 'sopited', 'topside'])
# (6, ['diols', 'idols', 'lidos', 'sloid', 'soldi', 'solid'])
# (6, ['easters', 'reseats', 'searest', 'seaters', 'teasers', 'tessera'])
# (6, ['easting', 'eatings', 'ingates', 'ingesta', 'seating', 'teasing'])
# (6, ['elastin', 'entails', 'nailset', 'salient', 'saltine', 'tenails'])
# (6, ['enters', 'nester', 'rentes', 'resent', 'tenser', 'ternes'])
# (6, ['esprit', 'priest', 'ripest', 'sprite', 'stripe', 'tripes'])
# (6, ['esters', 'reests', 'resets', 'serest', 'steers', 'steres'])
# (6, ['estrange', 'grantees', 'greatens', 'negaters', 'reagents', 'sergeant'])
# (6, ['eviler', 'levier', 'liever', 'relive', 'revile', 'veiler'])
# (6, ['hales', 'heals', 'leash', 'selah', 'shale', 'sheal'])
# (6, ['hassel', 'hassle', 'lashes', 'selahs', 'shales', 'sheals'])
# (6, ['hectors', 'rochets', 'rotches', 'tochers', 'torches', 'troches'])
# (6, ['laves', 'salve', 'slave', 'vales', 'valse', 'veals'])
# (6, ['leapt', 'lepta', 'palet', 'petal', 'plate', 'pleat'])
# (6, ['leasts', 'slates', 'stales', 'steals', 'tassel', 'teslas'])
# (6, ['luster', 'lustre', 'result', 'rustle', 'sutler', 'ulster'])
# (6, ['lusters', 'lustres', 'results', 'rustles', 'sutlers', 'ulsters'])
# (6, ['mates', 'meats', 'satem', 'steam', 'tames', 'teams'])
# (6, ['notes', 'onset', 'seton', 'steno', 'stone', 'tones'])
# (6, ['opts', 'post', 'pots', 'spot', 'stop', 'tops'])
# (6, ['painters', 'pantries', 'pertains', 'pinaster', 'pristane', 'repaints'])
# (6, ['palters', 'persalt', 'plaster', 'platers', 'psalter', 'stapler'])
# (6, ['parties', 'pastier', 'piaster', 'piastre', 'pirates', 'traipse'])
# (6, ['parts', 'prats', 'sprat', 'strap', 'tarps', 'traps'])
# (6, ['paster', 'paters', 'prates', 'repast', 'tapers', 'trapes'])
# (6, ['petrous', 'posture', 'pouters', 'proteus', 'spouter', 'troupes'])
# (6, ['piles', 'plies', 'slipe', 'speil', 'spiel', 'spile'])
# (6, ['realist', 'retails', 'saltier', 'saltire', 'slatier', 'tailers'])
# (6, ['recepts', 'respect', 'scepter', 'sceptre', 'specter', 'spectre'])
# (6, ['reigns', 'renigs', 'resign', 'sering', 'signer', 'singer'])
# (6, ['reins', 'resin', 'rinse', 'risen', 'serin', 'siren'])
# (6, ['staw', 'swat', 'taws', 'twas', 'wast', 'wats'])
# (6, ['stow', 'swot', 'tows', 'twos', 'wost', 'wots'])
# (7, ['abets', 'baste', 'bates', 'beast', 'beats', 'betas', 'tabes'])
# (7, ['algins', 'aligns', 'lasing', 'liangs', 'ligans', 'lingas', 'signal'])
# (7, ['amens', 'manes', 'manse', 'means', 'mensa', 'names', 'nemas'])
# (7, ['angriest', 'astringe', 'ganister', 'gantries', 'granites', 'ingrates', 'rangiest'])
# (7, ['ardebs', 'bardes', 'beards', 'breads', 'debars', 'sabred', 'serdab'])
# (7, ['ares', 'arse', 'ears', 'eras', 'rase', 'sear', 'sera'])
# (7, ['aridest', 'astride', 'diaster', 'disrate', 'staider', 'tardies', 'tirades'])
# (7, ['ariled', 'derail', 'dialer', 'laired', 'railed', 'redial', 'relaid'])
# (7, ['armets', 'master', 'maters', 'matres', 'ramets', 'stream', 'tamers'])
# (7, ['arrest', 'rarest', 'raster', 'raters', 'starer', 'tarres', 'terras'])
# (7, ['artiest', 'artiste', 'attires', 'iratest', 'ratites', 'striate', 'tastier'])
# (7, ['aspen', 'napes', 'neaps', 'panes', 'peans', 'sneap', 'spean'])
# (7, ['caret', 'carte', 'cater', 'crate', 'react', 'recta', 'trace'])
# (7, ['cruets', 'cruset', 'curets', 'eructs', 'rectus', 'recuts', 'truces'])
# (7, ['deist', 'diets', 'dites', 'edits', 'sited', 'stied', 'tides'])
# (7, ['drapes', 'padres', 'parsed', 'rasped', 'spader', 'spared', 'spread'])
# (7, ['emits', 'items', 'metis', 'mites', 'smite', 'stime', 'times'])
# (7, ['empires', 'emprise', 'epimers', 'imprese', 'premies', 'premise', 'spireme'])
# (7, ['enosis', 'eosins', 'essoin', 'noesis', 'noises', 'ossein', 'sonsie'])
# (7, ['esprits', 'persist', 'priests', 'spriest', 'sprites', 'stirpes', 'stripes'])
# (7, ['ester', 'reest', 'reset', 'steer', 'stere', 'terse', 'trees'])
# (7, ['estrous', 'oestrus', 'ousters', 'sourest', 'souters', 'stoures', 'tussore'])
# (7, ['lavers', 'ravels', 'salver', 'serval', 'slaver', 'velars', 'versal'])
# (7, ['merits', 'mister', 'miters', 'mitres', 'remits', 'smiter', 'timers'])
# (7, ['nestor', 'noters', 'stoner', 'tenors', 'tensor', 'toners', 'trones'])
# (7, ['paste', 'pates', 'peats', 'septa', 'spate', 'tapes', 'tepas'])
# (7, ['peers', 'peres', 'perse', 'prees', 'prese', 'speer', 'spree'])
# (7, ['resaw', 'sawer', 'sewar', 'sware', 'swear', 'wares', 'wears'])
# (8, ['acers', 'acres', 'cares', 'carse', 'escar', 'races', 'scare', 'serac'])
# (8, ['anestri', 'nastier', 'ratines', 'retains', 'retinas', 'retsina', 'stainer', 'stearin'])
# (8, ['arles', 'earls', 'lares', 'laser', 'lears', 'rales', 'reals', 'seral'])
# (8, ['aspers', 'parses', 'passer', 'prases', 'repass', 'spares', 'sparse', 'spears'])
# (8, ['ates', 'east', 'eats', 'etas', 'sate', 'seat', 'seta', 'teas'])
# (8, ['carets', 'cartes', 'caster', 'caters', 'crates', 'reacts', 'recast', 'traces'])
# (8, ['earings', 'erasing', 'gainers', 'reagins', 'regains', 'reginas', 'searing', 'seringa'])
# (8, ['lapse', 'leaps', 'pales', 'peals', 'pleas', 'salep', 'sepal', 'spale'])
# (8, ['palest', 'palets', 'pastel', 'petals', 'plates', 'pleats', 'septal', 'staple'])
# (8, ['peris', 'piers', 'pries', 'prise', 'ripes', 'speir', 'spier', 'spire'])
# (9, ['capers', 'crapes', 'escarp', 'pacers', 'parsec', 'recaps', 'scrape', 'secpar', 'spacer'])
# (9, ['estrin', 'inerts', 'insert', 'inters', 'niters', 'nitres', 'sinter', 'triens', 'trines'])
# (10, ['least', 'setal', 'slate', 'stale', 'steal', 'stela', 'taels', 'tales', 'teals', 'tesla'])
# (11, ['alerts', 'alters', 'artels', 'estral', 'laster', 'ratels', 'salter', 'slater', 'staler', 'stelar', 'talers'])
# (11, ['apers', 'asper', 'pares', 'parse', 'pears', 'prase', 'presa', 'rapes', 'reaps', 'spare', 'spear'])

# %% [markdown]
# Solução do autor:

# %%
def signature(s):
    """Returns the signature of this string, which is a string
    that contains all of the letters in order.
    """
    t = list(s)
    t.sort()
    t = ''.join(t)
    return t

# %%
def all_anagrams(filename):
    """Finds all anagrams in a list of words.

    filename: string filename of the word list

    Returns: a map from each word to a list of its anagrams.
    """
    d = {}
    for line in open(filename):
        word = line.strip().lower()
        t = signature(word)

        if t not in d:
            d[t] = [word]
        else:
            d[t].append(word)
    return d

# %%
def print_anagram_sets(d):
    """Prints the anagram sets in d.

    d: map from words to list of their anagrams
    """
    for v in d.values():
        if len(v) > 1:
            print(len(v), v)

# %%
def print_anagram_sets_in_order(d):
    """Prints the anagram sets in d in decreasing order of size.

    d: map from words to list of their anagrams
    """

    # make a list of (length, word pairs)
    t = []
    for v in d.values():
        if len(v) > 1:
            t.append((len(v), v))

    # sort in ascending order of length
    t.sort()

    # print the sorted list
    for x in t:
        print(x)

# %%
def filter_length(d, n):
    """Select only the words in d that have n letters.

    d: map from word to list of anagrams
    n: integer number of letters

    Returns: new map from word to list of anagrams
    """
    res = {}
    for word, anagrams in d.items():
        if len(word) == n:
            res[word] = anagrams
    return res

# %%
if __name__ == '__main__':
    anagram_dict = {}
    anagram_dict = all_anagrams('words.txt')
    
    metatese_test(anagram_dict)
    # a solucao deu levemente diferente da do autor, pois os valores associados as chaves podem ser múltiplos
# Out:
['artels'], 'artels': ['ratels'], 'laster': ['salter'], 'salter': ['slater'], 'slater': ['staler'], 'staler': ['stelar'], 'lase': ['sale'], 'leas': ['seal'], 'veinal': ['venial'], 'venial': ['vineal'], 'releasing': ['resealing'], 'algin': ['align'], 'algins': ['aligns'], 'algor': ['argol'], 'algors': ['argols'], 'algum': ['almug'], 'algums': ['almugs'], 'alien': ['aline'], 'aline': ['anile'], 'aliens': ['alines'], 'saline': ['silane'], 'dealing': ['leading'], 'lati': ['tali'], 'tail': ['tali'], 'alkalies': ['alkalise'], 'alma': ['lama'], 'almas': ['lamas'], 'alme': ['lame'], 'lame': ['male'], 'almes': ['lames'], 'lames': ['males'], 'alms': ['lams'], 'aloft': ['float'], 'float': ['flota'], 'alone': ['anole'], 'alow': ['awol'], 'alp': ['lap'], 'lap': ['pal'], 'penial': ['pineal'], 'alps': ['laps'], 'laps': ['pals'], 'pals': ['salp'], 'salp': ['slap'], 'alt': ['lat'], 'altar': ['artal'], 'artal': ['ratal'], 'realters': ['relaters'], 'loath': ['lotah'], 'altitude': ['latitude'], 'altitudes': ['latitudes'], 'lota': ['tola'], 'lotas': ['tolas'], 'altruism': ['ultraism'], 'altruisms': ['ultraisms'], 'altruist': ['ultraist'], 'altruists': ['ultraists'], 'alts': ['lats'], 'last': ['lats', 'salt'], 'salt': ['slat'], 'alumin': ['alumni'], 'am': ['ma'], 'amain': ['amnia'], 'amnia': ['mania'], 'amber': ['embar' ...
# 3134

# %% [markdown]
# Solução do autor:

# %%
def word_distance(word1, word2):
    """Computes the number of differences between two words.

    word1, word2: strings

    Returns: integer
    """
    assert len(word1) == len(word2)

    count = 0
    for c1, c2 in zip(word1, word2):
        if c1 != c2:
            count += 1

    return count

# %%
if __name__ == '__main__':
    d = all_anagrams('words.txt')
    metathesis_pairs(d)
# Out:
# aah aha
# aal ala
# aals alas
# aba baa
# abas baas
# abbe babe
# abbes babes
# bate beta
# beat beta
# bates betas
# bates tabes
# beast beats
# beats betas
# abide abied
# able bale
# bale blae
# abler baler
# ables bales
# abmho abohm
# abmhos abohms
# abode adobe
# abodes adobes
# tabu tuba
# tabus tubas
# aby bay
# abyed bayed
# abying baying
# abys bays
# accouter accoutre
# accouters accoutres
# cade dace
# acers acres
# acres cares
# cares carse
# cares races
# achier cahier
# acid caid
# cadi caid
# acids caids
# cadis caids
# acme came
# came mace
# acmes cames
# cames maces
# acne cane
# acned caned
# acnes canes
# acre care
# care race
# acred arced
# acred cared
# arced raced
# cared raced
# act cat
# actin antic
# actins antics
# action cation
# actions cations
# castor costar
# acts cats
# cast cats
# ad da
# add dad
# adds dads
# pated taped
# adman daman
# maned menad
# maned named
# adze daze
# adzes dazes
# aerologies areologies
# aerology areology
# hereat reheat
# aetheric hetaeric
# aft fat
# age gae
# aged egad
# aged gaed
# rages sager
# ages gaes
# agger eggar
# agger gager
# aggers eggars
# aggers gagers
# sagger seggar
# saggers seggars
# agin gain
# agonies agonise
# eager eagre
# eager ragee
# eagre ragee
# eagers eagres
# eagers ragees
# eagres ragees
# ah ha
# ahem haem
# haem hame
# aider aired
# daimen maiden
# dais said
# sadi said
# ailment aliment
# ailments aliments
# sail sial
# aim ami
# armies ramies
# aims amis
# aims sima
# ain ani
# ains anis
# arising raising
# resails serails
# serails serials
# rain rani
# naris ranis
# naris sarin
# rains ranis
# stair stria
# akin kain
# alan anal
# alb lab
# bal lab
# baals balas
# balas balsa
# balas basal
# albs labs
# bals labs
# alburnum laburnum
# alburnums laburnums
# alder lader
# alders laders
# aldol allod
# aldols allods
# alef flea
# feal leaf
# alefs fleas
# alter artel
# alter later
# artel ratel
# later ratel
# later taler
# realter relater
# alters artels
# artels ratels
# laster salter
# salter slater
# slater staler
# staler stelar
# lase sale
# leas seal
# veinal venial
# venial vineal
# releasing resealing
# algin align
# algins aligns
# algor argol
# algors argols
# algum almug
# algums almugs
# alien aline
# aline anile
# aliens alines
# saline silane
# dealing leading
# lati tali
# tail tali
# alkalies alkalise
# alma lama
# almas lamas
# alme lame
# lame male
# almes lames
# lames males
# alms lams
# aloft float
# float flota
# alone anole
# alow awol
# alp lap
# lap pal
# penial pineal
# alps laps
# laps pals
# pals salp
# salp slap
# alt lat
# altar artal
# artal ratal
# realters relaters
# loath lotah
# altitude latitude
# altitudes latitudes
# lota tola
# lotas tolas
# altruism ultraism
# altruisms ultraisms
# altruist ultraist
# altruists ultraists
# alts lats
# last lats
# last salt
# salt slat
# alumin alumni
# am ma
# amain amnia
# amnia mania
# amber embar
# ambers embars
# bedlam beldam
# marble ramble
# marbles rambles
# mane name
# name nema
# manes manse
# manes names
# manse mensa
# names nemas
# amid maid
# amids maids
# amigo imago
# amin main
# amine anime
# amines animes
# amins mains
# amir mair
# amirs mairs
# ammine immane
# amnic manic
# amp map
# map pam
# ample maple
# amps maps
# maps pams
# pams samp
# an na
# anas ansa
# anchor archon
# anchors archons
# ane nae
# leaden leaned
# ratines retinas
# retains retsina
# angel angle
# angels angles
# ranges sanger
# anil nail
# lain nail
# anils nails
# slain snail
# sanies sansei
# tetanies tetanise
# khans shank
# anna nana
# annas nanas
# anoxic axonic
# anserous arsenous
# antes nates
# antimonies antinomies
# antimony antinomy
# saint tains
# satin stain
# nival vinal
# any nay
# pare rape
# pear reap
# pares parse
# pares rapes
# parse prase
# pears reaps
# prase presa
# apes apse
# apse pase
# apse spae
# appal papal
# appel apple
# appels apples
# apses pases
# apses spaes
# pases passe
# apsis aspis
# apt pat
# pat tap
# apter pater
# pater taper
# aptly patly
# aptness patness
# aptnesses patnesses
# chares chaser
# arcing racing
# caring racing
# arcked racked
# carked racked
# dacker racked
# arcking racking
# carking racking
# arco orca
# causers saucers
# barde bared
# are era
# ear era
# ares arse
# ares eras
# arse rase
# ears eras
# sear sera
# seater teaser
# argal graal
# argals graals
# argil grail
# glair grail
# argils grails
# glairs grails
# argon organ
# groan organ
# argons organs
# groans organs
# gaurs guars
# aria raia
# arias raias
# arid raid
# arider raider
# resail serail
# serail serial
# treaties treatise
# aril rail
# lair liar
# lair rail
# liar lira
# liar rial
# rail rial
# ariled railed
# laired railed
# arils rails
# lairs liars
# lairs rails
# liars liras
# liars rials
# rails rials
# arise raise
# arises raises
# riatas tiaras
# arles rales
# earls lares
# lares laser
# lares rales
# lears reals
# arm ram
# mar ram
# armet ramet
# mater tamer
# ramet tamer
# armets ramets
# maters matres
# maters tamers
# ramets tamers
# armoires armories
# arms rams
# mars rams
# arrest rarest
# tarres terras
# ars ras
# arses rases
# art rat
# rat tar
# strait strati
# lasters salters
# salters slaters
# arts rats
# rats tars
# star tsar
# arty tray
# coast coats
# coats costa
# hassels hassles
# asker eskar
# asker saker
# rakes saker
# askers eskars
# askers sakers
# wakes wekas
# asp sap
# pas sap
# sap spa
# napes panes
# neaps peans
# sneap spean
# sneaps speans
# parses passer
# parses prases
# spares sparse
# paresis parises
# parises praises
# asps saps
# pass saps
# saps spas
# assert asters
# serrates terrases
# assertor assorter
# assertors assorters
# rates tares
# at ta
# ate eta
# ate tae
# eat eta
# eat tae
# eta tea
# tae tea
# ates etas
# east eats
# eats etas
# eats sate
# etas teas
# sate seta
# seat seta
# seat teas
# rattish tartish
# atlas talas
# osmatic somatic
# atomies atomise
# atoms stoma
# riata tiara
# nattered rattened
# aunt tuna
# aunts tunas
# urase ursae
# ureas ursae
# auric curia
# saliva salvia
# naves vanes
# raves saver
# save vase
# avo ova
# awe wae
# awes waes
# awn wan
# awned waned
# dawen dewan
# awning waning
# awns wans
# sawn swan
# snaw swan
# awny wany
# awry wary
# axel axle
# axels axles
# axemen examen
# ay ya
# ayes eyas
# eyas yeas
# babul bubal
# babuls bubals
# bad dab
# badger barged
# barged garbed
# bads dabs
# bag gab
# bags gabs
# baht bath
# bahts baths
# balded bladed
# ban nab
# bans nabs
# bar bra
# barbet rabbet
# barbets rabbets
# bard brad
# bard darb
# brad drab
# darb drab
# bards brads
# bards darbs
# brads drabs
# darbs drabs
# bare brae
# bear brae
# barege bargee
# bareges bargees
# barely barley
# barer barre
# bares baser
# bares braes
# baser saber
# bears braes
# saber sabre
# barging garbing
# baric rabic
# barked braked
# barkier brakier
# barkiest brakiest
# barking braking
# barky braky
# barn bran
# barns brans
# barret barter
# barrets barters
# barrette berretta
# barrettes berrettas
# bars bras
# bas sab
# base sabe
# based sabed
# bases sabes
# basest basset
# basset bastes
# basin sabin
# nabis sabin
# basins sabins
# basis bassi
# bass sabs
# bast bats
# bats tabs
# bat tab
# baud daub
# bauds daubs
# bayadeer bayadere
# bayadeers bayaderes
# beam bema
# beams bemas
# berate rebate
# berates rebates
# becrust becurst
# bed deb
# bedlams beldams
# bidder birded
# bedrug redbug
# bedrugged begrudged
# bedrugging begrudging
# bedrugs redbugs
# beds debs
# been bene
# beer bree
# beers brees
# belated bleated
# belt blet
# belts blets
# blest blets
# bemire berime
# berime bireme
# bemired berimed
# bemires berimes
# berimes biremes
# bemiring beriming
# ben neb
# bens nebs
# beraking breaking
# berated rebated
# debater rebated
# berating rebating
# beslime besmile
# beslimed besmiled
# beslimes besmiles
# besliming besmiling
# best bets
# bestir bister
# bister bistre
# bestirs bisters
# bisters bistres
# bestrid bistred
# bestud busted
# bey bye
# beys byes
# bibs sibb
# bicorn bicron
# bid dib
# bids dibs
# big gib
# bigly bilgy
# bike kibe
# bikes kibes
# biltong bolting
# limbate timbale
# bin nib
# bins nibs
# bionic niobic
# birder birred
# bis sib
# blankest blankets
# blast blats
# blot bolt
# blots bolts
# blouses boluses
# bluest bluets
# bustle subtle
# bluesy blueys
# umbels umbles
# blurs slurb
# boar bora
# boars boras
# boast boats
# bodies dobies
# body doby
# bog gob
# bogan goban
# bogans gobans
# bogies gobies
# bogs gobs
# bogy goby
# bolar lobar
# labor lobar
# bolder bordel
# bole lobe
# boles lobes
# bolo lobo
# bolos lobos
# bolster lobster
# bolsters lobsters
# bombed mobbed
# bomber mobber
# bombers mobbers
# bombing mobbing
# bonus bosun
# booger goober
# boogers goobers
# boor broo
# boors broos
# boost boots
# bore robe
# bored robed
# orbed robed
# bores robes
# robes sober
# boring robing
# orbing robing
# bos sob
# boss sobs
# botanies botanise
# unrobes unsober
# brag grab
# garb grab
# brags grabs
# garbs grabs
# brede breed
# bredes breeds
# dibber ribbed
# fiber fibre
# fibers fibres
# briskest briskets
# omber ombre
# ombers ombres
# somber sombre
# bromo broom
# bromos brooms
# brugh burgh
# brughs burghs
# bruin burin
# bruins burins
# buries busier
# buries rubies
# brunet burnet
# brunets burnets
# brunt burnt
# bud dub
# buds dubs
# bugle bulge
# bugled bulged
# bugler bulger
# buglers bulgers
# bugles bulges
# bugling bulging
# bun nub
# buns nubs
# bur rub
# unbar urban
# buras bursa
# burble rubble
# burbled rubbled
# burbles rubbles
# burblier rubblier
# burbliest rubbliest
# burbling rubbling
# burbly rubbly
# burden burned
# buried rubied
# burier rubier
# burkes busker
# burs rubs
# rebus rubes
# rubes suber
# bury ruby
# burying rubying
# bus sub
# buss subs
# bust buts
# buts tubs
# cubist cubits
# busy buys
# but tub
# cadaster cadastre
# cadasters cadastres
# cades cased
# cades daces
# sacred scared
# caestus cuestas
# cafe face
# cafes faces
# caliber calibre
# calibers calibres
# calk lack
# calked lacked
# calker lacker
# calkers lackers
# calking lacking
# calks lacks
# caller cellar
# callers cellars
# calm clam
# calms clams
# calque claque
# calques claques
# calve clave
# cam mac
# caramel ceramal
# cams macs
# discanted distanced
# caners casern
# canine cannie
# ceratins creatins
# cannot canton
# canst cants
# decanter recanted
# cantor carton
# carton craton
# cantors cartons
# cartons cratons
# cap pac
# cape pace
# caped paced
# caper pacer
# capers pacers
# capes paces
# scape space
# caps pacs
# caption paction
# captions pactions
# captor cartop
# caramels ceramals
# carbon corban
# carbons corbans
# triacids triadics
# carer racer
# carers racers
# caress carses
# carses crases
# caret carte
# caret cater
# carte crate
# crate trace
# carets cartes
# carets caters
# cartes caster
# cartes crates
# crates traces
# caries cerias
# cark rack
# carks racks
# carn narc
# carns narcs
# carol coral
# carols corals
# carp crap
# carped craped
# carpel parcel
# carpels parcels
# scarper scraper
# carping craping
# scarping scraping
# carps craps
# scarp scrap
# carted crated
# crated traced
# carter crater
# crater tracer
# carters craters
# craters tracers
# carting crating
# crating tracing
# carve crave
# carved craved
# carven craven
# carver craver
# carvers cravers
# carves craves
# carving craving
# carvings cravings
# cascabel cascable
# cascabels cascables
# cascade saccade
# cascades saccades
# chases chasse
# cask sack
# casked sacked
# casking sacking
# casks sacks
# casque sacque
# casques sacques
# cassock cossack
# cassocks cossacks
# caste cesta
# cates taces
# castes cestas
# castors costars
# casual causal
# casually causally
# casuals causals
# cate tace
# cerated created
# recrate retrace
# retrace terrace
# recrates retraces
# retraces terraces
# cause sauce
# caused sauced
# causer saucer
# causes sauces
# causing saucing
# ceder cered
# cered creed
# center centre
# decenter decentre
# centers centres
# cento conte
# centos contes
# cerate create
# cerates creates
# ceratin certain
# ceratin creatin
# cerci ceric
# ceruse recuse
# recuse secure
# cerite recite
# cerites recites
# cero core
# ceros cores
# cores corse
# course source
# certes terces
# certification rectification
# certifications rectifications
# certified rectified
# certifier rectifier
# certifiers rectifiers
# certifies rectifies
# certify rectify
# certifying rectifying
# certitude rectitude
# certitudes rectitudes
# ceruses recuses
# recuses secures
# cervices crevices
# cess secs
# latches satchel
# chams chasm
# chancres cranches
# snatcher stancher
# snatch stanch
# sachet taches
# snatches stanches
# chicle cliche
# chicles cliches
# chiel chile
# chiels chiles
# chiles chisel
# inched niched
# inches niches
# inching niching
# chopine phocine
# ocher ochre
# oraches roaches
# ochers ochres
# citherns cithrens
# cider dicer
# dicer riced
# ciders dicers
# cine nice
# cion coin
# cion icon
# coin coni
# cions coins
# cions icons
# cipolin picolin
# cipolins picolins
# cithern cithren
# tetracid tetradic
# citrin nitric
# clanged glanced
# clanging glancing
# claps clasp
# clematis climates
# clod cold
# clods colds
# closest closets
# clot colt
# clots colts
# cloy coly
# clutch cultch
# clutches cultches
# coal cola
# cola loca
# coals colas
# coax coxa
# cod doc
# codder corded
# code coed
# coden coned
# coder cored
# codes coeds
# codex coxed
# cods docs
# cohered ochered
# cohering ochering
# fico foci
# coinfer conifer
# coinfers conifers
# collide collied
# colonies colonise
# combat tombac
# combats tombacs
# comet comte
# comets comtes
# compeer compere
# compeers comperes
# compiled complied
# compiler complier
# compilers compliers
# compiles complies
# complaint compliant
# concent connect
# concents connects
# concerted concreted
# concerting concreting
# condoles consoled
# condor cordon
# condors cordons
# conk nock
# conked nocked
# conking nocking
# conks nocks
# conservation conversation
# conservations conversations
# conserve converse
# conserved conversed
# conserves converses
# conserving conversing
# copes copse
# copula cupola
# copulas cupolas
# cork rock
# corked rocked
# docker rocked
# corker rocker
# corkers rockers
# corkier rockier
# corkiest rockiest
# corking rocking
# corklike rocklike
# corks rocks
# corky rocky
# corny crony
# coroner crooner
# coroners crooners
# corps crops
# electors electros
# rectos sector
# coset cotes
# cost cots
# costumer customer
# costumers customers
# cosy coys
# coude douce
# courses sources
# couth touch
# couther toucher
# couthier touchier
# couthiest touchiest
# coves voces
# lascar rascal
# crafted fracted
# recrated retraced
# retraced terraced
# recrating retracing
# retracing terracing
# creep crepe
# creeps crepes
# creepy crepey
# crud curd
# cruds curds
# cruet curet
# cruet eruct
# curet cuter
# eruct truce
# cruets curets
# cruets eructs
# eructs truces
# rectus recuts
# crus curs
# cruse curse
# cures curse
# cruses curses
# curses cusser
# crust curst
# cud duc
# cuds ducs
# cumin mucin
# cumins mucins
# cups cusp
# curacao curacoa
# curacaos curacoas
# curdier curried
# curtesy curtsey
# cusk suck
# cusks sucks
# cutesy cuteys
# cylix xylic
# dabbler rabbled
# daddles saddled
# dafter rafted
# farted rafted
# dag gad
# dagger ragged
# dags gads
# dah had
# dahs dash
# dairies diaries
# dairy diary
# dairy yaird
# hankered harkened
# dale lade
# deal lead
# dales lades
# deals leads
# lades lased
# dalles ladles
# dallier rallied
# dallies sallied
# dam mad
# dame made
# dammer rammed
# demander remanded
# damper ramped
# dams mads
# monads nomads
# danger gander
# danger ranged
# gander garden
# dangered gandered
# gandered gardened
# dangering gandering
# gandering gardening
# dangers ganders
# ganders gardens
# danker darken
# danker ranked
# darken narked
# narked ranked
# dap pad
# dapper rapped
# daps pads
# dear read
# dears reads
# darling larding
# darn nard
# nard rand
# darns nards
# nards rands
# dart drat
# drat trad
# darts drats
# shader shared
# dashes sadhes
# dashes sashed
# sadhes sashed
# dater rated
# rated tared
# dates sated
# stade tsade
# doat toad
# doats toads
# daw wad
# dawdle waddle
# dawdled waddled
# dawdler waddler
# dawdlers waddlers
# dawdles waddles
# dawdling waddling
# dawed waded
# dawing wading
# daws wads
# deaden deaned
# dealer leader
# dealers leaders
# dealings leadings
# dearer reader
# dearer reared
# reader reared
# redear reread
# redates sedater
# dearies readies
# hardest hardset
# deary deray
# deary ready
# deceiver received
# decenters decentres
# deckel deckle
# deckels deckles
# decker recked
# decliner reclined
# recedes seceder
# radicel radicle
# radicels radicles
# dedans desand
# sadden sanded
# deuced educed
# deduces seduced
# deem deme
# deem meed
# deems demes
# deems meeds
# deep peed
# deer dere
# deer dree
# deer reed
# dere dree
# dere rede
# rede reed
# deers drees
# deers reeds
# redes reeds
# redes seder
# seder sered
# dees seed
# defacer refaced
# defer refed
# deferrer referred
# defiler refiled
# definer refined
# deflower reflowed
# deformer reformed
# degrader regraded
# regarded regraded
# dei die
# deification edification
# deifications edifications
# deified edified
# deifier edifier
# deifier reified
# deifies edifies
# deify edify
# deifying edifying
# signed singed
# deil deli
# deil diel
# diel lied
# deils delis
# idles isled
# diets dites
# dites sited
# dites tides
# sited stied
# del led
# eld led
# delayer relayed
# sleeted steeled
# listed silted
# deliver relived
# relived reviled
# silvered slivered
# lasted salted
# salted slated
# slated staled
# insouled unsoiled
# demies demise
# demo dome
# dome mode
# demos domes
# domes modes
# denes dense
# denotation detonation
# denotations detonations
# dens send
# send sned
# denser sender
# dent tend
# dented tended
# indent intend
# denting tending
# indents intends
# dents tends
# deny dyne
# parted prated
# deposer reposed
# podites posited
# posited sopited
# desired resided
# deviser revised
# derries redries
# derries serried
# desirer resider
# desirers residers
# elver lever
# lever revel
# elvers levers
# levers revels
# em me
# seem seme
# regimes remiges
# mire rime
# mires miser
# mires rimes
# mite time
# emits smite
# metis mites
# mites times
# smite stime
# emprise imprese
# premies premise
# emprises impreses
# encoder encored
# endue undee
# endues ensued
# endures ensured
# energies energise
# enisle ensile
# enisled ensiled
# enisles ensiles
# enisling ensiling
# leno lone
# enologies neologies
# enology neology
# essoin ossein
# noesis noises
# enrol nerol
# enrols nerols
# terreen terrene
# terreens terrenes
# tenia tinea
# entires entries
# latrines ratlines
# eons noes
# eons sone
# noes nose
# noes ones
# nose sone
# phase shape
# epics spice
# epos opes
# peso pose
# epoxide epoxied
# er re
# ere ree
# goer gore
# gore ogre
# eros ores
# ores roes
# roes rose
# rose sore
# ers res
# res ser
# seers seres
# erst rest
# rest rets
# rogue rouge
# rogues rouges
# liver livre
# liver viler
# livers livres
# silver sliver
# eses sees
# lapises lipases
# sprite stripe
# sprites stripes
# stirpes stripes
# essoins osseins
# reest reset
# steer stere
# reests resets
# steers steres
# ptoses stopes
# insert inters
# inters niters
# niters nitres
# triens trines
# loiters toilers
# russet tusser
# etched teched
# there three
# theres threes
# shote those
# eulogies eulogise
# roues rouse
# eve vee
# neves seven
# ever veer
# revest revets
# verset verste
# every veery
# eves vees
# evil veil
# live vile
# eviler veiler
# relive revile
# lively vilely
# liveness vileness
# livenesses vilenesses
# evils veils
# ewe wee
# ewer weer
# weer were
# sewer sweer
# ewes wees
# example exempla
# except expect
# excepted expected
# excepting expecting
# excepts expects
# excides excised
# exist exits
# exploder explored
# eyen eyne
# eyers eyres
# fader fared
# fain naif
# fair fiar
# fairs fiars
# fakir kafir
# fakirs kafirs
# falcon flacon
# falcons flacons
# faltboat flatboat
# faltboats flatboats
# fare frae
# fear frae
# farmable framable
# farmed framed
# farmer framer
# farmers framers
# farming framing
# faro fora
# fart frat
# fart raft
# farting rafting
# farts frats
# farts rafts
# fast fats
# fate feta
# feat feta
# fates fetas
# feast feats
# feats fetas
# fealty featly
# reefed refeed
# feel flee
# feeling fleeing
# feels flees
# feet fete
# felid filed
# field filed
# filed flied
# felt left
# felts lefts
# femur fumer
# femurs fumers
# fer ref
# fere free
# feres frees
# ferine refine
# ferlies reflies
# refiles reflies
# ferly refly
# ferried refried
# refired refried
# ferries refries
# refires refries
# ferritic terrific
# ferry refry
# ferrying refrying
# fortes foster
# foster softer
# fief fife
# fiefs fifes
# fiend fined
# flair frail
# file life
# lief life
# filer flier
# filer lifer
# filers fliers
# filers lifers
# files flies
# filter lifter
# filters lifters
# fire rife
# fired fried
# firer frier
# firer rifer
# firers friers
# fires fries
# fries frise
# firth frith
# firths friths
# fist fits
# fist sift
# fisted sifted
# fisting sifting
# fists sifts
# flairs frails
# floats flotas
# flooder floored
# flour fluor
# flours fluors
# fluty fluyt
# foal loaf
# foaled loafed
# foaling loafing
# foals loafs
# focuses fucoses
# fodder forded
# foetor footer
# foetors footers
# fool loof
# fools loofs
# for fro
# foramen foreman
# fore froe
# fores froes
# form from
# forth froth
# forward froward
# infarct infract
# freer frere
# freers freres
# freshest freshets
# fret tref
# frumenties furmenties
# frumenty furmenty
# furs surf
# gaddi gadid
# gaddis gadids
# gaen gane
# gal lag
# gelatine legatine
# gallate galleta
# gallate tallage
# gallates galletas
# gallates tallages
# gals lags
# gam mag
# gambler gambrel
# gamblers gambrels
# game mage
# games mages
# gamic magic
# gamma magma
# gammas magmas
# gams mags
# gan nag
# ganged nagged
# ganger nagger
# gangers naggers
# ganging nagging
# gaol goal
# gaoled goaled
# gaoling goaling
# gaols goals
# gape page
# gaped paged
# gapes pages
# gaping paging
# gaps gasp
# gar rag
# gargle raggle
# gargles raggles
# garment margent
# garmented margented
# garmenting margenting
# garments margents
# garret garter
# garter grater
# garrets garters
# garters graters
# gars rags
# gas sag
# gases sages
# gast gats
# gats tags
# gat tag
# gateway getaway
# gateways getaways
# magus sagum
# gaun guan
# gaur guar
# gayer yager
# gel leg
# gelated legated
# gelating legating
# gelation legation
# gelations legations
# geld gled
# gelds gleds
# gels legs
# genets gentes
# genro negro
# sleeting steeling
# genus negus
# genuses neguses
# gerent regent
# gerents regents
# maligner malinger
# gest gets
# gets tegs
# get teg
# ghast ghats
# gilded glided
# gilder glider
# gilders gliders
# gilding gliding
# ginger nigger
# gingers niggers
# gingko ginkgo
# gingkoes ginkgoes
# gink king
# ginks kings
# gins sing
# sign sing
# gip pig
# gips pigs
# gird grid
# girded grided
# girding griding
# girds grids
# girn grin
# girns grins
# girt grit
# grit trig
# girth grith
# girths griths
# girts grits
# grist grits
# grits trigs
# glans slang
# glass slags
# glede gleed
# gledes gleeds
# singlet tingles
# gloss slogs
# glover grovel
# glovers grovels
# gluer gruel
# gluers gruels
# glues gules
# gules luges
# hangs sangh
# gnu gun
# gnus guns
# gnus snug
# guns sung
# snug sung
# godling lodging
# godlings lodgings
# goers gores
# gores gorse
# gores ogres
# goglets loggets
# goiter goitre
# goiters goitres
# gong nogg
# gonging nogging
# gongs noggs
# gory gyro
# got tog
# grandam grandma
# grandams grandmas
# targe terga
# rating taring
# grip prig
# grips prigs
# underdog undergod
# gurged rugged
# grummest grummets
# guides guised
# gul lug
# guls lugs
# gum mug
# gums mugs
# gunless gunsels
# gurging rugging
# gush sugh
# hugs sugh
# gushed sughed
# gushing sughing
# gust guts
# guts tugs
# gustier gutsier
# gustiest gutsiest
# gusty gutsy
# gut tug
# gutless tugless
# hade haed
# haed head
# haems hames
# haets haste
# haets hates
# haets heats
# hahs hash
# hallo holla
# halloed hollaed
# halloing hollaing
# halloo holloa
# hallooed holloaed
# hallooing holloaing
# halloos holloas
# hallos hollas
# handles handsel
# handless handsels
# hanker harken
# hankerer harkener
# hankerers harkeners
# hankering harkening
# hankers harkens
# hap pah
# haps hasp
# hasp pash
# haptene heptane
# haptenes heptanes
# hardier harried
# rheas shear
# haslets hatless
# hasped pashed
# phased shaped
# hasping pashing
# phasing shaping
# hassel hassle
# hast hats
# hay yah
# rochet tocher
# rochets tochers
# rotches torches
# torches troches
# hegari hegira
# hegaris hegiras
# shier shire
# helios holies
# henequin heniquen
# henequins heniquens
# shent thens
# pastiche pistache
# sherd shred
# hereto hetero
# shoer shore
# hey yeh
# hide hied
# hider hired
# shriek shrike
# hins hisn
# hins sinh
# phis ship
# hirsel hirsle
# hirsels hirsles
# shiers shires
# hist hits
# hits sith
# shit this
# shist shits
# hitter tither
# hitters tithers
# hitting tithing
# ho oh
# hoar hora
# hoars horas
# hoed ohed
# hoes hose
# holes hosel
# homage ohmage
# homages ohmages
# hones hosen
# hones nohes
# hoop pooh
# hooped poohed
# hooping poohing
# hoops poohs
# hoots sooth
# hop poh
# hops soph
# posh soph
# hordes horsed
# shoers shores
# host hots
# host tosh
# hots soth
# soth tosh
# hotter tother
# huddler hurdled
# hurtles hustler
# hurtless hustlers
# shut thus
# pythonic typhonic
# icecap ipecac
# icecaps ipecacs
# idly idyl
# kino oink
# kinos oinks
# ileus lieus
# illicit illitic
# illy lily
# lily yill
# impetus imputes
# impure umpire
# incest insect
# incest nicest
# incests insects
# incudes incused
# incudes induces
# indented intended
# indenter intender
# indenters intenders
# indenting intending
# indues undies
# nudies undies
# ruinated urinated
# inter niter
# niter nitre
# infarcts infracts
# reinform reniform
# signers singers
# pouring rouping
# kins sink
# reinsert reinters
# rusine ursine
# minister misinter
# intro nitro
# intros nitros
# untired untried
# rise sire
# irides irised
# irks kris
# is si
# sanities sanitise
# leis lies
# ism sim
# mis sim
# isms sims
# miss sims
# theories theorise
# it ti
# its tis
# sit tis
# jar raj
# jato jota
# jatos jotas
# jeered jereed
# jest jets
# jollity joltily
# just juts
# kae kea
# kaes keas
# kale lake
# kales lakes
# kame make
# kames makes
# kames samek
# skean sneak
# kaon koan
# kaons koans
# karn nark
# nark rank
# karns narks
# knars snark
# narks ranks
# karst karts
# kay yak
# kays yaks
# keel leek
# keels leeks
# keen knee
# keening kneeing
# keens knees
# skeen skene
# keep peek
# peek peke
# keeping peeking
# keeps peeks
# peeks pekes
# skeet steek
# keir kier
# keirs kiers
# siker skier
# keister kiester
# keisters kiesters
# kenotic ketonic
# reeky rekey
# kilting kitling
# kiltings kitlings
# skip spik
# kist kits
# kite tike
# kites tikes
# kittel kittle
# kleig klieg
# skint stink
# knops knosp
# koa oka
# oak oka
# koas okas
# koas soak
# oaks okas
# krait traik
# kraits traiks
# kue uke
# kues ukes
# kyte tyke
# kytes tykes
# lacey lycea
# ladder larded
# raddles saddler
# ladron lardon
# ladrons lardons
# lairing railing
# lameness maleness
# lameness nameless
# maleness maneless
# maneless nameless
# lamenesses malenesses
# mantel mantle
# mantel mental
# mantels mantles
# plasm psalm
# lapper rappel
# lappers rappels
# leaps peals
# pales salep
# lapsing sapling
# las sal
# lascars rascals
# lases sales
# lass sals
# lasting salting
# salting slating
# slating staling
# lasts salts
# salts slats
# late tale
# tael tale
# tael teal
# tale tela
# teal tela
# latent talent
# latents talents
# laterite literate
# laterites literates
# latrine ratline
# lave leva
# lave vale
# leva vela
# vale vela
# veal vela
# leaver vealer
# leavers vealers
# laver ravel
# lavers ravels
# salver slaver
# serval versal
# laves vales
# salve slave
# salve valse
# vales valse
# lawed waled
# lawing waling
# leap peal
# leaped pealed
# leaping pealing
# leasable sealable
# leased sealed
# leaser sealer
# reales sealer
# leasing sealing
# setal steal
# slate stale
# stale stela
# steal stela
# taels tales
# taels teals
# teals tesla
# slates stales
# leaved vealed
# leavier vealier
# leaving vealing
# leavy vealy
# leer reel
# leered reeled
# sleetier steelier
# leering reeling
# leers reels
# sleet steel
# steel stele
# legist legits
# mangel mangle
# lei lie
# lemon melon
# lemons melons
# lenes lense
# lenis lines
# liens lines
# lenses lessen
# lentil lintel
# lentils lintels
# leper repel
# lepers repels
# less sels
# lest lets
# levered reveled
# levering reveling
# leviable liveable
# relives reviles
# levin liven
# levins livens
# levo love
# love vole
# lewd weld
# lewder welder
# ley lye
# leys lyes
# lyes lyse
# sild slid
# lien line
# lienable lineable
# lienal lineal
# lier lire
# lier riel
# lire rile
# riel rile
# liers riels
# riels riles
# lilt till
# lilted tilled
# lilting tilling
# lilts tills
# lime mile
# limes miles
# slime smile
# limestone milestone
# limestones milestones
# limitary military
# limo milo
# limos milos
# rimples simpler
# limpest limpets
# limpsy simply
# lin nil
# lino lion
# lion loin
# loin noil
# linos lions
# lions loins
# loins noils
# lins nils
# lips lisp
# sliping spiling
# list lits
# list silt
# lits tils
# silt slit
# silt tils
# liters litres
# liters tilers
# listing silting
# lists silts
# silts slits
# lit til
# liter litre
# liter tiler
# litter tilter
# litters tilters
# livest vilest
# salon solan
# loden olden
# loess loses
# loses soles
# sloes soles
# loiter toiler
# melton molten
# loom mool
# looms mools
# nolos solon
# loop pool
# polo pool
# looped pooled
# looping pooling
# loops pools
# polos pools
# sloop spool
# loot tool
# looted tooled
# looter tooler
# looters toolers
# looting tooling
# loots lotos
# loots tools
# lotos sotol
# sotol stool
# lop pol
# lope pole
# loped poled
# loper poler
# lopers polers
# lopes poles
# loping poling
# lops pols
# lore role
# orle role
# lores loser
# lores roles
# lores sorel
# orles roles
# lose sole
# sloe sole
# losing soling
# loss sols
# lost lots
# lotus louts
# lotus tolus
# louder loured
# loused souled
# louver louvre
# louvers louvres
# loved voled
# loves voles
# loving voling
# lower rowel
# lowered roweled
# lowering roweling
# lowers rowels
# lowes lowse
# nuclear unclear
# plums slump
# luna ulna
# ulan ulna
# lunar ulnar
# lunas ulnas
# ulans ulnas
# lure rule
# lured ruled
# lurer ruler
# lurers rulers
# lures rules
# luring ruling
# luster lustre
# luster ulster
# lustre rustle
# lusters lustres
# lusters ulsters
# lustres rustles
# lustred rustled
# lustring rustling
# lute tule
# lutes tules
# mutuel mutule
# macaber macabre
# macerate racemate
# macerates racemates
# macho mocha
# machos mochas
# maligners malingers
# manege menage
# maneges menages
# mangels mangles
# ramson ransom
# manos mason
# manos monas
# moans monas
# monas nomas
# manses mensas
# mensas messan
# many myna
# mapper pamper
# mappers pampers
# marbled rambled
# marbler rambler
# marblers ramblers
# marbling rambling
# mares marse
# mares maser
# noteless toneless
# noter toner
# tenor toner
# notes tones
# steno stone
# noting toning
# nous onus
# nouses onuses
# now won
# own won
# nows sown
# nows wons
# owns wons
# nowt town
# nowt wont
# nowts towns
# nowts wonts
# nu un
# nuder under
# nuns sunn
# nus sun
# nus uns
# nut tun
# nuts tuns
# oar ora
# osar soar
# soar sora
# oasis ossia
# oast oats
# oats taos
# oat tao
# observe obverse
# observes obverses
# ocherous ochreous
# yodel yodle
# yodels yodles
# oes ose
# oho ooh
# oils silo
# silo soli
# soil soli
# stenos stones
# oot too
# opt pot
# pot top
# option potion
# options potions
# opts pots
# post pots
# pots tops
# spot stop
# orach roach
# orb rob
# orbs robs
# orc roc
# orcs rocs
# ore roe
# ort rot
# rot tor
# orts rots
# rots tors
# sort tors
# os so
# otter toter
# otters toters
# sought toughs
# oust outs
# routes souter
# ousting outsing
# outer outre
# routing touring
# outguns outsung
# output putout
# outputs putouts
# outrides outsider
# outslept outspelt
# overbusy overbuys
# overdoes overdose
# servo verso
# ow wo
# owe woe
# owes owse
# owes woes
# rewon rowen
# ozonides ozonised
# padri pardi
# pail pial
# pairs paris
# palest palets
# palmary palmyra
# palter plater
# palters platers
# plaster psalter
# paltry partly
# partly raptly
# paly play
# panel penal
# plane plena
# panne penna
# panted pentad
# par rap
# parer raper
# parers rapers
# paring raping
# pars raps
# raps rasp
# part prat
# part rapt
# part tarp
# prat trap
# tarp trap
# partan tarpan
# tarpan trapan
# partans tarpans
# tarpans trapans
# parties pastier
# piaster piastre
# parting prating
# parton patron
# parton tarpon
# partons patrons
# partons tarpons
# parts prats
# parts tarps
# prats traps
# sprat strap
# tarps traps
# phases shapes
# past pats
# pats taps
# pates tapes
# tapes tepas
# paters tapers
# prates trapes
# spates stapes
# pastiches pistaches
# pasties patsies
# piasters piastres
# pasty patsy
# pate tape
# tape tepa
# patios patois
# patulent petulant
# pavid vapid
# paw wap
# paws waps
# waps wasp
# pay pya
# pay yap
# pays pyas
# pays yaps
# peckier pickeer
# pedicel pedicle
# peel pele
# sleeping speeling
# peels peles
# sleep speel
# peer pere
# peer pree
# pere pree
# peering preeing
# peers peres
# peers prees
# peres perse
# peres prees
# perse prese
# prees prese
# speer spree
# pees seep
# peins penis
# penis pines
# snipe spine
# peltry pertly
# slept spelt
# pennate pentane
# pepo pope
# pepos popes
# per rep
# percent precent
# percents precents
# percept precept
# percepts precepts
# perfect prefect
# perfects prefects
# perform preform
# performed preformed
# performing preforming
# performs preforms
# pries prise
# speir spier
# spier spire
# plasters psalters
# speers sprees
# pertest pretest
# purees rupees
# pervious previous
# pesos poses
# poses posse
# pest pets
# pest sept
# pests septs
# petit petti
# plastery psaltery
# philter philtre
# philters philtres
# python typhon
# pythons typhons
# pile plie
# piled plied
# piles plies
# slipe spile
# speil spiel
# spiel spile
# pilus pulis
# pintos piston
# piston postin
# pis psi
# pis sip
# piss psis
# piss sips
# pistons postins
# pit tip
# pits tips
# pixys pyxis
# plaint pliant
# plaiter platier
# planate platane
# planet platen
# planets platens
# plasmic psalmic
# plasms psalms
# slipes spiles
# speils spiels
# spiels spiles
# ploy poly
# ploys polys
# plus puls
# pluses pulses
# poises posies
# snoopier spoonier
# snoop spoon
# pore rope
# pores poser
# pores ropes
# poring roping
# portend protend
# portended protended
# portending protending
# portends protends
# positing sopiting
# spots stops
# potful topful
# potstone topstone
# potstones topstones
# pour roup
# poured rouped
# pours roups
# spout stoup
# pow wop
# pows wops
# prao proa
# praos proas
# precis prices
# presetting pretesting
# speired spiered
# pride pried
# prides prised
# spider spired
# prims prism
# speirs spiers
# spiers spires
# propenes propense
# sopor spoor
# sopors spoors
# pules pulse
# puree rupee
# pus sup
# pus ups
# puses supes
# spues supes
# puss sups
# put tup
# puts tups
# quais quasi
# quarte quatre
# quartes quatres
# questionnaire questionniare
# questionnaires questionniares
# quickest quickset
# quiet quite
# quinnat quintan
# quinnats quintans
# racket tacker
# rackets tackers
# ragtag tagrag
# ragtags tagrags
# rallies sallier
# ramsons ransoms
# randies sandier
# tarns trans
# rate tare
# tarre terra
# ratine retina
# rato rota
# rato taro
# rota tora
# taro tora
# ratos rotas
# ratos taros
# rotas toras
# taros toras
# rattan tartan
# rattans tartans
# ratted tarted
# ratter tarter
# ratting tarting
# rattly tartly
# ravages savager
# raw war
# rawer warer
# tawers waters
# raws wars
# ray rya
# ray yar
# rays ryas
# redears rereads
# saltier saltire
# saltier slatier
# saltiers saltires
# scepter sceptre
# scepter specter
# sceptre spectre
# specter spectre
# recourse resource
# recourses resources
# recused secured
# reduces seducer
# recusing securing
# scarped scraped
# redden rended
# rees seer
# seer sere
# reeved veered
# reeving veering
# regarding regrading
# regelated relegated
# regelating relegating
# renigs resign
# signer singer
# resin risen
# resin serin
# risen siren
# serin siren
# reiver riever
# reivers rievers
# released resealed
# reliving reviling
# renews resewn
# rennet tenner
# rennets tenners
# repertoires repertories
# repin ripen
# repined ripened
# repiner ripener
# repiners ripeners
# repining ripening
# repins ripens
# serries sirrees
# sawer sewar
# sewar swear
# sawers sewars
# sewars swears
# reserve reverse
# reveres reverse
# reveres severer
# reserver reverser
# reservers reversers
# reserves reverses
# reserving reversing
# resetting retesting
# silverer sliverer
# silverers sliverers
# resins serins
# serins sirens
# roster sorter
# rosters sorters
# resow serow
# resows serows
# scepters sceptres
# scepters specters
# sceptres spectres
# specters spectres
# retrains terrains
# retail retial
# setter tester
# setters testers
# retired retried
# retires retries
# retries terries
# retrain terrain
# retry terry
# server verser
# versets verstes
# rhesus rhuses
# ribbon robbin
# ribbons robbins
# rickets tickers
# ridden rinded
# rilles siller
# rillet tiller
# rillets tillers
# ringlet tingler
# ringlets tinglers
# tiro tori
# tiro trio
# tiros trios
# trios trois
# ripplet tippler
# ripplets tipplers
# rises sires
# rising siring
# rite tire
# tier tire
# rites tires
# tiers tires
# tires tries
# rival viral
# rives siver
# rives vires
# viers vires
# roguing rouging
# roost roots
# roots rotos
# rotos toros
# toros torso
# root roto
# roto toro
# rootlet tootler
# rootlets tootlers
# roser sorer
# roses sores
# roset rotes
# rotes tores
# tores torse
# torses tosser
# sorites sorties
# rotch torch
# rote tore
# rotten torten
# rouser sourer
# rousing souring
# roust routs
# routs tours
# torus tours
# routers tourers
# rout tour
# router tourer
# rowdier wordier
# wordier worried
# rowdiest wordiest
# rowdily wordily
# rowdiness wordiness
# rowdinesses wordinesses
# rowth worth
# worth wroth
# rowths worths
# rues ruse
# rues suer
# ruse sure
# suer sure
# suer user
# ruffes suffer
# ruinate urinate
# uranite urinate
# ruinates urinates
# uranites urinates
# ruinating urinating
# ruinous urinous
# run urn
# runs urns
# suers users
# russets tussers
# rust ruts
# tory troy
# tory tyro
# story stroy
# sabers sabres
# sadis saids
# sae sea
# sails sials
# satins stains
# salines silanes
# salivas salvias
# salons solans
# salps slaps
# saltiest slatiest
# salty slaty
# salutes taluses
# salved slaved
# salvers slavers
# salves slaves
# salves valses
# salving slaving
# sanity satiny
# talons tolans
# sat tas
# satirist sitarist
# satirists sitarists
# saves vases
# saw was
# sawyer swayer
# sawyers swayers
# scaped spaced
# scapes spaces
# scaping spacing
# scarpers scrapers
# scarps scraps
# sceptral spectral
# schemer schmeer
# schemers schmeers
# seated teased
# seeking skeeing
# seeks skees
# seems semes
# segni sengi
# sengi singe
# series sirees
# sends sneds
# sennit tennis
# sepulcher sepulchre
# sepulchers sepulchres
# servant versant
# servants versants
# serve verse
# served versed
# servers versers
# serves verses
# serving versing
# servos versos
# sestet testes
# settee testee
# settees testees
# setting testing
# sherds shreds
# shout thous
# shrieks shrikes
# tushes tusseh
# signing singing
# signs sings
# sikes skies
# silly slily
# silly yills
# vails vials
# silvering slivering
# silvers slivers
# sinew wines
# siped spied
# sipes spies
# sir sri
# sirs sris
# sites sties
# titers titres
# six xis
# skate stake
# skated staked
# skates stakes
# skating staking
# skeans sneaks
# skeens skenes
# skeets steeks
# skips spiks
# skirret skirter
# skirrets skirters
# skirt stirk
# skirts stirks
# sleeps speels
# sleetiest steeliest
# sleets steels
# steels steles
# sleety steely
# sliming smiling
# slipt spilt
# spilt split
# slitted stilted
# slitting stilting
# sloops spools
# slowness snowless
# smites stimes
# snapless spanless
# snaps spans
# snatched stanched
# snatchers stanchers
# snatching stanching
# snaws swans
# sneaped speaned
# sneaping speaning
# sniped spined
# snipes spines
# snips spins
# snooped spooned
# snoopiest spooniest
# snoopily spoonily
# snooping spooning
# snoops spoons
# snoopy spoony
# snye syne
# soars soras
# soldier solider
# solitaires solitaries
# solus souls
# somberly sombrely
# sonnet tonnes
# sorus sours
# sotols stools
# sots toss
# sow wos
# spade spaed
# speeder speered
# speiled spieled
# speiling spieling
# speiring spiering
# spirt sprit
# spirt stirp
# sprit strip
# stirp strip
# spirts sprits
# spirts stirps
# sprits strips
# stirps strips
# spite stipe
# spited stiped
# spites stipes
# spotlight stoplight
# spotlights stoplights
# spouts stoups
# sprats straps
# spue supe
# sputa stupa
# staccato stoccata
# staccatos stoccatas
# stades tsades
# stardom tsardom
# stardoms tsardoms
# starets staters
# stars tsars
# trass tsars
# taste testa
# teats testa
# tasset tastes
# staw swat
# swat twas
# taws twas
# taws wats
# wast wats
# tews wets
# west wets
# stey stye
# telos toles
# storying stroying
# stow swot
# swot twos
# tows twos
# tows wots
# wost wots
# stows swots
# strongly strongyl
# worst worts
# strut sturt
# struts sturts
# tumblers tumbrels
# suable usable
# suably usably
# subbed subdeb
# sue use
# sues uses
# suing using
# suit tuis
# thaws whats
# ways yaws
# weest weets
# wildness windless
# whist whits
# tactic tictac
# tactics tictacs
# tailles tallies
# tango tonga
# tangos tongas
# tantara tartana
# tantaras tartanas
# tardier tarried
# tarries tarsier
# tartlet tattler
# tartlets tattlers
# tav vat
# tavs vats
# vast vats
# taw twa
# taw wat
# tawer water
# taxes texas
# teazel teazle
# teazels teazles
# tenias tineas
# unites unties
# unmiters unmitres
# termor tremor
# termors tremors
# tew wet
# tewed tweed
# thaw what
# theater theatre
# thew whet
# thews whets
# thickest thickets
# thickest thickset
# thorned throned
# tilde tiled
# tilted titled
# tilting titling
# timber timbre
# timbers timbres
# tired tried
# titer titre
# toady today
# tort trot
# torts trots
# tost tots
# tow two
# tow wot
# trail trial
# trails trials
# triacid triadic
# trying tyring
# tumbler tumbrel
# twist twits
# unburden unburned
# uncrated untraced
# underdogs undergods
# ungual ungula
# unite untie
# unleased unsealed
# unlit until
# unmated untamed
# unserved unversed
# unspilt unsplit
# untilted untitled
# vail vial
# vailed vialed
# vailing vialing
# valor volar
# verst verts
# vest vets
# veto vote
# vies vise
# wadder warded
# wader wared
# waist waits
# waiver wavier
# waives wavies
# wake weka
# weak weka
# wander warden
# warden warned
# wanders wardens
# warner warren
# warners warrens
# warp wrap
# warps wraps
# warstle wrastle
# warstled wrastled
# warstles wrastles
# warstling wrastling
# way yaw
# weiner wiener
# weird wried
# wider wired
# wired wried
# weirs wries
# wires wiser
# wires wries
# whoso woosh
# wides wised
# wield wiled
# wilting witling
# wirer wrier
# wist wits
# worthful wrothful
# wrist writs
# zaffer zaffre
# zaffers zaffres

# %% [markdown]
# ### Exercício 12.4
#
# Aqui está outro quebra-cabeça do programa Car Talk (http://www.cartalk.com/content/puzzlers):
#
# Qual é a palavra inglesa mais longa, que permanece uma palavra inglesa válida, conforme vai removendo suas letras, uma após a outra?
#
# Agora, as letras podem ser retiradas do fim ou do meio, mas você não pode reajustar nenhuma delas. Cada vez que remove uma letra, você acaba com outra palavra inglesa. Se fizer isto, eventualmente você acabará com uma letra e isso também será uma palavra inglesa; uma encontrada no dicionário. Quero saber qual é a palavra mais longa e quantas letras tem?
#
# Vou dar um pequeno exemplo modesto: Sprite. Ok? Você começa com sprite, tira uma letra do interior da palavra, tira o r, e ficamos com a palavra spite, então tiramos o e do fim, ficamos com spit, tiramos o s, ficamos com pit, it e I.
#
# Escreva um programa que encontre todas as palavras que podem ser reduzidas desta forma, e então encontre a mais longa.
#
# Este exercício é um pouco mais desafiador que a maioria, então aqui estão algumas sugestões:
#
# 1. Você pode querer escrever uma função que receba uma palavra e calcule uma lista de todas as palavras que podem ser formadas retirando uma letra. Esses são os “filhos” da palavra.
#
# 2. Recursivamente, uma palavra é redutível se algum de seus filhos for redutível. Como caso base, você pode considerar a string vazia redutível.
#
# 3. A lista de palavras que forneci, words.txt, não contém palavras de uma letra só. Portanto, você pode querer acrescentar “I”, “a”, e a string vazia.
#
# 4. Para melhorar o desempenho do seu programa, você pode querer memorizar as palavras conhecidas por serem redutíveis.
#
# Solução: http://thinkpython2.com/code/reducible.py.

# %% [markdown]
# Solução do autor:

# %%
def make_word_dict(filename):
    d = dict()
    for line in open(filename):
        word = line.strip().lower()
        d[word] = word
    
    for letter in ['a', 'i', '']:
        d[letter] = letter

    return d

# %%
def children(word, word_dict):
    """Returns a list of all words that can be formed by removing one letter.

    word: string

    Returns: list of strings
    """
    res = []
    for i in range(len(word)):
        child = word[:i] + word[i+1:]
        if child in word_dict:
            res.append(child)
    return res

# %%
memo = {}
memo[''] = ['']
def is_reducible(word, word_dict):
    """If word is reducible, returns a list of its reducible children.

    Also adds an entry to the memo dictionary.

    A string is reducible if it has at least one child that is 
    reducible.  The empty string is also reducible.

    word: string
    word_dict: dictionary with words as keys
    """
     # if have already checked this word, return the answer
    if word in memo:
        return memo[word]

    # check each of the children and make a list of the reducible ones
    res = []
    for child in children(word, word_dict):
        t = is_reducible(child, word_dict)
        if t:
            res.append(child)

    # memoize and return the result
    memo[word] = res
    return res

# %%
def all_reducible(word_dict):
    """Checks all words in the word_dict; returns a list reducible ones.

    word_dict: dictionary with words as keys
    """
    res = []
    for word in word_dict:
        t = is_reducible(word, word_dict)
        if t != []:
            res.append(word)
    return res

# %%
def print_trail(word):
    """Prints the sequence of words that reduces this word to the empty string.

    If there is more than one choice, it chooses the first.

    word: string
    """
    if len(word) == 0:
        return
    print (word)
    t = is_reducible(word, word_dict)
    print_trail(t[0])

# %%
def print_longest_words(word_dict):
    words = all_reducible(word_dict)

    # use DSU to sort by word length
    t = []
    for word in words:
        t.append((len(word), word))
    t.sort(reverse=True)

    # print the longest 5 words
    for length, word in t[0:5]:
        print_trail(word)
        print ('\n')

# %%
if __name__ == '__main__':
    word_dict = make_word_dict('words.txt')
    print_longest_words(word_dict)
# Out:
# complecting
# completing
# competing
# compting
# comping
# coping
# oping
# ping
# pig
# pi
# i
#
#
# twitchiest
# witchiest
# withiest
# withies
# withes
# wites
# wits
# its
# is
# i
#
#
# stranglers
# strangers
# stranger
# strange
# strang
# stang
# tang
# tag
# ta
# a
#
#
# staunchest
# stanchest
# stanches
# stances
# stanes
# sanes
# anes
# ane
# ae
# a
#
#
# restarting
# restating
# estating
# stating
# sating
# sting
# ting
# tin
# in
# i

# %%
count = 0
for word in word_dict:
  if count < 30:
    print(word)
    count = count + 1
# Out:
# aa
# aah
# aahed
# aahing
# aahs
# aal
# aalii
# aaliis
# aals
# aardvark
# aardvarks
# aardwolf
# aardwolves
# aas
# aasvogel
# aasvogels
# aba
# abaca
# abacas
# abaci
# aback
# abacus
# abacuses
# abaft
# abaka
# abakas
# abalone
# abalones
# abamp
# abampere
