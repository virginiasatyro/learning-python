# %% [markdown]
# # Programming for Everybody (Getting Started with Python) - University of Michigan
#
# # Week 1
#
# ## Welcome
#
# ### Video: Welcome to Class - Dr. Chuck
#
# ### Reading: Welcome to Class
#
# - https://www.py4e.com/ - This web site is building a set of free materials, lectures, book and assignments to help students learn how to program in Python.
#
# ### Video: Welcome to Python - Guido van Rossum
#
# ### Course Syllabus
#
# ### Welcome to Python 3
#
# ### Textbook: Python for Everybody: Exploring Data in Python 3
#
# - https://do1.dr-chuck.com/pythonlearn/EN_us/pythonlearn.pdf - Book
#
# - https://www.youtube.com/playlist?list=PLlRFEj9H3Oj7Bp8-DfGpfAfDBiblRfl5p - Youtube lessons playlist
#
# ### Submitting Assignments
#
# ## Lecture Materials
#
# ### 1.1 Why Program
#
# ### 1.2 Hardware Overview
#
# - **Central Processing Unit**: runs the program - the CPU is alwas wondering "what to do next". Not the brains exactly - very dumb but very very fast
# - **Input Devices**: keyboard, mouse, touch screen
# - **Output Devices**: screen, speakers, printter, DVD burner
# - **Main Memory**: fast small temporary storage -lost on reboot - aka RAM
# - **Secondary Memory**: slower, large, permanent storage - lasts until deleted - disk drive / memory stick
#
# ### 1.3 Python as a Language
#
# ## Additional Materials
#
# # Week 2
#
# ## Installing Python
#
# ### Important Reading: Using Python in this Class
#
# - https://www.py4e.com/tools/pythonauto/?PHPSESSID=9d11e9babd1019a47bf492f2db8330a3
#
# ### Notes on Choice of Text Editor
#
# ### Demonstration: Using the Python Playground
#
# ### Python Code Playground
#
# - https://www.py4e.com/tools/pythonauto/?PHPSESSID=9d11e9babd1019a47bf492f2db8330a3
#
# ### Windows 10: Installing Python and Writing A Program
#
# ## Bonus Materials
#
# ### Bonus: Eben Upton and the RaspBerry Pi
#
# # Week 3
#
# ## Lecture Materials
#
# ### 1.4 - Writing Paragraphs of Code
#
# - Reserved words
# - Sentences or lines
# - Variable, operator, constant, function
# - Interactive: type directly to Python at a time and it responds
# - Script: sequence of statements into a file using a text editor and tell Python to execute
# - Sequential, conditional, repeat
#
# ## Review: Chapter 1
#
# ## Assignment: Chapter 1
#
# ### Demonstration: Doing the "Hello World" Assignment

# %%
# Write a program that uses a print statement to say 'hello world' as shown in 'Desired Output'.

print("hello world")
# Out:
# hello world

# %% [markdown]
# ## Bonus: Chapter 1
#
# ### Interview: Daphne Koller - Building Coursera
#
# ### Face-to-Face Office Hours: Milan, Italy
#
# # Week 4
#
# ## Lecture Materials
#
# ### 2.1 - Expressions
#
# - Constants
#
# - Reserved words
#
# - **Variable** - is a named *place in the memory* where a programmer can store data and later retrieve the data using the variable "name".
#
# ###
#
# ###
#
# ## Review: Chapter 2
#
# ## Assignment: Chapter 2
#
# ## Bonus: Chapter 2
